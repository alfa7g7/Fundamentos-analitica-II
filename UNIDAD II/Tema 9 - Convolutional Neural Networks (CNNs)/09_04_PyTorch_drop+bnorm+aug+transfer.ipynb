# %% [markdown]
# # Regularización, data augmentation y transfer learning con modelos convolucionales

# %% [markdown]
# Bibliografía:
# - Machine Learning with PyTorch and Scikit-Learn: Develop machine learning and deep learning models with Python (capítulo 14), Sebastian Rachska et al., 2022 Packt
# - Deep Learning with PyTorch, Eli Stevens et al, 2020 Manning
# - Deep Learning with Python (capítulo 2), Francois Chollet, 2018 Manning
# - Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems (2nd ed.), Aurelien Geron, 2019 O'Reilly
# - Deep Learning Specialization, DeepLearning.AI, Coursera
# - https://pytorch.org/tutorials

# %% [markdown]
# En este noteboook presentamos:
# - El uso de data loaders basados en datasets de imágenes desde el sistema de archivos
# - Regularización de modelos con capas dropout o de batch normalization
# - Data augmentation con imágenes a partir de transformaciones
# - Transfer learning
# - Fine tuning de capas transferidas

# %% [markdown]
# Utilizamos los siguientes componentes técnicos:
# - layers: Conv2D, MaxPooling2D, Flatten, Dense, Droupout, BatchNormalisation
# - optimizadores: Adam
# - loss functions: binary_crossentropy
# - métricas de seguimiento y evaluación: accuracy
# - funciones de activación: relu, sigmoid
# - generadores de datos de imágenes: ImageDataGenerator
# - modelos transferidos: VGG16, InceptionV3
# - Uso de Api funcional de Keras para creación de modelos no secuenciales

# %%
import os, glob, zipfile, shutil
import requests
import time
import copy
from shutil import rmtree, copyfile
import random
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import torchvision
import torchvision.transforms as T
import torchvision
import torchvision.models as models

# %%
# !pip install torchvision
import torchvision
import torchvision.transforms as T

from torchsummary import summary
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.5.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.5.0+cu121)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.5.0->torchvision) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.0->torchvision) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.0->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.0->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.0->torchvision) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.0->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.0->torchvision) (3.0.2)

# %%
if torch.cuda.is_available():
    print("Utilizamos la primera GPU disponible")
    DEVICE=device = torch.device('cuda:0')
    os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
else:
    print("No hay GPU, toca correr todo en CPU")
    DEVICE=device = torch.device('cpu')

DEVICE
# Out:
# Utilizamos la primera GPU disponible
# device(type='cuda', index=0)

# %%
def reset_seed():
    random_seed = 42
    torch.backends.cudnn.enabled = True
    torch.manual_seed(random_seed)
    np.random.seed(random_seed)
    random.seed(random_seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed(42)
        torch.cuda.manual_seed_all(42)

        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %%
reset_seed()

# %% [markdown]
# ## Parte 1. Obtención y preparación del dataset

# %% [markdown]
# Este notebook parte del hecho de que se va a ejecutar en **Google Colab**.
#
# Bajamos la data en un zip, y lo descomprimimos.

# %%
if os.path.exists('/content/kagglecatsanddogs_5340.zip'):
  os.remove('/content/kagglecatsanddogs_5340.zip')

# %%
# !wget --no-check-certificate \
    "https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip"
# Out:
# --2024-10-23 23:25:17--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip
# Resolving download.microsoft.com (download.microsoft.com)... 96.7.158.17, 2600:1409:9800:48e::317f, 2600:1409:9800:480::317f
# Connecting to download.microsoft.com (download.microsoft.com)|96.7.158.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824887076 (787M) [application/octet-stream]
# Saving to: ‘kagglecatsanddogs_5340.zip’
#
# kagglecatsanddogs_5 100%[===================>] 786.67M  71.9MB/s    in 8.4s
#
# 2024-10-23 23:25:26 (93.2 MB/s) - ‘kagglecatsanddogs_5340.zip’ saved [824887076/824887076]

# %% [markdown]
# El dataset que vamos a utilizar fue objeto de una competencia de **Kaggle** de hace unos años.
# Ya descargamos el archivo zip y lo descomprimimos.
# Ahora vamos a reorganizarlo para hacer varios experimentos.
# Esta operación <font color="red">**solo se debe realizar una única vez** </font>.

# %%
ORGANIZAR_ARCHIVOS=True

# %%
# El directorio con los datos originales bajados
original_dataset_dir = '/content/original/'
original_dataset_cats_dir = '/content/original/PetImages/Cat'
original_dataset_dogs_dir = '/content/original/PetImages/Dog'

# El directorio con los particionamientos que utilizaremos para entrenar, validar y evaluar
base_dir = '/content/cats_and_dogs'

# %%
#shutil.rmtree('/content/original')
#shutil.rmtree(base_dir)

# %%
if os.path.exists(original_dataset_dir):
  shutil.rmtree(original_dataset_dir)

if ORGANIZAR_ARCHIVOS:
  if os.path.exists(base_dir):
    shutil.rmtree(base_dir)

# %%
if os.path.exists(base_dir):
  shutil.rmtree(base_dir)

# %%
# !unzip kagglecatsanddogs_5340.zip -d original
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   inflating: original/PetImages/Dog/5500.jpg
#   inflating: original/PetImages/Dog/5501.jpg
#   inflating: original/PetImages/Dog/5502.jpg
#   inflating: original/PetImages/Dog/5503.jpg
#   inflating: original/PetImages/Dog/5504.jpg
#   inflating: original/PetImages/Dog/5505.jpg
#   inflating: original/PetImages/Dog/5506.jpg
#   inflating: original/PetImages/Dog/5507.jpg
#   inflating: original/PetImages/Dog/5508.jpg
#   inflating: original/PetImages/Dog/5509.jpg
#   inflating: original/PetImages/Dog/551.jpg
#   inflating: original/PetImages/Dog/5510.jpg
#   inflating: original/PetImages/Dog/5511.jpg
#   inflating: original/PetImages/Dog/5512.jpg
#   inflating: original/PetImages/Dog/5513.jpg
#   inflating: original/PetImages/Dog/5514.jpg
#   inflating: original/PetImages/Dog/5515.jpg
#   inflating: original/PetImages/Dog/5516.jpg
#   inflating: original/PetImages/Dog/5517.jpg
#   inflating: original/PetImages/Dog/5518.jpg
#   inflating: original/PetImages/Dog/5519.jpg
#   inflating: original/PetImages/Dog/552.jpg
#   inflating: original/PetImages/Dog/5520.jpg
#   inflating: original/PetImages/Dog/5521.jpg
#   inflating: original/PetImages/Dog/5522.jpg
#   inflating: original/PetImages/Dog/5523.jpg
#   inflating: original/PetImages/Dog/5524.jpg
#   inflating: original/PetImages/Dog/5525.jpg
#   inflating: original/PetImages/Dog/5526.jpg
#   inflating: original/PetImages/Dog/5527.jpg
#   inflating: original/PetImages/Dog/5528.jpg
#   inflating: original/PetImages/Dog/5529.jpg
#   inflating: original/PetImages/Dog/553.jpg
#   inflating: original/PetImages/Dog/5530.jpg
#   inflating: original/PetImages/Dog/5531.jpg
#   inflating: original/PetImages/Dog/5532.jpg
#   inflating: original/PetImages/Dog/5533.jpg
#   inflating: original/PetImages/Dog/5534.jpg
#   inflating: original/PetImages/Dog/5535.jpg
#   inflating: original/PetImages/Dog/5536.jpg
#   inflating: original/PetImages/Dog/5537.jpg
#   inflating: original/PetImages/Dog/5538.jpg
#   inflating: original/PetImages/Dog/5539.jpg
#   inflating: original/PetImages/Dog/554.jpg
#   inflating: original/PetImages/Dog/5540.jpg
#   inflating: original/PetImages/Dog/5541.jpg
#   inflating: original/PetImages/Dog/5542.jpg
#   inflating: original/PetImages/Dog/5543.jpg
#   inflating: original/PetImages/Dog/5544.jpg
#   inflating: original/PetImages/Dog/5545.jpg
#   inflating: original/PetImages/Dog/5546.jpg
#   inflating: original/PetImages/Dog/5547.jpg
#   inflating: original/PetImages/Dog/5548.jpg
#   inflating: original/PetImages/Dog/5549.jpg
#   inflating: original/PetImages/Dog/555.jpg
#   inflating: original/PetImages/Dog/5550.jpg
#   inflating: original/PetImages/Dog/5551.jpg
#   inflating: original/PetImages/Dog/5552.jpg
#   inflating: original/PetImages/Dog/5553.jpg
#   inflating: original/PetImages/Dog/5554.jpg
#   inflating: original/PetImages/Dog/5555.jpg
#   inflating: original/PetImages/Dog/5556.jpg
#   inflating: original/PetImages/Dog/5557.jpg
#   inflating: original/PetImages/Dog/5558.jpg
#   inflating: original/PetImages/Dog/5559.jpg
#   inflating: original/PetImages/Dog/556.jpg
#   inflating: original/PetImages/Dog/5560.jpg
#   inflating: original/PetImages/Dog/5561.jpg
#   inflating: original/PetImages/Dog/5562.jpg
#   inflating: original/PetImages/Dog/5563.jpg
#   inflating: original/PetImages/Dog/5564.jpg
#   inflating: original/PetImages/Dog/5565.jpg
#   inflating: original/PetImages/Dog/5566.jpg
#   inflating: original/PetImages/Dog/5567.jpg
#   inflating: original/PetImages/Dog/5568.jpg
#   inflating: original/PetImages/Dog/5569.jpg
#   inflating: original/PetImages/Dog/557.jpg
#   inflating: original/PetImages/Dog/5570.jpg
#   inflating: original/PetImages/Dog/5571.jpg
#   inflating: original/PetImages/Dog/5572.jpg
#   inflating: original/PetImages/Dog/5573.jpg
#   inflating: original/PetImages/Dog/5574.jpg
#   inflating: original/PetImages/Dog/5575.jpg
#   inflating: original/PetImages/Dog/5576.jpg
#   inflating: original/PetImages/Dog/5577.jpg
#   inflating: original/PetImages/Dog/5578.jpg
#   inflating: original/PetImages/Dog/5579.jpg
#   inflating: original/PetImages/Dog/558.jpg
#   inflating: original/PetImages/Dog/5580.jpg
#   inflating: original/PetImages/Dog/5581.jpg
#   inflating: original/PetImages/Dog/5582.jpg
#   inflating: original/PetImages/Dog/5583.jpg
#   inflating: original/PetImages/Dog/5584.jpg
#   inflating: original/PetImages/Dog/5585.jpg
#   inflating: original/PetImages/Dog/5586.jpg
#   inflating: original/PetImages/Dog/5587.jpg
#   inflating: original/PetImages/Dog/5588.jpg
#   inflating: original/PetImages/Dog/5589.jpg
#   inflating: original/PetImages/Dog/559.jpg
#   inflating: original/PetImages/Dog/5590.jpg
#   inflating: original/PetImages/Dog/5591.jpg
#   inflating: original/PetImages/Dog/5592.jpg
#   inflating: original/PetImages/Dog/5593.jpg
#   inflating: original/PetImages/Dog/5594.jpg
#   inflating: original/PetImages/Dog/5595.jpg
#   inflating: original/PetImages/Dog/5596.jpg
#   inflating: original/PetImages/Dog/5597.jpg
#   inflating: original/PetImages/Dog/5598.jpg
#   inflating: original/PetImages/Dog/5599.jpg
#   inflating: original/PetImages/Dog/56.jpg
#   inflating: original/PetImages/Dog/560.jpg
#   inflating: original/PetImages/Dog/5600.jpg
#   inflating: original/PetImages/Dog/5601.jpg
#   inflating: original/PetImages/Dog/5602.jpg
#   inflating: original/PetImages/Dog/5603.jpg
#  extracting: original/PetImages/Dog/5604.jpg
#   inflating: original/PetImages/Dog/5605.jpg
#   inflating: original/PetImages/Dog/5606.jpg
#   inflating: original/PetImages/Dog/5607.jpg
#   inflating: original/PetImages/Dog/5608.jpg
#   inflating: original/PetImages/Dog/5609.jpg
#   inflating: original/PetImages/Dog/561.jpg
#   inflating: original/PetImages/Dog/5610.jpg
#   inflating: original/PetImages/Dog/5611.jpg
#   inflating: original/PetImages/Dog/5612.jpg
#   inflating: original/PetImages/Dog/5613.jpg
#   inflating: original/PetImages/Dog/5614.jpg
#   inflating: original/PetImages/Dog/5615.jpg
#   inflating: original/PetImages/Dog/5616.jpg
#   inflating: original/PetImages/Dog/5617.jpg
#   inflating: original/PetImages/Dog/5618.jpg
#   inflating: original/PetImages/Dog/5619.jpg
#   inflating: original/PetImages/Dog/562.jpg
#   inflating: original/PetImages/Dog/5620.jpg
#   inflating: original/PetImages/Dog/5621.jpg
#   inflating: original/PetImages/Dog/5622.jpg
#   inflating: original/PetImages/Dog/5623.jpg
#   inflating: original/PetImages/Dog/5624.jpg
#   inflating: original/PetImages/Dog/5625.jpg
#   inflating: original/PetImages/Dog/5626.jpg
#   inflating: original/PetImages/Dog/5627.jpg
#   inflating: original/PetImages/Dog/5628.jpg
#   inflating: original/PetImages/Dog/5629.jpg
#   inflating: original/PetImages/Dog/563.jpg
#   inflating: original/PetImages/Dog/5630.jpg
#   inflating: original/PetImages/Dog/5631.jpg
#   inflating: original/PetImages/Dog/5632.jpg
#   inflating: original/PetImages/Dog/5633.jpg
#   inflating: original/PetImages/Dog/5634.jpg
#   inflating: original/PetImages/Dog/5635.jpg
#   inflating: original/PetImages/Dog/5636.jpg
#   inflating: original/PetImages/Dog/5637.jpg
#   inflating: original/PetImages/Dog/5638.jpg
#   inflating: original/PetImages/Dog/5639.jpg
#   inflating: original/PetImages/Dog/564.jpg
#   inflating: original/PetImages/Dog/5640.jpg
#   inflating: original/PetImages/Dog/5641.jpg
#   inflating: original/PetImages/Dog/5642.jpg
#   inflating: original/PetImages/Dog/5643.jpg
#   inflating: original/PetImages/Dog/5644.jpg
#   inflating: original/PetImages/Dog/5645.jpg
#   inflating: original/PetImages/Dog/5646.jpg
#   inflating: original/PetImages/Dog/5647.jpg
#   inflating: original/PetImages/Dog/5648.jpg
#   inflating: original/PetImages/Dog/5649.jpg
#   inflating: original/PetImages/Dog/565.jpg
#   inflating: original/PetImages/Dog/5650.jpg
#   inflating: original/PetImages/Dog/5651.jpg
#   inflating: original/PetImages/Dog/5652.jpg
#   inflating: original/PetImages/Dog/5653.jpg
#   inflating: original/PetImages/Dog/5654.jpg
#   inflating: original/PetImages/Dog/5655.jpg
#   inflating: original/PetImages/Dog/5656.jpg
#   inflating: original/PetImages/Dog/5657.jpg
#   inflating: original/PetImages/Dog/5658.jpg
#   inflating: original/PetImages/Dog/5659.jpg
#   inflating: original/PetImages/Dog/566.jpg
#   inflating: original/PetImages/Dog/5660.jpg
#   inflating: original/PetImages/Dog/5661.jpg
#   inflating: original/PetImages/Dog/5662.jpg
#   inflating: original/PetImages/Dog/5663.jpg
#   inflating: original/PetImages/Dog/5664.jpg
#   inflating: original/PetImages/Dog/5665.jpg
#   inflating: original/PetImages/Dog/5666.jpg
#   inflating: original/PetImages/Dog/5667.jpg
#   inflating: original/PetImages/Dog/5668.jpg
#   inflating: original/PetImages/Dog/5669.jpg
#   inflating: original/PetImages/Dog/567.jpg
#   inflating: original/PetImages/Dog/5670.jpg
#   inflating: original/PetImages/Dog/5671.jpg
#   inflating: original/PetImages/Dog/5672.jpg
#   inflating: original/PetImages/Dog/5673.jpg
#   inflating: original/PetImages/Dog/5674.jpg
#   inflating: original/PetImages/Dog/5675.jpg
#   inflating: original/PetImages/Dog/5676.jpg
#   inflating: original/PetImages/Dog/5677.jpg
#   inflating: original/PetImages/Dog/5678.jpg
#   inflating: original/PetImages/Dog/5679.jpg
#   inflating: original/PetImages/Dog/568.jpg
#   inflating: original/PetImages/Dog/5680.jpg
#   inflating: original/PetImages/Dog/5681.jpg
#   inflating: original/PetImages/Dog/5682.jpg
#   inflating: original/PetImages/Dog/5683.jpg
#   inflating: original/PetImages/Dog/5684.jpg
#   inflating: original/PetImages/Dog/5685.jpg
#   inflating: original/PetImages/Dog/5686.jpg
#   inflating: original/PetImages/Dog/5687.jpg
#   inflating: original/PetImages/Dog/5688.jpg
#   inflating: original/PetImages/Dog/5689.jpg
#   inflating: original/PetImages/Dog/569.jpg
#   inflating: original/PetImages/Dog/5690.jpg
#   inflating: original/PetImages/Dog/5691.jpg
#   inflating: original/PetImages/Dog/5692.jpg
#   inflating: original/PetImages/Dog/5693.jpg
#   inflating: original/PetImages/Dog/5694.jpg
#   inflating: original/PetImages/Dog/5695.jpg
#   inflating: original/PetImages/Dog/5696.jpg
#   inflating: original/PetImages/Dog/5697.jpg
#   inflating: original/PetImages/Dog/5698.jpg
#   inflating: original/PetImages/Dog/5699.jpg
#   inflating: original/PetImages/Dog/57.jpg
#   inflating: original/PetImages/Dog/570.jpg
#   inflating: original/PetImages/Dog/5700.jpg
#   inflating: original/PetImages/Dog/5701.jpg
#   inflating: original/PetImages/Dog/5702.jpg
#   inflating: original/PetImages/Dog/5703.jpg
#   inflating: original/PetImages/Dog/5704.jpg
#   inflating: original/PetImages/Dog/5705.jpg
#   inflating: original/PetImages/Dog/5706.jpg
#   inflating: original/PetImages/Dog/5707.jpg
#   inflating: original/PetImages/Dog/5708.jpg
#   inflating: original/PetImages/Dog/5709.jpg
#   inflating: original/PetImages/Dog/571.jpg
#   inflating: original/PetImages/Dog/5710.jpg
#   inflating: original/PetImages/Dog/5711.jpg
#   inflating: original/PetImages/Dog/5712.jpg
#   inflating: original/PetImages/Dog/5713.jpg
#   inflating: original/PetImages/Dog/5714.jpg
#   inflating: original/PetImages/Dog/5715.jpg
#   inflating: original/PetImages/Dog/5716.jpg
#   inflating: original/PetImages/Dog/5717.jpg
#   inflating: original/PetImages/Dog/5718.jpg
#   inflating: original/PetImages/Dog/5719.jpg
#   inflating: original/PetImages/Dog/572.jpg
#   inflating: original/PetImages/Dog/5720.jpg
#   inflating: original/PetImages/Dog/5721.jpg
#   inflating: original/PetImages/Dog/5722.jpg
#   inflating: original/PetImages/Dog/5723.jpg
#   inflating: original/PetImages/Dog/5724.jpg
#   inflating: original/PetImages/Dog/5725.jpg
#   inflating: original/PetImages/Dog/5726.jpg
#   inflating: original/PetImages/Dog/5727.jpg
#   inflating: original/PetImages/Dog/5728.jpg
#   inflating: original/PetImages/Dog/5729.jpg
#   inflating: original/PetImages/Dog/573.jpg
#   inflating: original/PetImages/Dog/5730.jpg
#   inflating: original/PetImages/Dog/5731.jpg
#   inflating: original/PetImages/Dog/5732.jpg
#   inflating: original/PetImages/Dog/5733.jpg
#   inflating: original/PetImages/Dog/5734.jpg
#   inflating: original/PetImages/Dog/5735.jpg
#   inflating: original/PetImages/Dog/5736.jpg
#   inflating: original/PetImages/Dog/5737.jpg
#   inflating: original/PetImages/Dog/5738.jpg
#   inflating: original/PetImages/Dog/5739.jpg
#   inflating: original/PetImages/Dog/574.jpg
#   inflating: original/PetImages/Dog/5740.jpg
#   inflating: original/PetImages/Dog/5741.jpg
#   inflating: original/PetImages/Dog/5742.jpg
#   inflating: original/PetImages/Dog/5743.jpg
#   inflating: original/PetImages/Dog/5744.jpg
#   inflating: original/PetImages/Dog/5745.jpg
#   inflating: original/PetImages/Dog/5746.jpg
#   inflating: original/PetImages/Dog/5747.jpg
#   inflating: original/PetImages/Dog/5748.jpg
#   inflating: original/PetImages/Dog/5749.jpg
#   inflating: original/PetImages/Dog/575.jpg
#   inflating: original/PetImages/Dog/5750.jpg
#   inflating: original/PetImages/Dog/5751.jpg
#   inflating: original/PetImages/Dog/5752.jpg
#   inflating: original/PetImages/Dog/5753.jpg
#   inflating: original/PetImages/Dog/5754.jpg
#   inflating: original/PetImages/Dog/5755.jpg
#   inflating: original/PetImages/Dog/5756.jpg
#   inflating: original/PetImages/Dog/5757.jpg
#   inflating: original/PetImages/Dog/5758.jpg
#   inflating: original/PetImages/Dog/5759.jpg
#   inflating: original/PetImages/Dog/576.jpg
#   inflating: original/PetImages/Dog/5760.jpg
#   inflating: original/PetImages/Dog/5761.jpg
#   inflating: original/PetImages/Dog/5762.jpg
#   inflating: original/PetImages/Dog/5763.jpg
#   inflating: original/PetImages/Dog/5764.jpg
#   inflating: original/PetImages/Dog/5765.jpg
#   inflating: original/PetImages/Dog/5766.jpg
#   inflating: original/PetImages/Dog/5767.jpg
#   inflating: original/PetImages/Dog/5768.jpg
#   inflating: original/PetImages/Dog/5769.jpg
#   inflating: original/PetImages/Dog/577.jpg
#   inflating: original/PetImages/Dog/5770.jpg
#   inflating: original/PetImages/Dog/5771.jpg
#   inflating: original/PetImages/Dog/5772.jpg
#   inflating: original/PetImages/Dog/5773.jpg
#   inflating: original/PetImages/Dog/5774.jpg
#   inflating: original/PetImages/Dog/5775.jpg
#   inflating: original/PetImages/Dog/5776.jpg
#   inflating: original/PetImages/Dog/5777.jpg
#   inflating: original/PetImages/Dog/5778.jpg
#   inflating: original/PetImages/Dog/5779.jpg
#   inflating: original/PetImages/Dog/578.jpg
#   inflating: original/PetImages/Dog/5780.jpg
#   inflating: original/PetImages/Dog/5781.jpg
#   inflating: original/PetImages/Dog/5782.jpg
#   inflating: original/PetImages/Dog/5783.jpg
#   inflating: original/PetImages/Dog/5784.jpg
#   inflating: original/PetImages/Dog/5785.jpg
#   inflating: original/PetImages/Dog/5786.jpg
#   inflating: original/PetImages/Dog/5787.jpg
#   inflating: original/PetImages/Dog/5788.jpg
#   inflating: original/PetImages/Dog/5789.jpg
#   inflating: original/PetImages/Dog/579.jpg
#   inflating: original/PetImages/Dog/5790.jpg
#   inflating: original/PetImages/Dog/5791.jpg
#   inflating: original/PetImages/Dog/5792.jpg
#   inflating: original/PetImages/Dog/5793.jpg
#   inflating: original/PetImages/Dog/5794.jpg
#   inflating: original/PetImages/Dog/5795.jpg
#   inflating: original/PetImages/Dog/5796.jpg
#   inflating: original/PetImages/Dog/5797.jpg
#   inflating: original/PetImages/Dog/5798.jpg
#   inflating: original/PetImages/Dog/5799.jpg
#   inflating: original/PetImages/Dog/58.jpg
#   inflating: original/PetImages/Dog/580.jpg
#   inflating: original/PetImages/Dog/5800.jpg
#   inflating: original/PetImages/Dog/5801.jpg
#   inflating: original/PetImages/Dog/5802.jpg
#   inflating: original/PetImages/Dog/5803.jpg
#   inflating: original/PetImages/Dog/5804.jpg
#   inflating: original/PetImages/Dog/5805.jpg
#   inflating: original/PetImages/Dog/5806.jpg
#   inflating: original/PetImages/Dog/5807.jpg
#   inflating: original/PetImages/Dog/5808.jpg
#   inflating: original/PetImages/Dog/5809.jpg
#   inflating: original/PetImages/Dog/581.jpg
#   inflating: original/PetImages/Dog/5810.jpg
#   inflating: original/PetImages/Dog/5811.jpg
#   inflating: original/PetImages/Dog/5812.jpg
#   inflating: original/PetImages/Dog/5813.jpg
#   inflating: original/PetImages/Dog/5814.jpg
#   inflating: original/PetImages/Dog/5815.jpg
#   inflating: original/PetImages/Dog/5816.jpg
#   inflating: original/PetImages/Dog/5817.jpg
#   inflating: original/PetImages/Dog/5818.jpg
#   inflating: original/PetImages/Dog/5819.jpg
#   inflating: original/PetImages/Dog/582.jpg
#   inflating: original/PetImages/Dog/5820.jpg
#   inflating: original/PetImages/Dog/5821.jpg
#   inflating: original/PetImages/Dog/5822.jpg
#   inflating: original/PetImages/Dog/5823.jpg
#   inflating: original/PetImages/Dog/5824.jpg
#   inflating: original/PetImages/Dog/5825.jpg
#   inflating: original/PetImages/Dog/5826.jpg
#   inflating: original/PetImages/Dog/5827.jpg
#   inflating: original/PetImages/Dog/5828.jpg
#   inflating: original/PetImages/Dog/5829.jpg
#   inflating: original/PetImages/Dog/583.jpg
#   inflating: original/PetImages/Dog/5830.jpg
#   inflating: original/PetImages/Dog/5831.jpg
#   inflating: original/PetImages/Dog/5832.jpg
#   inflating: original/PetImages/Dog/5833.jpg
#   inflating: original/PetImages/Dog/5834.jpg
#   inflating: original/PetImages/Dog/5835.jpg
#   inflating: original/PetImages/Dog/5836.jpg
#   inflating: original/PetImages/Dog/5837.jpg
#   inflating: original/PetImages/Dog/5838.jpg
#   inflating: original/PetImages/Dog/5839.jpg
#   inflating: original/PetImages/Dog/584.jpg
#   inflating: original/PetImages/Dog/5840.jpg
#   inflating: original/PetImages/Dog/5841.jpg
#   inflating: original/PetImages/Dog/5842.jpg
#   inflating: original/PetImages/Dog/5843.jpg
#   inflating: original/PetImages/Dog/5844.jpg
#   inflating: original/PetImages/Dog/5845.jpg
#   inflating: original/PetImages/Dog/5846.jpg
#   inflating: original/PetImages/Dog/5847.jpg
#   inflating: original/PetImages/Dog/5848.jpg
#   inflating: original/PetImages/Dog/5849.jpg
#   inflating: original/PetImages/Dog/585.jpg
#   inflating: original/PetImages/Dog/5850.jpg
#   inflating: original/PetImages/Dog/5851.jpg
#   inflating: original/PetImages/Dog/5852.jpg
#   inflating: original/PetImages/Dog/5853.jpg
#   inflating: original/PetImages/Dog/5854.jpg
#   inflating: original/PetImages/Dog/5855.jpg
#   inflating: original/PetImages/Dog/5856.jpg
#   inflating: original/PetImages/Dog/5857.jpg
#   inflating: original/PetImages/Dog/5858.jpg
#   inflating: original/PetImages/Dog/5859.jpg
#   inflating: original/PetImages/Dog/586.jpg
#   inflating: original/PetImages/Dog/5860.jpg
#   inflating: original/PetImages/Dog/5861.jpg
#   inflating: original/PetImages/Dog/5862.jpg
#   inflating: original/PetImages/Dog/5863.jpg
#   inflating: original/PetImages/Dog/5864.jpg
#   inflating: original/PetImages/Dog/5865.jpg
#   inflating: original/PetImages/Dog/5866.jpg
#   inflating: original/PetImages/Dog/5867.jpg
#   inflating: original/PetImages/Dog/5868.jpg
#   inflating: original/PetImages/Dog/5869.jpg
#   inflating: original/PetImages/Dog/587.jpg
#   inflating: original/PetImages/Dog/5870.jpg
#   inflating: original/PetImages/Dog/5871.jpg
#   inflating: original/PetImages/Dog/5872.jpg
#   inflating: original/PetImages/Dog/5873.jpg
#   inflating: original/PetImages/Dog/5874.jpg
#   inflating: original/PetImages/Dog/5875.jpg
#   inflating: original/PetImages/Dog/5876.jpg
#   inflating: original/PetImages/Dog/5877.jpg
#   inflating: original/PetImages/Dog/5878.jpg
#   inflating: original/PetImages/Dog/5879.jpg
#   inflating: original/PetImages/Dog/588.jpg
#   inflating: original/PetImages/Dog/5880.jpg
#   inflating: original/PetImages/Dog/5881.jpg
#   inflating: original/PetImages/Dog/5882.jpg
#   inflating: original/PetImages/Dog/5883.jpg
#   inflating: original/PetImages/Dog/5884.jpg
#   inflating: original/PetImages/Dog/5885.jpg
#   inflating: original/PetImages/Dog/5886.jpg
#   inflating: original/PetImages/Dog/5887.jpg
#   inflating: original/PetImages/Dog/5888.jpg
#   inflating: original/PetImages/Dog/5889.jpg
#   inflating: original/PetImages/Dog/589.jpg
#   inflating: original/PetImages/Dog/5890.jpg
#   inflating: original/PetImages/Dog/5891.jpg
#   inflating: original/PetImages/Dog/5892.jpg
#   inflating: original/PetImages/Dog/5893.jpg
#   inflating: original/PetImages/Dog/5894.jpg
#   inflating: original/PetImages/Dog/5895.jpg
#   inflating: original/PetImages/Dog/5896.jpg
#   inflating: original/PetImages/Dog/5897.jpg
#   inflating: original/PetImages/Dog/5898.jpg
#   inflating: original/PetImages/Dog/5899.jpg
#   inflating: original/PetImages/Dog/59.jpg
#   inflating: original/PetImages/Dog/590.jpg
#   inflating: original/PetImages/Dog/5900.jpg
#   inflating: original/PetImages/Dog/5901.jpg
#   inflating: original/PetImages/Dog/5902.jpg
#   inflating: original/PetImages/Dog/5903.jpg
#   inflating: original/PetImages/Dog/5904.jpg
#   inflating: original/PetImages/Dog/5905.jpg
#   inflating: original/PetImages/Dog/5906.jpg
#   inflating: original/PetImages/Dog/5907.jpg
#   inflating: original/PetImages/Dog/5908.jpg
#   inflating: original/PetImages/Dog/5909.jpg
#   inflating: original/PetImages/Dog/591.jpg
#   inflating: original/PetImages/Dog/5910.jpg
#   inflating: original/PetImages/Dog/5911.jpg
#   inflating: original/PetImages/Dog/5912.jpg
#   inflating: original/PetImages/Dog/5913.jpg
#   inflating: original/PetImages/Dog/5914.jpg
#   inflating: original/PetImages/Dog/5915.jpg
#   inflating: original/PetImages/Dog/5916.jpg
#   inflating: original/PetImages/Dog/5917.jpg
#   inflating: original/PetImages/Dog/5918.jpg
#   inflating: original/PetImages/Dog/5919.jpg
#   inflating: original/PetImages/Dog/592.jpg
#   inflating: original/PetImages/Dog/5920.jpg
#   inflating: original/PetImages/Dog/5921.jpg
#   inflating: original/PetImages/Dog/5922.jpg
#   inflating: original/PetImages/Dog/5923.jpg
#   inflating: original/PetImages/Dog/5924.jpg
#   inflating: original/PetImages/Dog/5925.jpg
#   inflating: original/PetImages/Dog/5926.jpg
#   inflating: original/PetImages/Dog/5927.jpg
#   inflating: original/PetImages/Dog/5928.jpg
#   inflating: original/PetImages/Dog/5929.jpg
#   inflating: original/PetImages/Dog/593.jpg
#   inflating: original/PetImages/Dog/5930.jpg
#   inflating: original/PetImages/Dog/5931.jpg
#   inflating: original/PetImages/Dog/5932.jpg
#   inflating: original/PetImages/Dog/5933.jpg
#   inflating: original/PetImages/Dog/5934.jpg
#   inflating: original/PetImages/Dog/5935.jpg
#   inflating: original/PetImages/Dog/5936.jpg
#   inflating: original/PetImages/Dog/5937.jpg
#   inflating: original/PetImages/Dog/5938.jpg
#   inflating: original/PetImages/Dog/5939.jpg
#   inflating: original/PetImages/Dog/594.jpg
#   inflating: original/PetImages/Dog/5940.jpg
#   inflating: original/PetImages/Dog/5941.jpg
#   inflating: original/PetImages/Dog/5942.jpg
#   inflating: original/PetImages/Dog/5943.jpg
#   inflating: original/PetImages/Dog/5944.jpg
#   inflating: original/PetImages/Dog/5945.jpg
#   inflating: original/PetImages/Dog/5946.jpg
#   inflating: original/PetImages/Dog/5947.jpg
#   inflating: original/PetImages/Dog/5948.jpg
#   inflating: original/PetImages/Dog/5949.jpg
#   inflating: original/PetImages/Dog/595.jpg
#   inflating: original/PetImages/Dog/5950.jpg
#   inflating: original/PetImages/Dog/5951.jpg
#   inflating: original/PetImages/Dog/5952.jpg
#   inflating: original/PetImages/Dog/5953.jpg
#   inflating: original/PetImages/Dog/5954.jpg
#   inflating: original/PetImages/Dog/5955.jpg
#   inflating: original/PetImages/Dog/5956.jpg
#   inflating: original/PetImages/Dog/5957.jpg
#   inflating: original/PetImages/Dog/5958.jpg
#   inflating: original/PetImages/Dog/5959.jpg
#   inflating: original/PetImages/Dog/596.jpg
#   inflating: original/PetImages/Dog/5960.jpg
#   inflating: original/PetImages/Dog/5961.jpg
#   inflating: original/PetImages/Dog/5962.jpg
#   inflating: original/PetImages/Dog/5963.jpg
#   inflating: original/PetImages/Dog/5964.jpg
#   inflating: original/PetImages/Dog/5965.jpg
#   inflating: original/PetImages/Dog/5966.jpg
#   inflating: original/PetImages/Dog/5967.jpg
#   inflating: original/PetImages/Dog/5968.jpg
#   inflating: original/PetImages/Dog/5969.jpg
#   inflating: original/PetImages/Dog/597.jpg
#   inflating: original/PetImages/Dog/5970.jpg
#   inflating: original/PetImages/Dog/5971.jpg
#   inflating: original/PetImages/Dog/5972.jpg
#   inflating: original/PetImages/Dog/5973.jpg
#   inflating: original/PetImages/Dog/5974.jpg
#   inflating: original/PetImages/Dog/5975.jpg
#   inflating: original/PetImages/Dog/5976.jpg
#   inflating: original/PetImages/Dog/5977.jpg
#   inflating: original/PetImages/Dog/5978.jpg
#   inflating: original/PetImages/Dog/5979.jpg
#   inflating: original/PetImages/Dog/598.jpg
#   inflating: original/PetImages/Dog/5980.jpg
#   inflating: original/PetImages/Dog/5981.jpg
#   inflating: original/PetImages/Dog/5982.jpg
#   inflating: original/PetImages/Dog/5983.jpg
#   inflating: original/PetImages/Dog/5984.jpg
#   inflating: original/PetImages/Dog/5985.jpg
#   inflating: original/PetImages/Dog/5986.jpg
#   inflating: original/PetImages/Dog/5987.jpg
#   inflating: original/PetImages/Dog/5988.jpg
#   inflating: original/PetImages/Dog/5989.jpg
#   inflating: original/PetImages/Dog/599.jpg
#   inflating: original/PetImages/Dog/5990.jpg
#   inflating: original/PetImages/Dog/5991.jpg
#   inflating: original/PetImages/Dog/5992.jpg
#   inflating: original/PetImages/Dog/5993.jpg
#   inflating: original/PetImages/Dog/5994.jpg
#   inflating: original/PetImages/Dog/5995.jpg
#   inflating: original/PetImages/Dog/5996.jpg
#   inflating: original/PetImages/Dog/5997.jpg
#   inflating: original/PetImages/Dog/5998.jpg
#   inflating: original/PetImages/Dog/5999.jpg
#   inflating: original/PetImages/Dog/6.jpg
#   inflating: original/PetImages/Dog/60.jpg
#   inflating: original/PetImages/Dog/600.jpg
#   inflating: original/PetImages/Dog/6000.jpg
#   inflating: original/PetImages/Dog/6001.jpg
#   inflating: original/PetImages/Dog/6002.jpg
#   inflating: original/PetImages/Dog/6003.jpg
#   inflating: original/PetImages/Dog/6004.jpg
#   inflating: original/PetImages/Dog/6005.jpg
#   inflating: original/PetImages/Dog/6006.jpg
#   inflating: original/PetImages/Dog/6007.jpg
#   inflating: original/PetImages/Dog/6008.jpg
#   inflating: original/PetImages/Dog/6009.jpg
#   inflating: original/PetImages/Dog/601.jpg
#   inflating: original/PetImages/Dog/6010.jpg
#   inflating: original/PetImages/Dog/6011.jpg
#   inflating: original/PetImages/Dog/6012.jpg
#   inflating: original/PetImages/Dog/6013.jpg
#   inflating: original/PetImages/Dog/6014.jpg
#   inflating: original/PetImages/Dog/6015.jpg
#   inflating: original/PetImages/Dog/6016.jpg
#   inflating: original/PetImages/Dog/6017.jpg
#   inflating: original/PetImages/Dog/6018.jpg
#   inflating: original/PetImages/Dog/6019.jpg
#   inflating: original/PetImages/Dog/602.jpg
#   inflating: original/PetImages/Dog/6020.jpg
#   inflating: original/PetImages/Dog/6021.jpg
#   inflating: original/PetImages/Dog/6022.jpg
#   inflating: original/PetImages/Dog/6023.jpg
#   inflating: original/PetImages/Dog/6024.jpg
#   inflating: original/PetImages/Dog/6025.jpg
#   inflating: original/PetImages/Dog/6026.jpg
#   inflating: original/PetImages/Dog/6027.jpg
#   inflating: original/PetImages/Dog/6028.jpg
#   inflating: original/PetImages/Dog/6029.jpg
#   inflating: original/PetImages/Dog/603.jpg
#   inflating: original/PetImages/Dog/6030.jpg
#   inflating: original/PetImages/Dog/6031.jpg
#   inflating: original/PetImages/Dog/6032.jpg
#   inflating: original/PetImages/Dog/6033.jpg
#   inflating: original/PetImages/Dog/6034.jpg
#   inflating: original/PetImages/Dog/6035.jpg
#   inflating: original/PetImages/Dog/6036.jpg
#   inflating: original/PetImages/Dog/6037.jpg
#   inflating: original/PetImages/Dog/6038.jpg
#   inflating: original/PetImages/Dog/6039.jpg
#   inflating: original/PetImages/Dog/604.jpg
#   inflating: original/PetImages/Dog/6040.jpg
#   inflating: original/PetImages/Dog/6041.jpg
#   inflating: original/PetImages/Dog/6042.jpg
#   inflating: original/PetImages/Dog/6043.jpg
#   inflating: original/PetImages/Dog/6044.jpg
#   inflating: original/PetImages/Dog/6045.jpg
#   inflating: original/PetImages/Dog/6046.jpg
#   inflating: original/PetImages/Dog/6047.jpg
#   inflating: original/PetImages/Dog/6048.jpg
#   inflating: original/PetImages/Dog/6049.jpg
#   inflating: original/PetImages/Dog/605.jpg
#   inflating: original/PetImages/Dog/6050.jpg
#   inflating: original/PetImages/Dog/6051.jpg
#   inflating: original/PetImages/Dog/6052.jpg
#   inflating: original/PetImages/Dog/6053.jpg
#   inflating: original/PetImages/Dog/6054.jpg
#   inflating: original/PetImages/Dog/6055.jpg
#   inflating: original/PetImages/Dog/6056.jpg
#   inflating: original/PetImages/Dog/6057.jpg
#   inflating: original/PetImages/Dog/6058.jpg
#   inflating: original/PetImages/Dog/6059.jpg
#   inflating: original/PetImages/Dog/606.jpg
#   inflating: original/PetImages/Dog/6060.jpg
#   inflating: original/PetImages/Dog/6061.jpg
#   inflating: original/PetImages/Dog/6062.jpg
#   inflating: original/PetImages/Dog/6063.jpg
#   inflating: original/PetImages/Dog/6064.jpg
#   inflating: original/PetImages/Dog/6065.jpg
#   inflating: original/PetImages/Dog/6066.jpg
#   inflating: original/PetImages/Dog/6067.jpg
#   inflating: original/PetImages/Dog/6068.jpg
#   inflating: original/PetImages/Dog/6069.jpg
#   inflating: original/PetImages/Dog/607.jpg
#   inflating: original/PetImages/Dog/6070.jpg
#   inflating: original/PetImages/Dog/6071.jpg
#   inflating: original/PetImages/Dog/6072.jpg
#   inflating: original/PetImages/Dog/6073.jpg
#   inflating: original/PetImages/Dog/6074.jpg
#   inflating: original/PetImages/Dog/6075.jpg
#   inflating: original/PetImages/Dog/6076.jpg
#   inflating: original/PetImages/Dog/6077.jpg
#   inflating: original/PetImages/Dog/6078.jpg
#   inflating: original/PetImages/Dog/6079.jpg
#   inflating: original/PetImages/Dog/608.jpg
#   inflating: original/PetImages/Dog/6080.jpg
#   inflating: original/PetImages/Dog/6081.jpg
#   inflating: original/PetImages/Dog/6082.jpg
#   inflating: original/PetImages/Dog/6083.jpg
#   inflating: original/PetImages/Dog/6084.jpg
#   inflating: original/PetImages/Dog/6085.jpg
#   inflating: original/PetImages/Dog/6086.jpg
#   inflating: original/PetImages/Dog/6087.jpg
#   inflating: original/PetImages/Dog/6088.jpg
#   inflating: original/PetImages/Dog/6089.jpg
#   inflating: original/PetImages/Dog/609.jpg
#   inflating: original/PetImages/Dog/6090.jpg
#   inflating: original/PetImages/Dog/6091.jpg
#   inflating: original/PetImages/Dog/6092.jpg
#   inflating: original/PetImages/Dog/6093.jpg
#   inflating: original/PetImages/Dog/6094.jpg
#   inflating: original/PetImages/Dog/6095.jpg
#   inflating: original/PetImages/Dog/6096.jpg
#   inflating: original/PetImages/Dog/6097.jpg
#   inflating: original/PetImages/Dog/6098.jpg
#   inflating: original/PetImages/Dog/6099.jpg
#   inflating: original/PetImages/Dog/61.jpg
#   inflating: original/PetImages/Dog/610.jpg
#   inflating: original/PetImages/Dog/6100.jpg
#   inflating: original/PetImages/Dog/6101.jpg
#   inflating: original/PetImages/Dog/6102.jpg
#   inflating: original/PetImages/Dog/6103.jpg
#   inflating: original/PetImages/Dog/6104.jpg
#   inflating: original/PetImages/Dog/6105.jpg
#   inflating: original/PetImages/Dog/6106.jpg
#   inflating: original/PetImages/Dog/6107.jpg
#   inflating: original/PetImages/Dog/6108.jpg
#   inflating: original/PetImages/Dog/6109.jpg
#   inflating: original/PetImages/Dog/611.jpg
#   inflating: original/PetImages/Dog/6110.jpg
#   inflating: original/PetImages/Dog/6111.jpg
#   inflating: original/PetImages/Dog/6112.jpg
#   inflating: original/PetImages/Dog/6113.jpg
#   inflating: original/PetImages/Dog/6114.jpg
#   inflating: original/PetImages/Dog/6115.jpg
#   inflating: original/PetImages/Dog/6116.jpg
#   inflating: original/PetImages/Dog/6117.jpg
#   inflating: original/PetImages/Dog/6118.jpg
#   inflating: original/PetImages/Dog/6119.jpg
#   inflating: original/PetImages/Dog/612.jpg
#   inflating: original/PetImages/Dog/6120.jpg
#   inflating: original/PetImages/Dog/6121.jpg
#   inflating: original/PetImages/Dog/6122.jpg
#   inflating: original/PetImages/Dog/6123.jpg
#   inflating: original/PetImages/Dog/6124.jpg
#   inflating: original/PetImages/Dog/6125.jpg
#   inflating: original/PetImages/Dog/6126.jpg
#   inflating: original/PetImages/Dog/6127.jpg
#   inflating: original/PetImages/Dog/6128.jpg
#   inflating: original/PetImages/Dog/6129.jpg
#   inflating: original/PetImages/Dog/613.jpg
#   inflating: original/PetImages/Dog/6130.jpg
#   inflating: original/PetImages/Dog/6131.jpg
#   inflating: original/PetImages/Dog/6132.jpg
#   inflating: original/PetImages/Dog/6133.jpg
#   inflating: original/PetImages/Dog/6134.jpg
#   inflating: original/PetImages/Dog/6135.jpg
#   inflating: original/PetImages/Dog/6136.jpg
#   inflating: original/PetImages/Dog/6137.jpg
#   inflating: original/PetImages/Dog/6138.jpg
#   inflating: original/PetImages/Dog/6139.jpg
#   inflating: original/PetImages/Dog/614.jpg
#   inflating: original/PetImages/Dog/6140.jpg
#   inflating: original/PetImages/Dog/6141.jpg
#   inflating: original/PetImages/Dog/6142.jpg
#   inflating: original/PetImages/Dog/6143.jpg
#   inflating: original/PetImages/Dog/6144.jpg
#   inflating: original/PetImages/Dog/6145.jpg
#   inflating: original/PetImages/Dog/6146.jpg
#   inflating: original/PetImages/Dog/6147.jpg
#   inflating: original/PetImages/Dog/6148.jpg
#   inflating: original/PetImages/Dog/6149.jpg
#   inflating: original/PetImages/Dog/615.jpg
#   inflating: original/PetImages/Dog/6150.jpg
#   inflating: original/PetImages/Dog/6151.jpg
#   inflating: original/PetImages/Dog/6152.jpg
#   inflating: original/PetImages/Dog/6153.jpg
#   inflating: original/PetImages/Dog/6154.jpg
#   inflating: original/PetImages/Dog/6155.jpg
#   inflating: original/PetImages/Dog/6156.jpg
#   inflating: original/PetImages/Dog/6157.jpg
#   inflating: original/PetImages/Dog/6158.jpg
#   inflating: original/PetImages/Dog/6159.jpg
#   inflating: original/PetImages/Dog/616.jpg
#   inflating: original/PetImages/Dog/6160.jpg
#   inflating: original/PetImages/Dog/6161.jpg
#   inflating: original/PetImages/Dog/6162.jpg
#   inflating: original/PetImages/Dog/6163.jpg
#   inflating: original/PetImages/Dog/6164.jpg
#   inflating: original/PetImages/Dog/6165.jpg
#   inflating: original/PetImages/Dog/6166.jpg
#   inflating: original/PetImages/Dog/6167.jpg
#   inflating: original/PetImages/Dog/6168.jpg
#   inflating: original/PetImages/Dog/6169.jpg
#   inflating: original/PetImages/Dog/617.jpg
#   inflating: original/PetImages/Dog/6170.jpg
#   inflating: original/PetImages/Dog/6171.jpg
#   inflating: original/PetImages/Dog/6172.jpg
#   inflating: original/PetImages/Dog/6173.jpg
#   inflating: original/PetImages/Dog/6174.jpg
#   inflating: original/PetImages/Dog/6175.jpg
#   inflating: original/PetImages/Dog/6176.jpg
#   inflating: original/PetImages/Dog/6177.jpg
#   inflating: original/PetImages/Dog/6178.jpg
#   inflating: original/PetImages/Dog/6179.jpg
#   inflating: original/PetImages/Dog/618.jpg
#   inflating: original/PetImages/Dog/6180.jpg
#   inflating: original/PetImages/Dog/6181.jpg
#   inflating: original/PetImages/Dog/6182.jpg
#   inflating: original/PetImages/Dog/6183.jpg
#   inflating: original/PetImages/Dog/6184.jpg
#   inflating: original/PetImages/Dog/6185.jpg
#   inflating: original/PetImages/Dog/6186.jpg
#   inflating: original/PetImages/Dog/6187.jpg
#   inflating: original/PetImages/Dog/6188.jpg
#   inflating: original/PetImages/Dog/6189.jpg
#   inflating: original/PetImages/Dog/619.jpg
#   inflating: original/PetImages/Dog/6190.jpg
#   inflating: original/PetImages/Dog/6191.jpg
#   inflating: original/PetImages/Dog/6192.jpg
#   inflating: original/PetImages/Dog/6193.jpg
#   inflating: original/PetImages/Dog/6194.jpg
#   inflating: original/PetImages/Dog/6195.jpg
#   inflating: original/PetImages/Dog/6196.jpg
#   inflating: original/PetImages/Dog/6197.jpg
#   inflating: original/PetImages/Dog/6198.jpg
#   inflating: original/PetImages/Dog/6199.jpg
#   inflating: original/PetImages/Dog/62.jpg
#   inflating: original/PetImages/Dog/620.jpg
#   inflating: original/PetImages/Dog/6200.jpg
#   inflating: original/PetImages/Dog/6201.jpg
#   inflating: original/PetImages/Dog/6202.jpg
#   inflating: original/PetImages/Dog/6203.jpg
#   inflating: original/PetImages/Dog/6204.jpg
#   inflating: original/PetImages/Dog/6205.jpg
#   inflating: original/PetImages/Dog/6206.jpg
#   inflating: original/PetImages/Dog/6207.jpg
#   inflating: original/PetImages/Dog/6208.jpg
#   inflating: original/PetImages/Dog/6209.jpg
#   inflating: original/PetImages/Dog/621.jpg
#   inflating: original/PetImages/Dog/6210.jpg
#   inflating: original/PetImages/Dog/6211.jpg
#   inflating: original/PetImages/Dog/6212.jpg
#   inflating: original/PetImages/Dog/6213.jpg
#   inflating: original/PetImages/Dog/6214.jpg
#   inflating: original/PetImages/Dog/6215.jpg
#   inflating: original/PetImages/Dog/6216.jpg
#   inflating: original/PetImages/Dog/6217.jpg
#   inflating: original/PetImages/Dog/6218.jpg
#   inflating: original/PetImages/Dog/6219.jpg
#   inflating: original/PetImages/Dog/622.jpg
#   inflating: original/PetImages/Dog/6220.jpg
#   inflating: original/PetImages/Dog/6221.jpg
#   inflating: original/PetImages/Dog/6222.jpg
#   inflating: original/PetImages/Dog/6223.jpg
#   inflating: original/PetImages/Dog/6224.jpg
#   inflating: original/PetImages/Dog/6225.jpg
#   inflating: original/PetImages/Dog/6226.jpg
#   inflating: original/PetImages/Dog/6227.jpg
#   inflating: original/PetImages/Dog/6228.jpg
#   inflating: original/PetImages/Dog/6229.jpg
#   inflating: original/PetImages/Dog/623.jpg
#   inflating: original/PetImages/Dog/6230.jpg
#   inflating: original/PetImages/Dog/6231.jpg
#   inflating: original/PetImages/Dog/6232.jpg
#   inflating: original/PetImages/Dog/6233.jpg
#   inflating: original/PetImages/Dog/6234.jpg
#   inflating: original/PetImages/Dog/6235.jpg
#   inflating: original/PetImages/Dog/6236.jpg
#   inflating: original/PetImages/Dog/6237.jpg
#   inflating: original/PetImages/Dog/6238.jpg
#   inflating: original/PetImages/Dog/6239.jpg
#   inflating: original/PetImages/Dog/624.jpg
#   inflating: original/PetImages/Dog/6240.jpg
#   inflating: original/PetImages/Dog/6241.jpg
#   inflating: original/PetImages/Dog/6242.jpg
#   inflating: original/PetImages/Dog/6243.jpg
#   inflating: original/PetImages/Dog/6244.jpg
#   inflating: original/PetImages/Dog/6245.jpg
#   inflating: original/PetImages/Dog/6246.jpg
#   inflating: original/PetImages/Dog/6247.jpg
#   inflating: original/PetImages/Dog/6248.jpg
#   inflating: original/PetImages/Dog/6249.jpg
#   inflating: original/PetImages/Dog/625.jpg
#   inflating: original/PetImages/Dog/6250.jpg
#   inflating: original/PetImages/Dog/6251.jpg
#   inflating: original/PetImages/Dog/6252.jpg
#   inflating: original/PetImages/Dog/6253.jpg
#   inflating: original/PetImages/Dog/6254.jpg
#   inflating: original/PetImages/Dog/6255.jpg
#   inflating: original/PetImages/Dog/6256.jpg
#   inflating: original/PetImages/Dog/6257.jpg
#   inflating: original/PetImages/Dog/6258.jpg
#   inflating: original/PetImages/Dog/6259.jpg
#   inflating: original/PetImages/Dog/626.jpg
#   inflating: original/PetImages/Dog/6260.jpg
#   inflating: original/PetImages/Dog/6261.jpg
#   inflating: original/PetImages/Dog/6262.jpg
#   inflating: original/PetImages/Dog/6263.jpg
#   inflating: original/PetImages/Dog/6264.jpg
#   inflating: original/PetImages/Dog/6265.jpg
#   inflating: original/PetImages/Dog/6266.jpg
#   inflating: original/PetImages/Dog/6267.jpg
#   inflating: original/PetImages/Dog/6268.jpg
#   inflating: original/PetImages/Dog/6269.jpg
#   inflating: original/PetImages/Dog/627.jpg
#   inflating: original/PetImages/Dog/6270.jpg
#   inflating: original/PetImages/Dog/6271.jpg
#   inflating: original/PetImages/Dog/6272.jpg
#   inflating: original/PetImages/Dog/6273.jpg
#   inflating: original/PetImages/Dog/6274.jpg
#   inflating: original/PetImages/Dog/6275.jpg
#   inflating: original/PetImages/Dog/6276.jpg
#   inflating: original/PetImages/Dog/6277.jpg
#   inflating: original/PetImages/Dog/6278.jpg
#   inflating: original/PetImages/Dog/6279.jpg
#   inflating: original/PetImages/Dog/628.jpg
#   inflating: original/PetImages/Dog/6280.jpg
#   inflating: original/PetImages/Dog/6281.jpg
#   inflating: original/PetImages/Dog/6282.jpg
#   inflating: original/PetImages/Dog/6283.jpg
#   inflating: original/PetImages/Dog/6284.jpg
#   inflating: original/PetImages/Dog/6285.jpg
#   inflating: original/PetImages/Dog/6286.jpg
#   inflating: original/PetImages/Dog/6287.jpg
#   inflating: original/PetImages/Dog/6288.jpg
#   inflating: original/PetImages/Dog/6289.jpg
#   inflating: original/PetImages/Dog/629.jpg
#   inflating: original/PetImages/Dog/6290.jpg
#   inflating: original/PetImages/Dog/6291.jpg
#   inflating: original/PetImages/Dog/6292.jpg
#   inflating: original/PetImages/Dog/6293.jpg
#   inflating: original/PetImages/Dog/6294.jpg
#   inflating: original/PetImages/Dog/6295.jpg
#   inflating: original/PetImages/Dog/6296.jpg
#   inflating: original/PetImages/Dog/6297.jpg
#   inflating: original/PetImages/Dog/6298.jpg
#   inflating: original/PetImages/Dog/6299.jpg
#   inflating: original/PetImages/Dog/63.jpg
#   inflating: original/PetImages/Dog/630.jpg
#   inflating: original/PetImages/Dog/6300.jpg
#   inflating: original/PetImages/Dog/6301.jpg
#   inflating: original/PetImages/Dog/6302.jpg
#   inflating: original/PetImages/Dog/6303.jpg
#   inflating: original/PetImages/Dog/6304.jpg
#   inflating: original/PetImages/Dog/6305.jpg
#   inflating: original/PetImages/Dog/6306.jpg
#   inflating: original/PetImages/Dog/6307.jpg
#   inflating: original/PetImages/Dog/6308.jpg
#   inflating: original/PetImages/Dog/6309.jpg
#   inflating: original/PetImages/Dog/631.jpg
#   inflating: original/PetImages/Dog/6310.jpg
#   inflating: original/PetImages/Dog/6311.jpg
#   inflating: original/PetImages/Dog/6312.jpg
#   inflating: original/PetImages/Dog/6313.jpg
#   inflating: original/PetImages/Dog/6314.jpg
#   inflating: original/PetImages/Dog/6315.jpg
#   inflating: original/PetImages/Dog/6316.jpg
#   inflating: original/PetImages/Dog/6317.jpg
#   inflating: original/PetImages/Dog/6318.jpg
#   inflating: original/PetImages/Dog/6319.jpg
#   inflating: original/PetImages/Dog/632.jpg
#   inflating: original/PetImages/Dog/6320.jpg
#   inflating: original/PetImages/Dog/6321.jpg
#   inflating: original/PetImages/Dog/6322.jpg
#   inflating: original/PetImages/Dog/6323.jpg
#   inflating: original/PetImages/Dog/6324.jpg
#   inflating: original/PetImages/Dog/6325.jpg
#   inflating: original/PetImages/Dog/6326.jpg
#   inflating: original/PetImages/Dog/6327.jpg
#   inflating: original/PetImages/Dog/6328.jpg
#   inflating: original/PetImages/Dog/6329.jpg
#   inflating: original/PetImages/Dog/633.jpg
#   inflating: original/PetImages/Dog/6330.jpg
#   inflating: original/PetImages/Dog/6331.jpg
#   inflating: original/PetImages/Dog/6332.jpg
#   inflating: original/PetImages/Dog/6333.jpg
#   inflating: original/PetImages/Dog/6334.jpg
#   inflating: original/PetImages/Dog/6335.jpg
#   inflating: original/PetImages/Dog/6336.jpg
#   inflating: original/PetImages/Dog/6337.jpg
#   inflating: original/PetImages/Dog/6338.jpg
#   inflating: original/PetImages/Dog/6339.jpg
#   inflating: original/PetImages/Dog/634.jpg
#   inflating: original/PetImages/Dog/6340.jpg
#   inflating: original/PetImages/Dog/6341.jpg
#   inflating: original/PetImages/Dog/6342.jpg
#   inflating: original/PetImages/Dog/6343.jpg
#   inflating: original/PetImages/Dog/6344.jpg
#   inflating: original/PetImages/Dog/6345.jpg
#   inflating: original/PetImages/Dog/6346.jpg
#   inflating: original/PetImages/Dog/6347.jpg
#   inflating: original/PetImages/Dog/6348.jpg
#   inflating: original/PetImages/Dog/6349.jpg
#   inflating: original/PetImages/Dog/635.jpg
#   inflating: original/PetImages/Dog/6350.jpg
#   inflating: original/PetImages/Dog/6351.jpg
#   inflating: original/PetImages/Dog/6352.jpg
#   inflating: original/PetImages/Dog/6353.jpg
#   inflating: original/PetImages/Dog/6354.jpg
#   inflating: original/PetImages/Dog/6355.jpg
#   inflating: original/PetImages/Dog/6356.jpg
#   inflating: original/PetImages/Dog/6357.jpg
#   inflating: original/PetImages/Dog/6358.jpg
#   inflating: original/PetImages/Dog/6359.jpg
#   inflating: original/PetImages/Dog/636.jpg
#   inflating: original/PetImages/Dog/6360.jpg
#   inflating: original/PetImages/Dog/6361.jpg
#   inflating: original/PetImages/Dog/6362.jpg
#   inflating: original/PetImages/Dog/6363.jpg
#   inflating: original/PetImages/Dog/6364.jpg
#   inflating: original/PetImages/Dog/6365.jpg
#   inflating: original/PetImages/Dog/6366.jpg
#   inflating: original/PetImages/Dog/6367.jpg
#   inflating: original/PetImages/Dog/6368.jpg
#   inflating: original/PetImages/Dog/6369.jpg
#   inflating: original/PetImages/Dog/637.jpg
#   inflating: original/PetImages/Dog/6370.jpg
#   inflating: original/PetImages/Dog/6371.jpg
#   inflating: original/PetImages/Dog/6372.jpg
#   inflating: original/PetImages/Dog/6373.jpg
#   inflating: original/PetImages/Dog/6374.jpg
#   inflating: original/PetImages/Dog/6375.jpg
#   inflating: original/PetImages/Dog/6376.jpg
#   inflating: original/PetImages/Dog/6377.jpg
#   inflating: original/PetImages/Dog/6378.jpg
#   inflating: original/PetImages/Dog/6379.jpg
#   inflating: original/PetImages/Dog/638.jpg
#   inflating: original/PetImages/Dog/6380.jpg
#   inflating: original/PetImages/Dog/6381.jpg
#   inflating: original/PetImages/Dog/6382.jpg
#   inflating: original/PetImages/Dog/6383.jpg
#   inflating: original/PetImages/Dog/6384.jpg
#   inflating: original/PetImages/Dog/6385.jpg
#   inflating: original/PetImages/Dog/6386.jpg
#   inflating: original/PetImages/Dog/6387.jpg
#   inflating: original/PetImages/Dog/6388.jpg
#   inflating: original/PetImages/Dog/6389.jpg
#   inflating: original/PetImages/Dog/639.jpg
#   inflating: original/PetImages/Dog/6390.jpg
#   inflating: original/PetImages/Dog/6391.jpg
#   inflating: original/PetImages/Dog/6392.jpg
#   inflating: original/PetImages/Dog/6393.jpg
#   inflating: original/PetImages/Dog/6394.jpg
#   inflating: original/PetImages/Dog/6395.jpg
#   inflating: original/PetImages/Dog/6396.jpg
#   inflating: original/PetImages/Dog/6397.jpg
#   inflating: original/PetImages/Dog/6398.jpg
#   inflating: original/PetImages/Dog/6399.jpg
#   inflating: original/PetImages/Dog/64.jpg
#   inflating: original/PetImages/Dog/640.jpg
#   inflating: original/PetImages/Dog/6400.jpg
#   inflating: original/PetImages/Dog/6401.jpg
#   inflating: original/PetImages/Dog/6402.jpg
#   inflating: original/PetImages/Dog/6403.jpg
#   inflating: original/PetImages/Dog/6404.jpg
#   inflating: original/PetImages/Dog/6405.jpg
#   inflating: original/PetImages/Dog/6406.jpg
#   inflating: original/PetImages/Dog/6407.jpg
#   inflating: original/PetImages/Dog/6408.jpg
#   inflating: original/PetImages/Dog/6409.jpg
#   inflating: original/PetImages/Dog/641.jpg
#   inflating: original/PetImages/Dog/6410.jpg
#   inflating: original/PetImages/Dog/6411.jpg
#   inflating: original/PetImages/Dog/6412.jpg
#   inflating: original/PetImages/Dog/6413.jpg
#   inflating: original/PetImages/Dog/6414.jpg
#   inflating: original/PetImages/Dog/6415.jpg
#   inflating: original/PetImages/Dog/6416.jpg
#   inflating: original/PetImages/Dog/6417.jpg
#   inflating: original/PetImages/Dog/6418.jpg
#   inflating: original/PetImages/Dog/6419.jpg
#   inflating: original/PetImages/Dog/642.jpg
# ...
#   inflating: original/PetImages/Dog/9695.jpg
#   inflating: original/PetImages/Dog/9696.jpg
#   inflating: original/PetImages/Dog/9697.jpg
#   inflating: original/PetImages/Dog/9698.jpg
#   inflating: original/PetImages/Dog/9699.jpg
#   inflating: original/PetImages/Dog/97.jpg
#   inflating: original/PetImages/Dog/970.jpg
#   inflating: original/PetImages/Dog/9700.jpg
#   inflating: original/PetImages/Dog/9701.jpg
#   inflating: original/PetImages/Dog/9702.jpg
#   inflating: original/PetImages/Dog/9703.jpg
#   inflating: original/PetImages/Dog/9704.jpg
#   inflating: original/PetImages/Dog/9705.jpg
#   inflating: original/PetImages/Dog/9706.jpg
#   inflating: original/PetImages/Dog/9707.jpg
#   inflating: original/PetImages/Dog/9708.jpg
#   inflating: original/PetImages/Dog/9709.jpg
#   inflating: original/PetImages/Dog/971.jpg
#   inflating: original/PetImages/Dog/9710.jpg
#   inflating: original/PetImages/Dog/9711.jpg
#   inflating: original/PetImages/Dog/9712.jpg
#   inflating: original/PetImages/Dog/9713.jpg
#   inflating: original/PetImages/Dog/9714.jpg
#   inflating: original/PetImages/Dog/9715.jpg
#   inflating: original/PetImages/Dog/9716.jpg
#   inflating: original/PetImages/Dog/9717.jpg
#   inflating: original/PetImages/Dog/9718.jpg
#   inflating: original/PetImages/Dog/9719.jpg
#   inflating: original/PetImages/Dog/972.jpg
#   inflating: original/PetImages/Dog/9720.jpg
#   inflating: original/PetImages/Dog/9721.jpg
#   inflating: original/PetImages/Dog/9722.jpg
#   inflating: original/PetImages/Dog/9723.jpg
#   inflating: original/PetImages/Dog/9724.jpg
#   inflating: original/PetImages/Dog/9725.jpg
#   inflating: original/PetImages/Dog/9726.jpg
#   inflating: original/PetImages/Dog/9727.jpg
#   inflating: original/PetImages/Dog/9728.jpg
#   inflating: original/PetImages/Dog/9729.jpg
#   inflating: original/PetImages/Dog/973.jpg
#   inflating: original/PetImages/Dog/9730.jpg
#   inflating: original/PetImages/Dog/9731.jpg
#   inflating: original/PetImages/Dog/9732.jpg
#   inflating: original/PetImages/Dog/9733.jpg
#   inflating: original/PetImages/Dog/9734.jpg
#   inflating: original/PetImages/Dog/9735.jpg
#   inflating: original/PetImages/Dog/9736.jpg
#   inflating: original/PetImages/Dog/9737.jpg
#   inflating: original/PetImages/Dog/9738.jpg
#   inflating: original/PetImages/Dog/9739.jpg
#   inflating: original/PetImages/Dog/974.jpg
#   inflating: original/PetImages/Dog/9740.jpg
#   inflating: original/PetImages/Dog/9741.jpg
#   inflating: original/PetImages/Dog/9742.jpg
#   inflating: original/PetImages/Dog/9743.jpg
#   inflating: original/PetImages/Dog/9744.jpg
#   inflating: original/PetImages/Dog/9745.jpg
#   inflating: original/PetImages/Dog/9746.jpg
#   inflating: original/PetImages/Dog/9747.jpg
#   inflating: original/PetImages/Dog/9748.jpg
#   inflating: original/PetImages/Dog/9749.jpg
#   inflating: original/PetImages/Dog/975.jpg
#   inflating: original/PetImages/Dog/9750.jpg
#   inflating: original/PetImages/Dog/9751.jpg
#   inflating: original/PetImages/Dog/9752.jpg
#   inflating: original/PetImages/Dog/9753.jpg
#   inflating: original/PetImages/Dog/9754.jpg
#   inflating: original/PetImages/Dog/9755.jpg
#   inflating: original/PetImages/Dog/9756.jpg
#   inflating: original/PetImages/Dog/9757.jpg
#   inflating: original/PetImages/Dog/9758.jpg
#   inflating: original/PetImages/Dog/9759.jpg
#   inflating: original/PetImages/Dog/976.jpg
#   inflating: original/PetImages/Dog/9760.jpg
#   inflating: original/PetImages/Dog/9761.jpg
#   inflating: original/PetImages/Dog/9762.jpg
#   inflating: original/PetImages/Dog/9763.jpg
#   inflating: original/PetImages/Dog/9764.jpg
#   inflating: original/PetImages/Dog/9765.jpg
#   inflating: original/PetImages/Dog/9766.jpg
#   inflating: original/PetImages/Dog/9767.jpg
#   inflating: original/PetImages/Dog/9768.jpg
#   inflating: original/PetImages/Dog/9769.jpg
#   inflating: original/PetImages/Dog/977.jpg
#   inflating: original/PetImages/Dog/9770.jpg
#   inflating: original/PetImages/Dog/9771.jpg
#   inflating: original/PetImages/Dog/9772.jpg
#   inflating: original/PetImages/Dog/9773.jpg
#   inflating: original/PetImages/Dog/9774.jpg
#   inflating: original/PetImages/Dog/9775.jpg
#   inflating: original/PetImages/Dog/9776.jpg
#   inflating: original/PetImages/Dog/9777.jpg
#   inflating: original/PetImages/Dog/9778.jpg
#   inflating: original/PetImages/Dog/9779.jpg
#   inflating: original/PetImages/Dog/978.jpg
#   inflating: original/PetImages/Dog/9780.jpg
#   inflating: original/PetImages/Dog/9781.jpg
#   inflating: original/PetImages/Dog/9782.jpg
#   inflating: original/PetImages/Dog/9783.jpg
#   inflating: original/PetImages/Dog/9784.jpg
#   inflating: original/PetImages/Dog/9785.jpg
#   inflating: original/PetImages/Dog/9786.jpg
#   inflating: original/PetImages/Dog/9787.jpg
#   inflating: original/PetImages/Dog/9788.jpg
#   inflating: original/PetImages/Dog/9789.jpg
#   inflating: original/PetImages/Dog/979.jpg
#   inflating: original/PetImages/Dog/9790.jpg
#   inflating: original/PetImages/Dog/9791.jpg
#   inflating: original/PetImages/Dog/9792.jpg
#   inflating: original/PetImages/Dog/9793.jpg
#   inflating: original/PetImages/Dog/9794.jpg
#   inflating: original/PetImages/Dog/9795.jpg
#   inflating: original/PetImages/Dog/9796.jpg
#   inflating: original/PetImages/Dog/9797.jpg
#   inflating: original/PetImages/Dog/9798.jpg
#   inflating: original/PetImages/Dog/9799.jpg
#   inflating: original/PetImages/Dog/98.jpg
#   inflating: original/PetImages/Dog/980.jpg
#   inflating: original/PetImages/Dog/9800.jpg
#   inflating: original/PetImages/Dog/9801.jpg
#   inflating: original/PetImages/Dog/9802.jpg
#   inflating: original/PetImages/Dog/9803.jpg
#   inflating: original/PetImages/Dog/9804.jpg
#   inflating: original/PetImages/Dog/9805.jpg
#   inflating: original/PetImages/Dog/9806.jpg
#   inflating: original/PetImages/Dog/9807.jpg
#   inflating: original/PetImages/Dog/9808.jpg
#   inflating: original/PetImages/Dog/9809.jpg
#   inflating: original/PetImages/Dog/981.jpg
#   inflating: original/PetImages/Dog/9810.jpg
#   inflating: original/PetImages/Dog/9811.jpg
#   inflating: original/PetImages/Dog/9812.jpg
#   inflating: original/PetImages/Dog/9813.jpg
#   inflating: original/PetImages/Dog/9814.jpg
#   inflating: original/PetImages/Dog/9815.jpg
#   inflating: original/PetImages/Dog/9816.jpg
#   inflating: original/PetImages/Dog/9817.jpg
#   inflating: original/PetImages/Dog/9818.jpg
#   inflating: original/PetImages/Dog/9819.jpg
#   inflating: original/PetImages/Dog/982.jpg
#   inflating: original/PetImages/Dog/9820.jpg
#   inflating: original/PetImages/Dog/9821.jpg
#   inflating: original/PetImages/Dog/9822.jpg
#   inflating: original/PetImages/Dog/9823.jpg
#   inflating: original/PetImages/Dog/9824.jpg
#   inflating: original/PetImages/Dog/9825.jpg
#   inflating: original/PetImages/Dog/9826.jpg
#   inflating: original/PetImages/Dog/9827.jpg
#   inflating: original/PetImages/Dog/9828.jpg
#   inflating: original/PetImages/Dog/9829.jpg
#   inflating: original/PetImages/Dog/983.jpg
#   inflating: original/PetImages/Dog/9830.jpg
#   inflating: original/PetImages/Dog/9831.jpg
#   inflating: original/PetImages/Dog/9832.jpg
#   inflating: original/PetImages/Dog/9833.jpg
#   inflating: original/PetImages/Dog/9834.jpg
#   inflating: original/PetImages/Dog/9835.jpg
#   inflating: original/PetImages/Dog/9836.jpg
#   inflating: original/PetImages/Dog/9837.jpg
#   inflating: original/PetImages/Dog/9838.jpg
#   inflating: original/PetImages/Dog/9839.jpg
#   inflating: original/PetImages/Dog/984.jpg
#   inflating: original/PetImages/Dog/9840.jpg
#   inflating: original/PetImages/Dog/9841.jpg
#   inflating: original/PetImages/Dog/9842.jpg
#   inflating: original/PetImages/Dog/9843.jpg
#   inflating: original/PetImages/Dog/9844.jpg
#   inflating: original/PetImages/Dog/9845.jpg
#   inflating: original/PetImages/Dog/9846.jpg
#   inflating: original/PetImages/Dog/9847.jpg
#   inflating: original/PetImages/Dog/9848.jpg
#   inflating: original/PetImages/Dog/9849.jpg
#   inflating: original/PetImages/Dog/985.jpg
#   inflating: original/PetImages/Dog/9850.jpg
#   inflating: original/PetImages/Dog/9851.jpg
#   inflating: original/PetImages/Dog/9852.jpg
#   inflating: original/PetImages/Dog/9853.jpg
#   inflating: original/PetImages/Dog/9854.jpg
#   inflating: original/PetImages/Dog/9855.jpg
#   inflating: original/PetImages/Dog/9856.jpg
#   inflating: original/PetImages/Dog/9857.jpg
#   inflating: original/PetImages/Dog/9858.jpg
#   inflating: original/PetImages/Dog/9859.jpg
#   inflating: original/PetImages/Dog/986.jpg
#   inflating: original/PetImages/Dog/9860.jpg
#   inflating: original/PetImages/Dog/9861.jpg
#   inflating: original/PetImages/Dog/9862.jpg
#   inflating: original/PetImages/Dog/9863.jpg
#   inflating: original/PetImages/Dog/9864.jpg
#   inflating: original/PetImages/Dog/9865.jpg
#   inflating: original/PetImages/Dog/9866.jpg
#   inflating: original/PetImages/Dog/9867.jpg
#   inflating: original/PetImages/Dog/9868.jpg
#   inflating: original/PetImages/Dog/9869.jpg
#   inflating: original/PetImages/Dog/987.jpg
#   inflating: original/PetImages/Dog/9870.jpg
#   inflating: original/PetImages/Dog/9871.jpg
#   inflating: original/PetImages/Dog/9872.jpg
#   inflating: original/PetImages/Dog/9873.jpg
#   inflating: original/PetImages/Dog/9874.jpg
#   inflating: original/PetImages/Dog/9875.jpg
#   inflating: original/PetImages/Dog/9876.jpg
#   inflating: original/PetImages/Dog/9877.jpg
#   inflating: original/PetImages/Dog/9878.jpg
#   inflating: original/PetImages/Dog/9879.jpg
#   inflating: original/PetImages/Dog/988.jpg
#   inflating: original/PetImages/Dog/9880.jpg
#   inflating: original/PetImages/Dog/9881.jpg
#   inflating: original/PetImages/Dog/9882.jpg
#   inflating: original/PetImages/Dog/9883.jpg
#   inflating: original/PetImages/Dog/9884.jpg
#   inflating: original/PetImages/Dog/9885.jpg
#   inflating: original/PetImages/Dog/9886.jpg
#   inflating: original/PetImages/Dog/9887.jpg
#   inflating: original/PetImages/Dog/9888.jpg
#   inflating: original/PetImages/Dog/9889.jpg
#   inflating: original/PetImages/Dog/989.jpg
#   inflating: original/PetImages/Dog/9890.jpg
#   inflating: original/PetImages/Dog/9891.jpg
#   inflating: original/PetImages/Dog/9892.jpg
#   inflating: original/PetImages/Dog/9893.jpg
#   inflating: original/PetImages/Dog/9894.jpg
#   inflating: original/PetImages/Dog/9895.jpg
#   inflating: original/PetImages/Dog/9896.jpg
#   inflating: original/PetImages/Dog/9897.jpg
#   inflating: original/PetImages/Dog/9898.jpg
#   inflating: original/PetImages/Dog/9899.jpg
#   inflating: original/PetImages/Dog/99.jpg
#   inflating: original/PetImages/Dog/990.jpg
#   inflating: original/PetImages/Dog/9900.jpg
#   inflating: original/PetImages/Dog/9901.jpg
#   inflating: original/PetImages/Dog/9902.jpg
#   inflating: original/PetImages/Dog/9903.jpg
#   inflating: original/PetImages/Dog/9904.jpg
#   inflating: original/PetImages/Dog/9905.jpg
#   inflating: original/PetImages/Dog/9906.jpg
#   inflating: original/PetImages/Dog/9907.jpg
#   inflating: original/PetImages/Dog/9908.jpg
#   inflating: original/PetImages/Dog/9909.jpg
#   inflating: original/PetImages/Dog/991.jpg
#   inflating: original/PetImages/Dog/9910.jpg
#   inflating: original/PetImages/Dog/9911.jpg
#   inflating: original/PetImages/Dog/9912.jpg
#   inflating: original/PetImages/Dog/9913.jpg
#   inflating: original/PetImages/Dog/9914.jpg
#   inflating: original/PetImages/Dog/9915.jpg
#   inflating: original/PetImages/Dog/9916.jpg
#   inflating: original/PetImages/Dog/9917.jpg
#   inflating: original/PetImages/Dog/9918.jpg
#   inflating: original/PetImages/Dog/9919.jpg
#   inflating: original/PetImages/Dog/992.jpg
#   inflating: original/PetImages/Dog/9920.jpg
#   inflating: original/PetImages/Dog/9921.jpg
#   inflating: original/PetImages/Dog/9922.jpg
#   inflating: original/PetImages/Dog/9923.jpg
#   inflating: original/PetImages/Dog/9924.jpg
#   inflating: original/PetImages/Dog/9925.jpg
#   inflating: original/PetImages/Dog/9926.jpg
#   inflating: original/PetImages/Dog/9927.jpg
#   inflating: original/PetImages/Dog/9928.jpg
#   inflating: original/PetImages/Dog/9929.jpg
#   inflating: original/PetImages/Dog/993.jpg
#   inflating: original/PetImages/Dog/9930.jpg
#   inflating: original/PetImages/Dog/9931.jpg
#   inflating: original/PetImages/Dog/9932.jpg
#   inflating: original/PetImages/Dog/9933.jpg
#   inflating: original/PetImages/Dog/9934.jpg
#   inflating: original/PetImages/Dog/9935.jpg
#   inflating: original/PetImages/Dog/9936.jpg
#   inflating: original/PetImages/Dog/9937.jpg
#   inflating: original/PetImages/Dog/9938.jpg
#   inflating: original/PetImages/Dog/9939.jpg
#   inflating: original/PetImages/Dog/994.jpg
#   inflating: original/PetImages/Dog/9940.jpg
#   inflating: original/PetImages/Dog/9941.jpg
#   inflating: original/PetImages/Dog/9942.jpg
#   inflating: original/PetImages/Dog/9943.jpg
#   inflating: original/PetImages/Dog/9944.jpg
#   inflating: original/PetImages/Dog/9945.jpg
#   inflating: original/PetImages/Dog/9946.jpg
#   inflating: original/PetImages/Dog/9947.jpg
#   inflating: original/PetImages/Dog/9948.jpg
#   inflating: original/PetImages/Dog/9949.jpg
#   inflating: original/PetImages/Dog/995.jpg
#   inflating: original/PetImages/Dog/9950.jpg
#   inflating: original/PetImages/Dog/9951.jpg
#   inflating: original/PetImages/Dog/9952.jpg
#   inflating: original/PetImages/Dog/9953.jpg
#   inflating: original/PetImages/Dog/9954.jpg
#   inflating: original/PetImages/Dog/9955.jpg
#   inflating: original/PetImages/Dog/9956.jpg
#   inflating: original/PetImages/Dog/9957.jpg
#   inflating: original/PetImages/Dog/9958.jpg
#   inflating: original/PetImages/Dog/9959.jpg
#   inflating: original/PetImages/Dog/996.jpg
#   inflating: original/PetImages/Dog/9960.jpg
#   inflating: original/PetImages/Dog/9961.jpg
#   inflating: original/PetImages/Dog/9962.jpg
#   inflating: original/PetImages/Dog/9963.jpg
#   inflating: original/PetImages/Dog/9964.jpg
#   inflating: original/PetImages/Dog/9965.jpg
#   inflating: original/PetImages/Dog/9966.jpg
#   inflating: original/PetImages/Dog/9967.jpg
#   inflating: original/PetImages/Dog/9968.jpg
#   inflating: original/PetImages/Dog/9969.jpg
#   inflating: original/PetImages/Dog/997.jpg
#   inflating: original/PetImages/Dog/9970.jpg
#   inflating: original/PetImages/Dog/9971.jpg
#   inflating: original/PetImages/Dog/9972.jpg
#   inflating: original/PetImages/Dog/9973.jpg
#   inflating: original/PetImages/Dog/9974.jpg
#   inflating: original/PetImages/Dog/9975.jpg
#   inflating: original/PetImages/Dog/9976.jpg
#   inflating: original/PetImages/Dog/9977.jpg
#   inflating: original/PetImages/Dog/9978.jpg
#   inflating: original/PetImages/Dog/9979.jpg
#   inflating: original/PetImages/Dog/998.jpg
#   inflating: original/PetImages/Dog/9980.jpg
#   inflating: original/PetImages/Dog/9981.jpg
#   inflating: original/PetImages/Dog/9982.jpg
#   inflating: original/PetImages/Dog/9983.jpg
#   inflating: original/PetImages/Dog/9984.jpg
#   inflating: original/PetImages/Dog/9985.jpg
#   inflating: original/PetImages/Dog/9986.jpg
#   inflating: original/PetImages/Dog/9987.jpg
#   inflating: original/PetImages/Dog/9988.jpg
#   inflating: original/PetImages/Dog/9989.jpg
#   inflating: original/PetImages/Dog/999.jpg
#   inflating: original/PetImages/Dog/9990.jpg
#   inflating: original/PetImages/Dog/9991.jpg
#   inflating: original/PetImages/Dog/9992.jpg
#   inflating: original/PetImages/Dog/9993.jpg
#   inflating: original/PetImages/Dog/9994.jpg
#   inflating: original/PetImages/Dog/9995.jpg
#   inflating: original/PetImages/Dog/9996.jpg
#   inflating: original/PetImages/Dog/9997.jpg
#   inflating: original/PetImages/Dog/9998.jpg
#   inflating: original/PetImages/Dog/9999.jpg
#   inflating: original/PetImages/Dog/Thumbs.db
#   inflating: original/readme[1].txt
#   inflating: original/CDLA-Permissive-2.0.pdf

# %% [markdown]
# Se ha descargado el archivo ZIP y al descomprimirlo, todo queda en el directorio **PetImages**, dentro del cual hay dos subdirectorios **Cat** y **Dog** con imágenes.

# %%
os.remove("/content/original/PetImages/Cat/Thumbs.db")
os.remove("/content/original/PetImages/Dog/Thumbs.db")
os.remove("/content/original/PetImages/Dog/9041.jpg") # imagen corrupta

# %% [markdown]
# Veamos cuántas imágenes de cada categoría hay.

# %%
cats = glob.glob(f"{original_dataset_cats_dir}/*.jpg")
dogs = glob.glob(f"{original_dataset_dogs_dir}/*.jpg")

# %%
print('Total cat images:', len(cats))
print('Total dog images:', len(dogs))
# Out:
# Total cat images: 12500
# Total dog images: 12499

# %% [markdown]
# Veamos un poco las imágenes que vamos a estar analizando (8 de gatos, 8 de perros)

# %%
nrows = 4
ncols = 4
images_per_class = 8

fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

next_cat_pix = cats[:images_per_class]
next_dog_pix = dogs[:images_per_class]

for i, img_path in enumerate(next_cat_pix+next_dog_pix):
    sp = plt.subplot(nrows, ncols, i + 1)
    sp.axis('Off') # Don't show axes (or gridlines)
    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %% [markdown]
# Vale la pena notar que así tengamos perros y gatos como únicas dos clases, dentro de cada una de las clases vemos gran diversidad de colores, formas y tamaños de animales.

# %% [markdown]
# Vamos a crear una estructura de directorios (train, test), cada uno con dos subdirectorios (cats, dogs) con las imágenes correspondientes.
# Comenzamos por crear la estructura de directorios.

# %%
TRAIN_DIR = os.path.join(base_dir, 'train')
TEST_DIR = os.path.join(base_dir, 'test')

CAT_SOURCE_DIR = original_dataset_cats_dir
TRAIN_CATS_DIR = os.path.join(TRAIN_DIR, 'cats')
TEST_CATS_DIR = os.path.join(TEST_DIR, 'cats')

DOG_SOURCE_DIR = original_dataset_dogs_dir
TRAIN_DOGS_DIR = os.path.join(TRAIN_DIR, 'dogs')
TEST_DOGS_DIR = os.path.join(TEST_DIR, 'dogs')

if ORGANIZAR_ARCHIVOS:
  if not os.path.exists(base_dir):
    os.mkdir(base_dir)
  if not os.path.exists(TRAIN_DIR):
    os.mkdir(TRAIN_DIR)
  if not os.path.exists(TEST_DIR):
    os.mkdir(TEST_DIR)
  if not os.path.exists(TRAIN_CATS_DIR):
    os.mkdir(TRAIN_CATS_DIR)
  if not os.path.exists(TEST_CATS_DIR):
    os.mkdir(TEST_CATS_DIR)
  if not os.path.exists(TRAIN_DOGS_DIR):
    os.mkdir(TRAIN_DOGS_DIR)
  if not os.path.exists(TEST_DOGS_DIR):
    os.mkdir(TEST_DOGS_DIR)

# %% [markdown]
# Vamos a crear una función que nos permita particionar las imágenes de base en los dos subdirectorios de manera aleatoria.
# Va a recibir:
# - source: directorio con las imágenes de base
# - train: directorio donde quedarán las imágenes a utilizar durante el entrenamiento
# - test: directorio donde quedarán las imágenes a utilizar para evaluar el modelo entrenado
# - split_size: porcentaje de las imágenes a conservar para el entrenamiento en el directorio de train; el complemento quedará en el directorio de test
# - dest_size: tamaño total del dataset final, incluyendo training y test, por defecto es el 100%. Si se establece este valor superior al número de imágenes totales, se capea a las imágenes disponibles
#
# Vamos a crear una estructura de directorios para un dataset con la totalidad de imágenes, con un 90% de imágenes en el test set.
# Los archivos de tamaño cero, o de tipos diferentes a imágenes serán ignorados.

# %%
def split_data(SOURCE, TRAIN, TEST, SPLIT_SIZE, DEST_SIZE=None):
    #Obtenemos todos los nombre de todos los archivos que se encuentran en la fuente de datos
    dataset_filenames = []
    for filename in os.listdir(SOURCE):
        #check archivo vacío
        filename_complete = os.path.join(SOURCE, filename)
        if os.path.getsize(filename_complete)==0:
            print(filename_complete, os.path.getsize(filename_complete))
            continue

        #check archivo no es imágen
        ext = os.path.splitext(filename)[1]
        if not ext.lower().endswith(('.png', '.jpg', '.jpeg')):
            print(filename_complete, os.path.getsize(filename_complete))
            continue

        dataset_filenames.append(filename)

    if DEST_SIZE is None or len(dataset_filenames) < DEST_SIZE:
        DEST_SIZE = len(dataset_filenames)

    #barajamos el conjunto de nombres de archivos y lo separamos en training y testing sets
    dataset_filenames_shuffled = random.sample(dataset_filenames, len(dataset_filenames))
    train = dataset_filenames_shuffled[0:int(DEST_SIZE * SPLIT_SIZE)]
    test = dataset_filenames_shuffled[int(DEST_SIZE * SPLIT_SIZE):DEST_SIZE]

    print(f"Se crea un dataset de {DEST_SIZE} instancias, con {int(DEST_SIZE * SPLIT_SIZE)} en training")

    #copiamos los archivos a los respectivos directorios
    for filename in train:
        filename_source = os.path.join(SOURCE, filename)
        filename_destination = os.path.join(TRAIN, filename)
        shutil.copyfile(filename_source, filename_destination)

    for filename in test:
        filename_source = os.path.join(SOURCE, filename)
        filename_destination = os.path.join(TEST, filename)
        shutil.copyfile(filename_source, filename_destination)

# %%
if ORGANIZAR_ARCHIVOS:
    random.seed(42)
    np.random.seed(42)
    split_size = .9
    split_data(CAT_SOURCE_DIR, TRAIN_CATS_DIR, TEST_CATS_DIR, split_size)
    split_data(DOG_SOURCE_DIR, TRAIN_DOGS_DIR, TEST_DOGS_DIR, split_size)
# Out:
# /content/original/PetImages/Cat/666.jpg 0
# Se crea un dataset de 12499 instancias, con 11249 en training
# /content/original/PetImages/Dog/11702.jpg 0
# Se crea un dataset de 12498 instancias, con 11248 en training

# %%
print('Total cat train images:', len(os.listdir(TRAIN_CATS_DIR)))
print('Total cat test images:', len(os.listdir(TEST_CATS_DIR)))
print('Total dog train images:', len(os.listdir(TRAIN_DOGS_DIR)))
print('Total dog test images:', len(os.listdir(TEST_DOGS_DIR)))
# Out:
# Total cat train images: 11249
# Total cat test images: 1250
# Total dog train images: 11248
# Total dog test images: 1250

# %% [markdown]
# Vamos también a crear una estructura de directorios alterntiva con un dataset reducido (2000 imágenes de training y 1000 de test), esto nos permitirá analizar las implicaciones del tamaño del dataset de entrenamiento en el modelo.

# %%
base_dir_small= '/content/cats_and_dogs_small'

# %%
#shutil.rmtree(base_dir_small)

# %%
TRAIN_SMALL_DIR = os.path.join(base_dir_small, 'train')
TEST_SMALL_DIR = os.path.join(base_dir_small, 'test')

CAT_SOURCE_DIR = original_dataset_cats_dir
TRAIN_CATS_SMALL_DIR = os.path.join(TRAIN_SMALL_DIR, 'cats')
TEST_CATS_SMALL_DIR = os.path.join(TEST_SMALL_DIR, 'cats')

DOG_SOURCE_DIR = original_dataset_dogs_dir
TRAIN_DOGS_SMALL_DIR = os.path.join(TRAIN_SMALL_DIR, 'dogs')
TEST_DOGS_SMALL_DIR = os.path.join(TEST_SMALL_DIR, 'dogs')

if ORGANIZAR_ARCHIVOS:
    # Creamos una estructura de directorios con un primer nivel separando las imágenes de train y de test, y otro con un subdirectorio para cada categoria de imágenes
    if not os.path.exists(base_dir_small):
      os.mkdir(base_dir_small)
    if not os.path.exists(TRAIN_SMALL_DIR):
      os.mkdir(TRAIN_SMALL_DIR)
    if not os.path.exists(TEST_SMALL_DIR):
      os.mkdir(TEST_SMALL_DIR)
    if not os.path.exists(TRAIN_CATS_SMALL_DIR):
      os.mkdir(TRAIN_CATS_SMALL_DIR)
    if not os.path.exists(TEST_CATS_SMALL_DIR):
      os.mkdir(TEST_CATS_SMALL_DIR)
    if not os.path.exists(TRAIN_DOGS_SMALL_DIR):
      os.mkdir(TRAIN_DOGS_SMALL_DIR)
    if not os.path.exists(TEST_DOGS_SMALL_DIR):
      os.mkdir(TEST_DOGS_SMALL_DIR)

# %% [markdown]
# Utilizamos la función split para escoger las imágenes del dataset reducido al azar, con 1500 imágenes para cada categoría, 1000 de train y 500 de test.

# %%
if ORGANIZAR_ARCHIVOS:
    random.seed(42)
    np.random.seed(42)
    dataset_size=1500
    split_size = 0.66667
    split_data(CAT_SOURCE_DIR, TRAIN_CATS_SMALL_DIR, TEST_CATS_SMALL_DIR, split_size, dataset_size)
    split_data(DOG_SOURCE_DIR, TRAIN_DOGS_SMALL_DIR, TEST_DOGS_SMALL_DIR, split_size, dataset_size)
# Out:
# /content/original/PetImages/Cat/666.jpg 0
# Se crea un dataset de 1500 instancias, con 1000 en training
# /content/original/PetImages/Dog/11702.jpg 0
# Se crea un dataset de 1500 instancias, con 1000 en training

# %%
print('Total cat train images:', len(os.listdir(TRAIN_CATS_SMALL_DIR)))
print('Total cat test images:', len(os.listdir(TEST_CATS_SMALL_DIR)))
print('Total dog train images:', len(os.listdir(TRAIN_DOGS_SMALL_DIR)))
print('Total dog test images:', len(os.listdir(TEST_DOGS_SMALL_DIR)))
# Out:
# Total cat train images: 1000
# Total cat test images: 500
# Total dog train images: 1000
# Total dog test images: 500

# %% [markdown]
# ## Parte 2. Carga de imágenes

# %%
TRAIN_SMALL_DIR
# Out:
# '/content/cats_and_dogs_small/train'

# %% [markdown]
# Vamos a utilizar una instancia de la clase ```torchvision.datasets.ImageFolder``` para cargar las imágenes del training set y del test set; cada uno en uno terminará en una instancia de la clase ```torchvision.datasets.Dataset```.
# Esta clase permite cargar imágenes desde un directorio donde se contiene un subdirectorio para cada clase.
# En nuestro caso, tendremos el directorio "train", con dos subdirectorios "cats" y "dogs", uno por cada clase.

# %% [markdown]
# Vamos a cargar las imágenes de tal manera que tengan todas la misma forma (150 pixeles de alto y ancho), utilizando instancias de ```torchvision.transforforms.Resize()```.

# %%
IMG_SIZE=150

# %%
TRANSFORM_IMG = torchvision.transforms.Compose([
    torchvision.transforms.Resize((IMG_SIZE, IMG_SIZE)),
    torchvision.transforms.ToTensor(),
])

# %%
train_data_small = torchvision.datasets.ImageFolder(root=TRAIN_SMALL_DIR, transform=TRANSFORM_IMG)
test_data_small = torchvision.datasets.ImageFolder(root=TEST_SMALL_DIR, transform=TRANSFORM_IMG)

# %%
train_data_small
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2000
#     Root location: /content/cats_and_dogs_small/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(150, 150), interpolation=bilinear, max_size=None, antialias=True)
#                ToTensor()
#            )

# %%
train_data_small.classes
# Out:
# ['cats', 'dogs']

# %%
print(train_data_small.imgs[0:3])
print(train_data_small.targets[0:3])
# Out:
# [('/content/cats_and_dogs_small/train/cats/10001.jpg', 0), ('/content/cats_and_dogs_small/train/cats/10003.jpg', 0), ('/content/cats_and_dogs_small/train/cats/10026.jpg', 0)]
# [0, 0, 0]

# %%
print(train_data_small.imgs[-3:])
print(train_data_small.targets[-3:])
# Out:
# [('/content/cats_and_dogs_small/train/dogs/9982.jpg', 1), ('/content/cats_and_dogs_small/train/dogs/9991.jpg', 1), ('/content/cats_and_dogs_small/train/dogs/9999.jpg', 1)]
# [1, 1, 1]

# %% [markdown]
# Ahora que ya tenemos las dos instancias de ```Dataset```, creamos los ```DataLoader``` correspondientes. Establecemos un batch size de 32 imágenes

# %%
BATCH_SIZE=16

# %%
train_data_loader_small = torch.utils.data.DataLoader(train_data_small, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2)
test_data_loader_small = torch.utils.data.DataLoader(test_data_small, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %% [markdown]
# Mas adelante crearemos más datasets y dataloaders para ilustrar el **data augmentation** y para poder además cargar el dataset completo.

# %% [markdown]
# ## Parte 3. Funciones para el entrenamiento y evaluación de modelos

# %% [markdown]
# En esta sección recopilamos las funciones que utilizaremos mas adelante para la búsqueda de los mejores modelos, analizando las diferentes técnicas de regularización y optimización del entrenamiento.

# %% [markdown]
# Creamos entonces la función encargada de realizar los ciclos de entrenamiento a partir de batches sobre el ```DataLoader``` de training que:
# - Por defecto define una función de pérdida ```nn.BCELoss()``` que recibe las probabilidades de clasificación, y calcula el accuracy teniendo en cuenta que el modelo retorna una sola probabilidad (de la clase 1), por lo que evalua si las predicciones son superiores a 0.5 para asignarles la clase e, o 0 de lo contrario. Se puede modificar enviando la función como parámetro; esto puede ser necesario si el modelo en cuestión no devuleve probabilidades sino logits.
# - permite definir el porcentaje de datos que se utilizará para validación durante cada epoca.
# - aplica técnica de creación de **checkpoints** del modelo previamente presentada en el notebook anterior
# - implementa la técnica de **early stopping** en el ciclo, estableciendo
#     - **early_stopping_acc_training**: una meta del accuracy sobre el training set a alcanzar antes de suspender el entrenamiento.
#     - **early_stopping_loss_val_patience**: un número de épocas máximo a iterar sin mejoras en el loss de validación. Requiere que se tenga un set de validación, en caso contrario, no se aplica.
# - aplica técnica de **data augmentation** sobre el training set para reducir un poco mas el overfitting modificando levemente las imágenes del dataset de entrenamiento

# %%
def train_model(modelo, train_dataset, train_batch_size=128, learning_rate = 1e-3, epocas=30, loss_fn=nn.BCELoss(), val_split=0, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=-1, transformaciones=None, verbose=False):
    """Se encarga de realizar el ciclo de épocas de entrenamiento.

    :modelo:
        instancia creada del modelo a entrenar
    :train_dataset:
        instancia de Dataset con los datos de entrenamiento
    :train_batch_size:
        tamaño del batch size de entrenamiento
    :learning_rate:
        learning rate del optimizador.
    :epocas:
        número de iteraciones de entrenamiento sobre el dataset completo
    :loss_fn:
        función de pérdida a utilizar. Si no se especifica, se usa BCELoss
    :val_split:
        porcentaje del dataset de entrenamiento dedicado a la validación, su valor será limitado al intervalo [0 (sin validación), 0.5]
    :early_stopping_acc_training:
        umbral máximo de accuracy sobre el training set, si se sobrepasa durante una época, se parará el entrenamiento, limitando el overfitting
    :early_stopping_loss_val_patience:
        número de épocas de paciencia a esperar una mejora del val loss antes de suspender el entrenamiento. -1 implica que no se aplica
    :transformaciones:
        transformaciones a realizar sobre el training set si se quiere aplicar data augmentation
    :verbose:
        indica si se quiere imprimr el avance del proceso o no
    :returns:
        el modelo entrenado y 4 arrays con los valores de losses y accuracies del training dataset, y los losses y accuracies del val set después de cada época
    """

    reset_seed()

    # Gestión de los loaders de training y validation
    if val_split > 0.5:
        val_split=0.5

    if val_split < 0:
        val_split=0

    if val_split > 0:
        num_training_instances = int(len(train_dataset)*(1-val_split))
        num_validation_instances = len(train_dataset) - num_training_instances
        print(f"val_split: {val_split}, num_training_instances {num_training_instances}, num_validation_instances {num_validation_instances}")
        training_subset, validation_subset = torch.utils.data.random_split(
            train_dataset, [num_training_instances, num_validation_instances])

        train_loader = torch.utils.data.DataLoader(
            training_subset, batch_size=train_batch_size, shuffle=True, num_workers=2)
        validation_loader = torch.utils.data.DataLoader(
            validation_subset, batch_size=1024, num_workers=2)

    else :
        train_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=train_batch_size, shuffle=True, num_workers=2)


    # Se crea el modelo y optimizador
    modelo = modelo.to(DEVICE) # situar el modelo en el dispositivo de procesamiento
    optimizer = torch.optim.Adam(modelo.parameters(), lr=learning_rate)

    # Creamos vectores donde almacenaremos los losses y métricas después de cada época
    train_losses = [0] * epocas
    train_accuracies = [0] * epocas
    val_losses = [0] * epocas
    val_accuracies = [0] * epocas

    min_loss = np.Inf
    best_model = None
    num_epocas_patience = 0


    for epoca in range(epocas):
        epoca_start_time = time.time()
        modelo.train()
        for batch_features, batch_labels in train_loader:
            # Nos aseguramos que los inputs del modelo estén en el mismo dispositivo
            batch_features = batch_features.to(DEVICE)
            batch_labels = batch_labels.to(DEVICE).unsqueeze(-1).float()
            # Data augmentation
            if transformaciones is not None:
                batch_features = transformaciones(batch_features)
            # Generar las predicciones
            batch_preds = modelo(batch_features)
            # Comparar con las realidades a partir del loss function
            loss = loss_fn(batch_preds, batch_labels)
            # Calcular los gradientes de la función de pérdida
            loss.backward()
            # Actualizar parámetros con los gradientes
            optimizer.step()
            # Resetear los gradientes para no reacumularlos
            optimizer.zero_grad()
            # se acumulan los losses de la epoca (ponderados por el tamaño del batch)
            train_losses[epoca] += loss.item() * batch_labels.size(0)
            # se acumulan las predicciones correctas de la epoca
            correctos = (batch_preds.gt(0.5).type(torch.float) == batch_labels)
            # print(f"batch_preds: {batch_preds}")
            # print(f"batch_preds.argmax: {batch_preds.argmax(1)}")
            # print(f"labels: {batch_labels}")
            # print(f"correctos: {correctos}")
            train_accuracies[epoca] += correctos.type(torch.float).sum().item()
            # print(f"train_accuracies[epoca]: {train_accuracies[epoca]}")

        # se normalizan el loss y el accuracy del training set
        train_losses[epoca] /= len(train_loader.dataset)
        train_accuracies[epoca] /= len(train_loader.dataset)

        if val_split > 0:
            # se desactiva la diferenciación automática para la inferencia sobre el val set
            modelo.eval()
            with torch.no_grad():
                for batch_features, batch_labels in validation_loader:
                    # Nos aseguramos que los inputs del modelo estén en el mismo dispositivo
                    batch_features = batch_features.to(DEVICE)
                    batch_labels = batch_labels.to(DEVICE).unsqueeze(-1).float()
                    # Generar las predicciones
                    batch_preds = modelo(batch_features)
                    # Comparar con las realidades a partir del loss function
                    loss = loss_fn(batch_preds, batch_labels)
                    # se acumulan los losses de la epoca (ponderados por el tamaño del batch)
                    val_losses[epoca] += loss.item() * batch_labels.size(0)
                    # se acumulan las predicciones correctas de la epoca
                    correctos = (batch_preds.gt(0.5).type(torch.float) == batch_labels)
                    val_accuracies[epoca] += correctos.type(torch.float).sum().item()
            # se normalizan el loss y el accuracy del val set
            val_losses[epoca] /= len(validation_loader.dataset)
            val_accuracies[epoca] /= len(validation_loader.dataset)

        epoca_end_time = time.time()
        segundos = epoca_end_time - epoca_start_time

        if verbose:
            if val_split > 0:
                print(f"{epoca}:  loss: {train_losses[epoca]:>7f}, accuracy: {train_accuracies[epoca]:>7f}, val loss: {val_losses[epoca]:>7f}, val accuracy: {val_accuracies[epoca]:>7f}",
                      f"-- epoch time: {segundos:.2f}")

                # model checkpoint
                if val_losses[epoca] < min_loss:
                    best_model=copy.deepcopy(modelo)
                    torch.save(modelo, "best_model.pth")
                    print(f"Se mejoró el loss de {min_loss} a {val_losses[epoca]}")
                    min_loss = val_losses[epoca]
                    num_epocas_patience = 0
                else:
                    num_epocas_patience +=1

                if early_stopping_loss_val_patience >-1 and num_epocas_patience > early_stopping_loss_val_patience:
                    print(f"----- Se sobrepasó el patience del val loss del early stopping {num_epocas_patience})")
                    break

            else:
                print(f"{epoca}:  loss: {train_losses[epoca]:>7f}, accuracy: {train_accuracies[epoca]:>7f}",
                      f"-- epoch time: {segundos:.2f}")

                # model checkpoint
                if train_losses[epoca] < min_loss:
                    torch.save(modelo, "best_model.pth")
                    print(f"Se mejoró el val loss de {min_loss} a {train_losses[epoca]}")
                    min_loss = train_losses[epoca]

        if early_stopping_acc_training != -1 and train_accuracies[epoca] > early_stopping_acc_training:
            print(f"----- Se sobrepasó el límite de accuracy del early stopping {early_stopping_acc_training})")
            break

    if val_split > 0:
        return best_model, train_losses, train_accuracies, val_losses, val_accuracies
    else:
        return modelo, train_losses, train_accuracies

# %% [markdown]
# Creamos una función reutilizable para plotear los resultados a lo largo del entrenamiento.

# %%
def plot_losses_and_accuracies(train_losses, train_accuracies, val_losses=None, val_accuracies=None):
    fig = plt.figure(figsize=(15,6))

    ax = fig.add_subplot(1, 2, 1)
    ax.plot(train_losses)
    if val_losses is not None:
        ax.plot(val_losses)
        plt.legend(['train', 'val'], loc='upper left')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.title('model loss')

    ax = fig.add_subplot(1, 2, 2)
    ax.plot(train_accuracies)
    if val_accuracies is not None:
        ax.plot(val_accuracies)
        plt.legend(['train', 'val'], loc='upper left')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.title('model accuracy')

    _=plt.show()

# %% [markdown]
# Creamos también una función que utilizaremos para evaluar cualquier dataset (e.g. el test set) con un modelo ya entrenado, y qye retorne el loss y accuracy del proceso de inferencia.

# %%
def eval_model(modelo, dataloader, loss_fn=nn.BCELoss()):
    modelo.eval()
    loss = 0
    accuracy = 0

    with torch.no_grad():
        for batch_idx, (batch_features, batch_labels) in enumerate(dataloader):
            batch_features = batch_features.to(DEVICE)
            batch_labels = batch_labels.to(DEVICE).unsqueeze(-1).float()
            batch_preds = modelo(batch_features)
            loss += loss_fn(batch_preds, batch_labels).item() * batch_labels.size(0)
            correctos = (batch_preds.gt(0.5).type(torch.float) == batch_labels)
            accuracy += correctos.type(torch.float).sum().item()

    # se normalizan el loss y el accuracy del val set
    loss /= len(dataloader.dataset)
    accuracy /= len(dataloader.dataset)

    return loss, accuracy

# %% [markdown]
# ## Parte 4. Dataset reducido -- modelo de base

# %% [markdown]
# Vamos a definir un modelo convolucional inicial de base (luego le agregaremos más complejidad) parecido a los que ya hemos definido antes:
# * que recibe un tensor con las instancias de imágen con tres ejes con la dimensionalidad (3, 150, 150),
# * con 4 capas convolucionales 2D ```nn.Conv2d```, todas con filtros 3x3 y función de activación ```F.relu()```; la primera con 32 filtros, la segunda con 64 filtros, y la tercera y cuarta con 128 filtros.
# * con 3 capas intermedias de ```nn.MaxPooling2d``` que toman las salidas de las capas convolucionales.
# * con una capa ```nn.Flatten``` que permite cambiar la representación de las salidas de las capas convolucionales a un tensor de un solo eje
# * con dos capas ```nn.Linear```, fully connected, la primera con 512 neuronas y ```F.relu()```, la segunda, la capa de salida, con 1 sola neurona que utiliza una función ```F.sigmoide()``` para clasificar las instancias en dos clases (binarias).
#
# La salida del modelo será entonces un tensor de rango 2, con el número de instancias del batch procesado, y con la probabilidad de pertenencia a la clase marcada como "1". La función de loss que utilizaremos será ```nn.BCE```, la versión binaria de cross-entropy que recibe probabilidad (existe también ```BCEWithLogits``` que recibe los logits y no requiere la función de activación final sigmoide como función de activación de la última capa).

# %%
class BinaryImageClassifierBase(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding="valid")
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding="valid")
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding="valid")
        self.maxpool3 = nn.MaxPool2d(kernel_size=2)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding="valid")
        self.maxpool4 = nn.MaxPool2d(kernel_size=2)
        self.flatten = nn.Flatten()
        self.linear1 = nn.Linear(in_features=128*7*7, out_features=512) # salida de cantidad de canales * alto *ancho de mi salida = 128*7*7
        self.linear2 = nn.Linear(in_features=512, out_features=1)

    def forward(self, image):
        x = self.conv1(image)
        x = F.relu(x)
        x = self.maxpool1(x)

        x = self.conv2(x)
        x = F.relu(x)
        x = self.maxpool2(x)

        x = self.conv3(x)
        x = F.relu(x)
        x = self.maxpool3(x)

        x = self.conv4(x)
        x = F.relu(x)
        x = self.maxpool4(x)

        x = self.flatten(x)
        x = self.linear1(x)
        x = F.relu(x)
        logits = self.linear2(x)
        probas = torch.sigmoid(logits)

        return probas

# %%
modelo_base = BinaryImageClassifierBase()
modelo_base
# Out:
# BinaryImageClassifierBase(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear1): Linear(in_features=6272, out_features=512, bias=True)
#   (linear2): Linear(in_features=512, out_features=1, bias=True)
# )

# %% [markdown]
# Ya deberían estar en capacidad de estimar el número de parámetros así como el tensor de salida de cada capa. Veamos los parámetros del modelo.

# %%
for param in modelo_base.parameters():
    print(f"{param.shape}")
# Out:
# torch.Size([32, 3, 3, 3])
# torch.Size([32])
# torch.Size([64, 32, 3, 3])
# torch.Size([64])
# torch.Size([128, 64, 3, 3])
# torch.Size([128])
# torch.Size([128, 128, 3, 3])
# torch.Size([128])
# torch.Size([512, 6272])
# torch.Size([512])
# torch.Size([1, 512])
# torch.Size([1])

# %% [markdown]
# Para poder visualizar mas en detalle las características internas del modelo, utilizamos  `torchsummary.summary`, que recibe el modelo y el tamaño del tensor de entrada, y permite visualizar el número de parámetros del modelo.

# %%
modelo_base.to(DEVICE) # OJO, es necesario que el modelo esté en el mismo dispositivo del resto de tensores con los que se interactúa.
summary(modelo_base, input_size=(3, 150, 150))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 148, 148]             896
#          MaxPool2d-2           [-1, 32, 74, 74]               0
#             Conv2d-3           [-1, 64, 72, 72]          18,496
#          MaxPool2d-4           [-1, 64, 36, 36]               0
#             Conv2d-5          [-1, 128, 34, 34]          73,856
#          MaxPool2d-6          [-1, 128, 17, 17]               0
#             Conv2d-7          [-1, 128, 15, 15]         147,584
#          MaxPool2d-8            [-1, 128, 7, 7]               0
#            Flatten-9                 [-1, 6272]               0
#            Linear-10                  [-1, 512]       3,211,776
#            Linear-11                    [-1, 1]             513
# ================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.26
# Forward/backward pass size (MB): 11.58
# Params size (MB): 13.17
# Estimated Total Size (MB): 25.01
# ----------------------------------------------------------------

# %% [markdown]
# En total, el modelo de base tiene 3.45 millones de parámetros, la gran mayoría de ellos asociados a las capas densas escondidas (una sola).
# Es por eso también que se dice que, las capas convolucionales sirven para generalizar mejor que las capas densas.

# %% [markdown]
# Vamos a realizar pruebas con diferentes valores del learning rates para ilustrar los comportamientos de convergencia y divergencia, así como tiempo en llegar a esos estados. Los learning rates van a depender del tamaños del batch, vamos a definir un batch de 16.
#
# Como punto de comparación del tiempo de ejecución en Colab, sin GPU se toma 90 segundos por cada época y 9 segundos con GPU.

# %%
BATCH_SIZE=16

# %%
start = time.time()
reset_seed()
modelo_base_1e5, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=0.00001, epocas=50, val_split=0.15, early_stopping_acc_training = 0.95, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.693120, accuracy: 0.502941, val loss: 0.693351, val accuracy: 0.483333 -- epoch time: 7.69
# Se mejoró el loss de inf a 0.6933510899543762
# 1:  loss: 0.692723, accuracy: 0.502353, val loss: 0.692461, val accuracy: 0.483333 -- epoch time: 5.98
# Se mejoró el loss de 0.6933510899543762 a 0.6924611330032349
# 2:  loss: 0.691118, accuracy: 0.502353, val loss: 0.690978, val accuracy: 0.493333 -- epoch time: 7.41
# Se mejoró el loss de 0.6924611330032349 a 0.6909782886505127
# 3:  loss: 0.689095, accuracy: 0.523529, val loss: 0.688368, val accuracy: 0.570000 -- epoch time: 5.97
# Se mejoró el loss de 0.6909782886505127 a 0.6883679628372192
# 4:  loss: 0.684538, accuracy: 0.577647, val loss: 0.688814, val accuracy: 0.493333 -- epoch time: 7.27
# 5:  loss: 0.678989, accuracy: 0.584118, val loss: 0.679357, val accuracy: 0.600000 -- epoch time: 6.04
# Se mejoró el loss de 0.6883679628372192 a 0.6793569326400757
# 6:  loss: 0.668516, accuracy: 0.610000, val loss: 0.672605, val accuracy: 0.593333 -- epoch time: 7.47
# Se mejoró el loss de 0.6793569326400757 a 0.6726053953170776
# 7:  loss: 0.661167, accuracy: 0.631765, val loss: 0.673823, val accuracy: 0.583333 -- epoch time: 5.98
# 8:  loss: 0.652453, accuracy: 0.623529, val loss: 0.665613, val accuracy: 0.600000 -- epoch time: 7.27
# Se mejoró el loss de 0.6726053953170776 a 0.665613055229187
# 9:  loss: 0.642881, accuracy: 0.635294, val loss: 0.660108, val accuracy: 0.600000 -- epoch time: 5.94
# Se mejoró el loss de 0.665613055229187 a 0.6601079702377319
# 10:  loss: 0.646148, accuracy: 0.626471, val loss: 0.666950, val accuracy: 0.610000 -- epoch time: 7.32
# 11:  loss: 0.634863, accuracy: 0.658824, val loss: 0.657561, val accuracy: 0.600000 -- epoch time: 6.04
# Se mejoró el loss de 0.6601079702377319 a 0.6575610637664795
# 12:  loss: 0.631418, accuracy: 0.646471, val loss: 0.657344, val accuracy: 0.596667 -- epoch time: 7.34
# Se mejoró el loss de 0.6575610637664795 a 0.657343864440918
# 13:  loss: 0.627910, accuracy: 0.642941, val loss: 0.652311, val accuracy: 0.596667 -- epoch time: 5.94
# Se mejoró el loss de 0.657343864440918 a 0.6523107290267944
# 14:  loss: 0.626044, accuracy: 0.655882, val loss: 0.651654, val accuracy: 0.596667 -- epoch time: 7.26
# Se mejoró el loss de 0.6523107290267944 a 0.6516535878181458
# 15:  loss: 0.621813, accuracy: 0.658235, val loss: 0.649104, val accuracy: 0.596667 -- epoch time: 6.04
# Se mejoró el loss de 0.6516535878181458 a 0.649104118347168
# 16:  loss: 0.618968, accuracy: 0.655882, val loss: 0.650926, val accuracy: 0.586667 -- epoch time: 8.46
# 17:  loss: 0.618936, accuracy: 0.660588, val loss: 0.659172, val accuracy: 0.620000 -- epoch time: 5.98
# 18:  loss: 0.619393, accuracy: 0.664706, val loss: 0.648409, val accuracy: 0.606667 -- epoch time: 7.31
# Se mejoró el loss de 0.649104118347168 a 0.6484087109565735
# 19:  loss: 0.612958, accuracy: 0.665294, val loss: 0.649010, val accuracy: 0.610000 -- epoch time: 5.94
# 20:  loss: 0.610523, accuracy: 0.662941, val loss: 0.646444, val accuracy: 0.610000 -- epoch time: 7.33
# Se mejoró el loss de 0.6484087109565735 a 0.6464440822601318
# 21:  loss: 0.608831, accuracy: 0.668235, val loss: 0.648363, val accuracy: 0.586667 -- epoch time: 5.92
# 22:  loss: 0.608884, accuracy: 0.663529, val loss: 0.644500, val accuracy: 0.610000 -- epoch time: 7.26
# Se mejoró el loss de 0.6464440822601318 a 0.6444997787475586
# 23:  loss: 0.604360, accuracy: 0.669412, val loss: 0.642164, val accuracy: 0.620000 -- epoch time: 5.95
# Se mejoró el loss de 0.6444997787475586 a 0.6421635746955872
# 24:  loss: 0.603546, accuracy: 0.669412, val loss: 0.644398, val accuracy: 0.580000 -- epoch time: 7.44
# 25:  loss: 0.602478, accuracy: 0.674118, val loss: 0.644985, val accuracy: 0.580000 -- epoch time: 5.98
# 26:  loss: 0.598868, accuracy: 0.674118, val loss: 0.643721, val accuracy: 0.586667 -- epoch time: 7.27
# 27:  loss: 0.596195, accuracy: 0.684118, val loss: 0.640729, val accuracy: 0.626667 -- epoch time: 5.96
# Se mejoró el loss de 0.6421635746955872 a 0.6407285928726196
# 28:  loss: 0.596487, accuracy: 0.683529, val loss: 0.646416, val accuracy: 0.633333 -- epoch time: 7.25
# 29:  loss: 0.591974, accuracy: 0.682353, val loss: 0.641080, val accuracy: 0.630000 -- epoch time: 6.06
# 30:  loss: 0.591474, accuracy: 0.693529, val loss: 0.648281, val accuracy: 0.640000 -- epoch time: 7.25
# 31:  loss: 0.597888, accuracy: 0.672941, val loss: 0.635964, val accuracy: 0.606667 -- epoch time: 5.98
# Se mejoró el loss de 0.6407285928726196 a 0.6359640955924988
# 32:  loss: 0.588341, accuracy: 0.692353, val loss: 0.635201, val accuracy: 0.616667 -- epoch time: 7.24
# Se mejoró el loss de 0.6359640955924988 a 0.635201096534729
# 33:  loss: 0.586841, accuracy: 0.690588, val loss: 0.634778, val accuracy: 0.613333 -- epoch time: 6.08
# Se mejoró el loss de 0.635201096534729 a 0.6347775459289551
# 34:  loss: 0.586936, accuracy: 0.677647, val loss: 0.652590, val accuracy: 0.630000 -- epoch time: 7.26
# 35:  loss: 0.582572, accuracy: 0.705294, val loss: 0.633759, val accuracy: 0.616667 -- epoch time: 5.96
# Se mejoró el loss de 0.6347775459289551 a 0.633759081363678
# 36:  loss: 0.583267, accuracy: 0.697647, val loss: 0.636919, val accuracy: 0.633333 -- epoch time: 7.32
# 37:  loss: 0.579055, accuracy: 0.697647, val loss: 0.635985, val accuracy: 0.630000 -- epoch time: 5.98
# 38:  loss: 0.579046, accuracy: 0.699412, val loss: 0.635300, val accuracy: 0.630000 -- epoch time: 7.37
# 39:  loss: 0.576757, accuracy: 0.703529, val loss: 0.630822, val accuracy: 0.620000 -- epoch time: 5.96
# Se mejoró el loss de 0.633759081363678 a 0.6308216452598572
# 40:  loss: 0.575840, accuracy: 0.699412, val loss: 0.638157, val accuracy: 0.643333 -- epoch time: 7.24
# 41:  loss: 0.574729, accuracy: 0.701176, val loss: 0.642300, val accuracy: 0.626667 -- epoch time: 5.94
# 42:  loss: 0.572515, accuracy: 0.697059, val loss: 0.630617, val accuracy: 0.633333 -- epoch time: 7.33
# Se mejoró el loss de 0.6308216452598572 a 0.6306167244911194
# 43:  loss: 0.569256, accuracy: 0.706471, val loss: 0.639112, val accuracy: 0.650000 -- epoch time: 6.05
# 44:  loss: 0.568395, accuracy: 0.701765, val loss: 0.630059, val accuracy: 0.626667 -- epoch time: 8.42
# Se mejoró el loss de 0.6306167244911194 a 0.6300585865974426
# 45:  loss: 0.569502, accuracy: 0.708235, val loss: 0.631400, val accuracy: 0.640000 -- epoch time: 6.81
# 46:  loss: 0.565955, accuracy: 0.704706, val loss: 0.630637, val accuracy: 0.636667 -- epoch time: 6.02
# 47:  loss: 0.563650, accuracy: 0.707647, val loss: 0.626347, val accuracy: 0.630000 -- epoch time: 7.06
# Se mejoró el loss de 0.6300585865974426 a 0.6263469457626343
# 48:  loss: 0.562501, accuracy: 0.707647, val loss: 0.626634, val accuracy: 0.636667 -- epoch time: 5.96
# 49:  loss: 0.560393, accuracy: 0.723529, val loss: 0.624906, val accuracy: 0.640000 -- epoch time: 7.09
# Se mejoró el loss de 0.6263469457626343 a 0.6249061226844788
# time: 336.51

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# Vemos que para este learning rate, el loss de validación baja continuamente, con la misma velocidad del loss del training (sin overfitting) alcanzando un accuracy de validación del 70.33%.
# Podría seguir bajando durante unas épocas mas.
#
# Intentamos con otros valores de lr.

# %%
start = time.time()
reset_seed()
modelo_base_5e5, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=5e-5, epocas=50, val_split=0.15, early_stopping_acc_training = 0.95, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.693323, accuracy: 0.502941, val loss: 0.692723, val accuracy: 0.510000 -- epoch time: 8.51
# Se mejoró el loss de inf a 0.692723274230957
# 1:  loss: 0.691839, accuracy: 0.523529, val loss: 0.687768, val accuracy: 0.506667 -- epoch time: 8.44
# Se mejoró el loss de 0.692723274230957 a 0.6877679824829102
# 2:  loss: 0.681568, accuracy: 0.575294, val loss: 0.687311, val accuracy: 0.533333 -- epoch time: 8.56
# Se mejoró el loss de 0.6877679824829102 a 0.6873109340667725
# 3:  loss: 0.671106, accuracy: 0.580588, val loss: 0.658529, val accuracy: 0.620000 -- epoch time: 8.70
# Se mejoró el loss de 0.6873109340667725 a 0.6585286855697632
# 4:  loss: 0.651435, accuracy: 0.625294, val loss: 0.632234, val accuracy: 0.636667 -- epoch time: 8.52
# Se mejoró el loss de 0.6585286855697632 a 0.6322343349456787
# 5:  loss: 0.634795, accuracy: 0.649412, val loss: 0.618261, val accuracy: 0.676667 -- epoch time: 8.43
# Se mejoró el loss de 0.6322343349456787 a 0.6182605028152466
# 6:  loss: 0.616137, accuracy: 0.661176, val loss: 0.624583, val accuracy: 0.630000 -- epoch time: 8.50
# 7:  loss: 0.612908, accuracy: 0.656471, val loss: 0.603658, val accuracy: 0.683333 -- epoch time: 8.44
# Se mejoró el loss de 0.6182605028152466 a 0.6036583781242371
# 8:  loss: 0.602364, accuracy: 0.663529, val loss: 0.617587, val accuracy: 0.650000 -- epoch time: 8.43
# 9:  loss: 0.586846, accuracy: 0.685294, val loss: 0.585314, val accuracy: 0.690000 -- epoch time: 8.48
# Se mejoró el loss de 0.6036583781242371 a 0.5853140354156494
# 10:  loss: 0.574200, accuracy: 0.700000, val loss: 0.569739, val accuracy: 0.693333 -- epoch time: 8.48
# Se mejoró el loss de 0.5853140354156494 a 0.5697389841079712
# 11:  loss: 0.560558, accuracy: 0.706471, val loss: 0.551651, val accuracy: 0.723333 -- epoch time: 12.08
# Se mejoró el loss de 0.5697389841079712 a 0.5516508221626282
# 12:  loss: 0.546909, accuracy: 0.720588, val loss: 0.561225, val accuracy: 0.713333 -- epoch time: 9.26
# 13:  loss: 0.533571, accuracy: 0.725882, val loss: 0.535851, val accuracy: 0.716667 -- epoch time: 8.47
# Se mejoró el loss de 0.5516508221626282 a 0.5358510613441467
# 14:  loss: 0.529765, accuracy: 0.730000, val loss: 0.518056, val accuracy: 0.740000 -- epoch time: 8.41
# Se mejoró el loss de 0.5358510613441467 a 0.5180555582046509
# 15:  loss: 0.518228, accuracy: 0.743529, val loss: 0.531108, val accuracy: 0.723333 -- epoch time: 8.47
# 16:  loss: 0.509173, accuracy: 0.749412, val loss: 0.500408, val accuracy: 0.746667 -- epoch time: 8.45
# Se mejoró el loss de 0.5180555582046509 a 0.5004077553749084
# 17:  loss: 0.500454, accuracy: 0.745294, val loss: 0.504673, val accuracy: 0.753333 -- epoch time: 8.54
# 18:  loss: 0.486633, accuracy: 0.753529, val loss: 0.495913, val accuracy: 0.736667 -- epoch time: 8.45
# Se mejoró el loss de 0.5004077553749084 a 0.49591323733329773
# 19:  loss: 0.473685, accuracy: 0.767059, val loss: 0.503997, val accuracy: 0.750000 -- epoch time: 8.48
# 20:  loss: 0.476464, accuracy: 0.758824, val loss: 0.510558, val accuracy: 0.726667 -- epoch time: 8.62
# 21:  loss: 0.473007, accuracy: 0.768824, val loss: 0.485762, val accuracy: 0.773333 -- epoch time: 9.23
# Se mejoró el loss de 0.49591323733329773 a 0.48576194047927856
# 22:  loss: 0.449836, accuracy: 0.785882, val loss: 0.485901, val accuracy: 0.750000 -- epoch time: 8.64
# 23:  loss: 0.452124, accuracy: 0.782941, val loss: 0.478469, val accuracy: 0.750000 -- epoch time: 9.33
# Se mejoró el loss de 0.48576194047927856 a 0.47846904397010803
# 24:  loss: 0.438844, accuracy: 0.787059, val loss: 0.494023, val accuracy: 0.740000 -- epoch time: 8.52
# 25:  loss: 0.428196, accuracy: 0.799412, val loss: 0.478900, val accuracy: 0.753333 -- epoch time: 8.54
# 26:  loss: 0.419407, accuracy: 0.803529, val loss: 0.479087, val accuracy: 0.743333 -- epoch time: 8.48
# 27:  loss: 0.411344, accuracy: 0.814118, val loss: 0.457004, val accuracy: 0.753333 -- epoch time: 8.54
# Se mejoró el loss de 0.47846904397010803 a 0.4570038318634033
# 28:  loss: 0.408634, accuracy: 0.801765, val loss: 0.502505, val accuracy: 0.773333 -- epoch time: 8.48
# 29:  loss: 0.390746, accuracy: 0.822353, val loss: 0.456965, val accuracy: 0.780000 -- epoch time: 8.48
# Se mejoró el loss de 0.4570038318634033 a 0.45696544647216797
# 30:  loss: 0.379886, accuracy: 0.819412, val loss: 0.524255, val accuracy: 0.746667 -- epoch time: 8.58
# 31:  loss: 0.374367, accuracy: 0.833529, val loss: 0.457090, val accuracy: 0.790000 -- epoch time: 8.63
# 32:  loss: 0.362712, accuracy: 0.837059, val loss: 0.425692, val accuracy: 0.790000 -- epoch time: 8.51
# Se mejoró el loss de 0.45696544647216797 a 0.4256916642189026
# 33:  loss: 0.348665, accuracy: 0.852353, val loss: 0.443954, val accuracy: 0.766667 -- epoch time: 8.50
# 34:  loss: 0.342243, accuracy: 0.847059, val loss: 0.443414, val accuracy: 0.790000 -- epoch time: 8.57
# 35:  loss: 0.332246, accuracy: 0.852941, val loss: 0.431772, val accuracy: 0.793333 -- epoch time: 9.49
# 36:  loss: 0.331184, accuracy: 0.857647, val loss: 0.438882, val accuracy: 0.776667 -- epoch time: 8.40
# 37:  loss: 0.323484, accuracy: 0.854118, val loss: 0.472652, val accuracy: 0.763333 -- epoch time: 8.44
# 38:  loss: 0.309352, accuracy: 0.862941, val loss: 0.421806, val accuracy: 0.790000 -- epoch time: 8.51
# Se mejoró el loss de 0.4256916642189026 a 0.42180564999580383
# 39:  loss: 0.292096, accuracy: 0.876471, val loss: 0.436462, val accuracy: 0.790000 -- epoch time: 8.56
# 40:  loss: 0.287896, accuracy: 0.882941, val loss: 0.448275, val accuracy: 0.776667 -- epoch time: 8.57
# 41:  loss: 0.280790, accuracy: 0.888824, val loss: 0.429142, val accuracy: 0.786667 -- epoch time: 8.56
# 42:  loss: 0.277870, accuracy: 0.875294, val loss: 0.491252, val accuracy: 0.780000 -- epoch time: 8.48
# 43:  loss: 0.266282, accuracy: 0.883529, val loss: 0.470774, val accuracy: 0.773333 -- epoch time: 8.49
# 44:  loss: 0.256343, accuracy: 0.901765, val loss: 0.441308, val accuracy: 0.780000 -- epoch time: 8.47
# 45:  loss: 0.248484, accuracy: 0.901176, val loss: 0.468418, val accuracy: 0.780000 -- epoch time: 8.62
# 46:  loss: 0.260475, accuracy: 0.888235, val loss: 0.447319, val accuracy: 0.790000 -- epoch time: 8.62
# 47:  loss: 0.235827, accuracy: 0.903529, val loss: 0.456654, val accuracy: 0.783333 -- epoch time: 9.22
# 48:  loss: 0.236215, accuracy: 0.904118, val loss: 0.454855, val accuracy: 0.800000 -- epoch time: 8.50
# 49:  loss: 0.224583, accuracy: 0.914706, val loss: 0.537018, val accuracy: 0.783333 -- epoch time: 8.47
# time: 434.10

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# Vemos que con un LR de 5e-5, el loss de validación baja a mayor velocidad que previamente, pero a partir de la época 21, comienza a presentarse una situación de overfitting.
# El val loss al que se llega es de 0.42, con un accuracy de 79%, mejores métricas que con el learning rate anterior.

# %%
start = time.time()
reset_seed()
modelo_base_1e4, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-4, epocas=30, val_split=0.15, early_stopping_acc_training = 0.95, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.693787, accuracy: 0.504118, val loss: 0.692698, val accuracy: 0.623333 -- epoch time: 8.59
# Se mejoró el loss de inf a 0.6926975846290588
# 1:  loss: 0.689751, accuracy: 0.555882, val loss: 0.679880, val accuracy: 0.596667 -- epoch time: 9.75
# Se mejoró el loss de 0.6926975846290588 a 0.6798800826072693
# 2:  loss: 0.671781, accuracy: 0.583529, val loss: 0.679814, val accuracy: 0.533333 -- epoch time: 8.57
# Se mejoró el loss de 0.6798800826072693 a 0.6798141598701477
# 3:  loss: 0.665856, accuracy: 0.595294, val loss: 0.659960, val accuracy: 0.596667 -- epoch time: 8.59
# Se mejoró el loss de 0.6798141598701477 a 0.6599599123001099
# 4:  loss: 0.646689, accuracy: 0.623529, val loss: 0.635000, val accuracy: 0.640000 -- epoch time: 8.65
# Se mejoró el loss de 0.6599599123001099 a 0.6349995732307434
# 5:  loss: 0.629769, accuracy: 0.653529, val loss: 0.626104, val accuracy: 0.636667 -- epoch time: 9.17
# Se mejoró el loss de 0.6349995732307434 a 0.626103937625885
# 6:  loss: 0.603627, accuracy: 0.665294, val loss: 0.626362, val accuracy: 0.650000 -- epoch time: 8.65
# 7:  loss: 0.594438, accuracy: 0.688824, val loss: 0.592197, val accuracy: 0.673333 -- epoch time: 9.51
# Se mejoró el loss de 0.626103937625885 a 0.5921973586082458
# 8:  loss: 0.575217, accuracy: 0.689412, val loss: 0.607208, val accuracy: 0.670000 -- epoch time: 8.60
# 9:  loss: 0.559333, accuracy: 0.710588, val loss: 0.556198, val accuracy: 0.733333 -- epoch time: 8.59
# Se mejoró el loss de 0.5921973586082458 a 0.5561978220939636
# 10:  loss: 0.542279, accuracy: 0.727647, val loss: 0.536751, val accuracy: 0.743333 -- epoch time: 8.70
# Se mejoró el loss de 0.5561978220939636 a 0.5367510318756104
# 11:  loss: 0.517593, accuracy: 0.736471, val loss: 0.520829, val accuracy: 0.746667 -- epoch time: 8.58
# Se mejoró el loss de 0.5367510318756104 a 0.5208290815353394
# 12:  loss: 0.505317, accuracy: 0.752353, val loss: 0.507414, val accuracy: 0.743333 -- epoch time: 8.63
# Se mejoró el loss de 0.5208290815353394 a 0.5074142813682556
# 13:  loss: 0.486993, accuracy: 0.757647, val loss: 0.525728, val accuracy: 0.726667 -- epoch time: 9.53
# 14:  loss: 0.481326, accuracy: 0.765294, val loss: 0.484873, val accuracy: 0.753333 -- epoch time: 8.60
# Se mejoró el loss de 0.5074142813682556 a 0.48487284779548645
# 15:  loss: 0.457080, accuracy: 0.782353, val loss: 0.482803, val accuracy: 0.790000 -- epoch time: 8.48
# Se mejoró el loss de 0.48487284779548645 a 0.4828026294708252
# 16:  loss: 0.433946, accuracy: 0.794706, val loss: 0.465136, val accuracy: 0.766667 -- epoch time: 8.45
# Se mejoró el loss de 0.4828026294708252 a 0.46513646841049194
# 17:  loss: 0.427108, accuracy: 0.798824, val loss: 0.459027, val accuracy: 0.773333 -- epoch time: 8.53
# Se mejoró el loss de 0.46513646841049194 a 0.4590272009372711
# 18:  loss: 0.399485, accuracy: 0.823529, val loss: 0.480170, val accuracy: 0.756667 -- epoch time: 8.43
# 19:  loss: 0.383973, accuracy: 0.827059, val loss: 0.473825, val accuracy: 0.763333 -- epoch time: 8.49
# 20:  loss: 0.371307, accuracy: 0.837647, val loss: 0.474463, val accuracy: 0.780000 -- epoch time: 9.57
# 21:  loss: 0.345821, accuracy: 0.839412, val loss: 0.468886, val accuracy: 0.780000 -- epoch time: 8.50
# 22:  loss: 0.319400, accuracy: 0.867647, val loss: 0.499523, val accuracy: 0.793333 -- epoch time: 8.47
# 23:  loss: 0.330340, accuracy: 0.859412, val loss: 0.494447, val accuracy: 0.746667 -- epoch time: 8.44
# 24:  loss: 0.283277, accuracy: 0.880000, val loss: 0.529601, val accuracy: 0.763333 -- epoch time: 8.48
# 25:  loss: 0.279132, accuracy: 0.885882, val loss: 0.509779, val accuracy: 0.776667 -- epoch time: 8.40
# 26:  loss: 0.259456, accuracy: 0.897059, val loss: 0.479752, val accuracy: 0.796667 -- epoch time: 9.54
# 27:  loss: 0.221413, accuracy: 0.913529, val loss: 0.496462, val accuracy: 0.796667 -- epoch time: 8.44
# 28:  loss: 0.202996, accuracy: 0.925882, val loss: 0.524036, val accuracy: 0.783333 -- epoch time: 8.50
# 29:  loss: 0.189890, accuracy: 0.927059, val loss: 0.588888, val accuracy: 0.756667 -- epoch time: 8.52
# time: 262.65

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# Con un LR de 1e-4 se activa el **early stopping** para evitar el overfitting en la época 18, logrando resultados ligeramente peores que con un LR de 5e-5, pues en validación el loss llega a 0.459 (0.4218 antes) con un accuracy de 77.33% (79% antes).

# %% [markdown]
# En este punto es necesario tomar ciertas decisiones con respecto a los criterios de escogencia del mejor modelo:
# - Podemos escoger el mejor modelo en cuanto al menor loss de validación alcanzado. Esta situación corresponde al modelo con LR de 5e-5 en la época 39, con un loss de 0.4218 aunque manchado de overfitting
# - Podemos buscar un compromiso entre evitar overfitting y calidad de la predicción, sacrificando un poco el loss por una mayor estabilidad. Esta situación corresponde al modelo con LR de 1e-4 en la época 18.
#
# Lo ideal es que los dos criterios ocurran para los mismos hiper-parámetros en la misma época, pero no siempre va a ser así, aunque se puede tratar de tener los dos criterios en cuenta al tiempo.
#
# En esta caso, vamos a escoger el modelo que satisface la segunda característica.  No es necesario reentrenarlo pues el mejor modelo fue retornado por el método de entrenamiento

# %%
modelo_base = modelo_base_1e4

# %% [markdown]
# Evaluamos entonces el dataset de test con el modelo escogido.

# %%
test_loss, test_acc = eval_model(modelo_base, test_data_loader_small)
print(f"El loss de test es {test_loss}, y el accuracy de test es de {test_acc:.3f}. ")
torch.save(modelo_base, "cats_and_dogs_small.pth")
# Out:
# El loss de test es 0.5502729597091675, y el accuracy de test es de 0.736.

# %% [markdown]
# Vemos que el accuracy sobre el test set es de 73.6\%, relativamente cercano al 77.33\% estimado sobre el validation set, y no tan lejos del 79.88% del training set.

# %% [markdown]
# ## Parte 5. Dataset reducido -- modelo con Dropout y batch normalization

# %% [markdown]
# ### Dropout

# %% [markdown]
# Hay varias heramientas para combatir el **overfitting**, entre ellas, la regularización usando capas de tipo ```nn.Dropout```.
# Estas capas se pueden agregar antes de las capas ```nn.Linear```, y tienen como labor apagar (poner en ceros), **solo durante el entrenamiento** una proporción de las entradas, con el objetivo de incentivar la no dependencia de algunas neuronas en particular, creando múltiples caminos en la red que permitan la identificaciones de patrones de mapeo entre inputs y outputs del modelo, reduciendo así el overfitting.
# Si es establece una tasa de 0.5 de drouput, el 50% de las entradas de una capa ```nn.Dropout``` se ponen en cero durante el entrenamiento, dejando pasar las demás con sus valores reescalados, de tal manera que la suma de todos los inputs quede estable.
#
# Esta capa (asi como otras como la ```nn.BatchNormalization```) presentan un comportamiento diferente para el **entrenamiento** del modelo, al requerido durante el uso del modelo para **inferencia**. Es necesario indicarle a PyTorch el tipo de uso que se está dando al modelo, llamando a los métodos ```train()``` y ```eval```, para entrenamiento de los parámetros, y evaluación del dataset de validación (o test), respectivamente.

# %%
class BinaryImageClassifierBase_Dropout(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding="valid")
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding="valid")
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding="valid")
        self.maxpool3 = nn.MaxPool2d(kernel_size=2)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding="valid")
        self.maxpool4 = nn.MaxPool2d(kernel_size=2)

        self.dropout1 = nn.Dropout(p=0.5)
        self.flatten = nn.Flatten()
        self.linear1 = nn.Linear(in_features=128*7*7, out_features=512)

        self.dropout2 = nn.Dropout(p=0.5)
        self.linear2 = nn.Linear(in_features=512, out_features=1)

    def forward(self, image):
        x = self.conv1(image)
        x = F.relu(x)
        x = self.maxpool1(x)

        x = self.conv2(x)
        x = F.relu(x)
        x = self.maxpool2(x)

        x = self.conv3(x)
        x = F.relu(x)
        x = self.maxpool3(x)

        x = self.conv4(x)
        x = F.relu(x)
        x = self.maxpool4(x)

        x = self.dropout1(x)
        x = self.flatten(x)
        x = self.linear1(x)
        x = F.relu(x)

        x = self.dropout2(x)
        logits = self.linear2(x)
        probas = torch.sigmoid(logits)

        return probas

# %%
modelo_base_dropout = BinaryImageClassifierBase_Dropout()
modelo_base_dropout.to(DEVICE)
# Out:
# BinaryImageClassifierBase_Dropout(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear1): Linear(in_features=6272, out_features=512, bias=True)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (linear2): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
summary(modelo_base_dropout, (3, 150, 150))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 148, 148]             896
#          MaxPool2d-2           [-1, 32, 74, 74]               0
#             Conv2d-3           [-1, 64, 72, 72]          18,496
#          MaxPool2d-4           [-1, 64, 36, 36]               0
#             Conv2d-5          [-1, 128, 34, 34]          73,856
#          MaxPool2d-6          [-1, 128, 17, 17]               0
#             Conv2d-7          [-1, 128, 15, 15]         147,584
#          MaxPool2d-8            [-1, 128, 7, 7]               0
#            Dropout-9            [-1, 128, 7, 7]               0
#           Flatten-10                 [-1, 6272]               0
#            Linear-11                  [-1, 512]       3,211,776
#           Dropout-12                  [-1, 512]               0
#            Linear-13                    [-1, 1]             513
# ================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.26
# Forward/backward pass size (MB): 11.63
# Params size (MB): 13.17
# Estimated Total Size (MB): 25.06
# ----------------------------------------------------------------

# %% [markdown]
# Vemos que las capas de dropout no tienen parámetros entrenables

# %% [markdown]
# El efecto esperado que tendrá el dropout en el entrenamiento es:
# - las diferencias entre el training y el validation set en términos del loss no deberían crecer tan rápido, reduciendo el overfitting
# - se puede llegar a demorar más épocas en llegar a un loss mínimo de validación. Vamos a aumentar el número de épocas.
# - puede que el loss mínimo de validación sea mejor que sin dropout (o puede que no se logre).
#
# Si bien existen capas ```nn.Dropout2d``` que se encargan de aleatoriamente apagar canales enteros (**spatial dropout**), que podrían ser utilizados antes de llamar a capas convolucionales, en este ejercicio solo consideramos capas ```nn.Dropout``` a aplicar antes de las capas lineales. Como ejercicio podrían agregar las capas 2d.
#
# Buscamos el mejor learning rate, aplicamos early stopping sobre la paciencia del val loss.

# %%
start = time.time()
reset_seed()
modelo_base_dropout_1e5, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_Dropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-5, epocas=70, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.693098, accuracy: 0.501765, val loss: 0.693514, val accuracy: 0.483333 -- epoch time: 8.58
# Se mejoró el loss de inf a 0.6935136914253235
# 1:  loss: 0.693085, accuracy: 0.502941, val loss: 0.693062, val accuracy: 0.483333 -- epoch time: 8.50
# Se mejoró el loss de 0.6935136914253235 a 0.6930617690086365
# 2:  loss: 0.692521, accuracy: 0.502941, val loss: 0.692644, val accuracy: 0.483333 -- epoch time: 8.60
# Se mejoró el loss de 0.6930617690086365 a 0.692644476890564
# 3:  loss: 0.692000, accuracy: 0.502353, val loss: 0.691843, val accuracy: 0.483333 -- epoch time: 8.61
# Se mejoró el loss de 0.692644476890564 a 0.6918425559997559
# 4:  loss: 0.691366, accuracy: 0.510588, val loss: 0.691460, val accuracy: 0.483333 -- epoch time: 9.73
# Se mejoró el loss de 0.6918425559997559 a 0.6914597749710083
# 5:  loss: 0.689313, accuracy: 0.518824, val loss: 0.687529, val accuracy: 0.523333 -- epoch time: 8.73
# Se mejoró el loss de 0.6914597749710083 a 0.6875291466712952
# 6:  loss: 0.686407, accuracy: 0.557059, val loss: 0.684849, val accuracy: 0.516667 -- epoch time: 9.45
# Se mejoró el loss de 0.6875291466712952 a 0.6848494410514832
# 7:  loss: 0.682705, accuracy: 0.578824, val loss: 0.676072, val accuracy: 0.613333 -- epoch time: 8.57
# Se mejoró el loss de 0.6848494410514832 a 0.6760715842247009
# 8:  loss: 0.676445, accuracy: 0.595294, val loss: 0.669839, val accuracy: 0.590000 -- epoch time: 8.44
# Se mejoró el loss de 0.6760715842247009 a 0.6698390245437622
# 9:  loss: 0.668233, accuracy: 0.607647, val loss: 0.657607, val accuracy: 0.670000 -- epoch time: 8.58
# Se mejoró el loss de 0.6698390245437622 a 0.6576072573661804
# 10:  loss: 0.664957, accuracy: 0.608824, val loss: 0.651834, val accuracy: 0.633333 -- epoch time: 9.94
# Se mejoró el loss de 0.6576072573661804 a 0.6518341302871704
# 11:  loss: 0.654894, accuracy: 0.610000, val loss: 0.642208, val accuracy: 0.656667 -- epoch time: 9.65
# Se mejoró el loss de 0.6518341302871704 a 0.6422078013420105
# 12:  loss: 0.647520, accuracy: 0.632353, val loss: 0.640141, val accuracy: 0.636667 -- epoch time: 8.50
# Se mejoró el loss de 0.6422078013420105 a 0.6401405334472656
# 13:  loss: 0.643191, accuracy: 0.630588, val loss: 0.628312, val accuracy: 0.646667 -- epoch time: 8.46
# Se mejoró el loss de 0.6401405334472656 a 0.6283121109008789
# 14:  loss: 0.641575, accuracy: 0.635294, val loss: 0.623268, val accuracy: 0.656667 -- epoch time: 8.56
# Se mejoró el loss de 0.6283121109008789 a 0.6232679486274719
# 15:  loss: 0.637383, accuracy: 0.634118, val loss: 0.621445, val accuracy: 0.653333 -- epoch time: 9.08
# Se mejoró el loss de 0.6232679486274719 a 0.6214452385902405
# 16:  loss: 0.634099, accuracy: 0.640588, val loss: 0.618532, val accuracy: 0.650000 -- epoch time: 8.69
# Se mejoró el loss de 0.6214452385902405 a 0.6185315251350403
# 17:  loss: 0.635599, accuracy: 0.630000, val loss: 0.626193, val accuracy: 0.656667 -- epoch time: 8.47
# 18:  loss: 0.631571, accuracy: 0.640000, val loss: 0.615099, val accuracy: 0.653333 -- epoch time: 9.24
# Se mejoró el loss de 0.6185315251350403 a 0.6150985360145569
# 19:  loss: 0.628121, accuracy: 0.642941, val loss: 0.613412, val accuracy: 0.656667 -- epoch time: 8.62
# Se mejoró el loss de 0.6150985360145569 a 0.6134122014045715
# 20:  loss: 0.626196, accuracy: 0.653529, val loss: 0.614307, val accuracy: 0.663333 -- epoch time: 8.61
# 21:  loss: 0.624929, accuracy: 0.651176, val loss: 0.615520, val accuracy: 0.663333 -- epoch time: 9.26
# 22:  loss: 0.624626, accuracy: 0.645294, val loss: 0.609885, val accuracy: 0.646667 -- epoch time: 8.51
# Se mejoró el loss de 0.6134122014045715 a 0.609885036945343
# 23:  loss: 0.620611, accuracy: 0.647059, val loss: 0.612583, val accuracy: 0.666667 -- epoch time: 8.52
# 24:  loss: 0.626536, accuracy: 0.644706, val loss: 0.611971, val accuracy: 0.666667 -- epoch time: 8.45
# 25:  loss: 0.620494, accuracy: 0.655294, val loss: 0.608641, val accuracy: 0.650000 -- epoch time: 8.54
# Se mejoró el loss de 0.609885036945343 a 0.6086412668228149
# 26:  loss: 0.616103, accuracy: 0.661765, val loss: 0.607730, val accuracy: 0.653333 -- epoch time: 8.48
# Se mejoró el loss de 0.6086412668228149 a 0.6077296137809753
# 27:  loss: 0.616886, accuracy: 0.654706, val loss: 0.607561, val accuracy: 0.660000 -- epoch time: 8.58
# Se mejoró el loss de 0.6077296137809753 a 0.6075609922409058
# 28:  loss: 0.613581, accuracy: 0.656471, val loss: 0.618986, val accuracy: 0.663333 -- epoch time: 9.68
# 29:  loss: 0.613280, accuracy: 0.661765, val loss: 0.610989, val accuracy: 0.683333 -- epoch time: 8.65
# 30:  loss: 0.614425, accuracy: 0.659412, val loss: 0.609350, val accuracy: 0.676667 -- epoch time: 8.54
# 31:  loss: 0.616695, accuracy: 0.657059, val loss: 0.606239, val accuracy: 0.656667 -- epoch time: 8.48
# Se mejoró el loss de 0.6075609922409058 a 0.606238603591919
# 32:  loss: 0.611795, accuracy: 0.661176, val loss: 0.606508, val accuracy: 0.660000 -- epoch time: 8.62
# 33:  loss: 0.611319, accuracy: 0.658824, val loss: 0.606829, val accuracy: 0.653333 -- epoch time: 9.35
# 34:  loss: 0.607845, accuracy: 0.664118, val loss: 0.616167, val accuracy: 0.656667 -- epoch time: 8.52
# 35:  loss: 0.605056, accuracy: 0.679412, val loss: 0.606703, val accuracy: 0.673333 -- epoch time: 8.57
# 36:  loss: 0.606208, accuracy: 0.664706, val loss: 0.611619, val accuracy: 0.670000 -- epoch time: 8.67
# 37:  loss: 0.604153, accuracy: 0.675882, val loss: 0.604862, val accuracy: 0.666667 -- epoch time: 9.39
# Se mejoró el loss de 0.606238603591919 a 0.6048615574836731
# 38:  loss: 0.606611, accuracy: 0.674706, val loss: 0.605782, val accuracy: 0.663333 -- epoch time: 8.62
# 39:  loss: 0.603443, accuracy: 0.666471, val loss: 0.607059, val accuracy: 0.670000 -- epoch time: 9.29
# 40:  loss: 0.601927, accuracy: 0.667059, val loss: 0.614177, val accuracy: 0.656667 -- epoch time: 8.54
# 41:  loss: 0.600029, accuracy: 0.673529, val loss: 0.614400, val accuracy: 0.673333 -- epoch time: 8.54
# 42:  loss: 0.598610, accuracy: 0.674706, val loss: 0.603641, val accuracy: 0.676667 -- epoch time: 8.62
# Se mejoró el loss de 0.6048615574836731 a 0.6036412715911865
# 43:  loss: 0.598159, accuracy: 0.673529, val loss: 0.605161, val accuracy: 0.670000 -- epoch time: 8.55
# 44:  loss: 0.598023, accuracy: 0.667059, val loss: 0.602595, val accuracy: 0.676667 -- epoch time: 8.62
# Se mejoró el loss de 0.6036412715911865 a 0.6025947332382202
# 45:  loss: 0.599748, accuracy: 0.671176, val loss: 0.602308, val accuracy: 0.666667 -- epoch time: 9.58
# Se mejoró el loss de 0.6025947332382202 a 0.6023077368736267
# 46:  loss: 0.597555, accuracy: 0.673529, val loss: 0.600985, val accuracy: 0.676667 -- epoch time: 8.50
# Se mejoró el loss de 0.6023077368736267 a 0.6009846329689026
# 47:  loss: 0.593960, accuracy: 0.678824, val loss: 0.602048, val accuracy: 0.673333 -- epoch time: 8.66
# 48:  loss: 0.591619, accuracy: 0.684706, val loss: 0.599395, val accuracy: 0.686667 -- epoch time: 8.54
# Se mejoró el loss de 0.6009846329689026 a 0.5993954539299011
# 49:  loss: 0.591817, accuracy: 0.671176, val loss: 0.598948, val accuracy: 0.683333 -- epoch time: 8.47
# Se mejoró el loss de 0.5993954539299011 a 0.5989475250244141
# 50:  loss: 0.592389, accuracy: 0.685294, val loss: 0.598214, val accuracy: 0.690000 -- epoch time: 8.52
# Se mejoró el loss de 0.5989475250244141 a 0.5982139110565186
# 51:  loss: 0.590623, accuracy: 0.683529, val loss: 0.597971, val accuracy: 0.683333 -- epoch time: 8.51
# Se mejoró el loss de 0.5982139110565186 a 0.5979712009429932
# 52:  loss: 0.589456, accuracy: 0.681176, val loss: 0.599901, val accuracy: 0.673333 -- epoch time: 9.55
# 53:  loss: 0.584890, accuracy: 0.684706, val loss: 0.595574, val accuracy: 0.686667 -- epoch time: 8.51
# Se mejoró el loss de 0.5979712009429932 a 0.5955735445022583
# 54:  loss: 0.588501, accuracy: 0.674706, val loss: 0.599541, val accuracy: 0.670000 -- epoch time: 8.52
# 55:  loss: 0.585586, accuracy: 0.684706, val loss: 0.594446, val accuracy: 0.690000 -- epoch time: 8.55
# Se mejoró el loss de 0.5955735445022583 a 0.5944464206695557
# 56:  loss: 0.588408, accuracy: 0.683529, val loss: 0.593332, val accuracy: 0.696667 -- epoch time: 8.57
# Se mejoró el loss de 0.5944464206695557 a 0.5933315753936768
# 57:  loss: 0.583567, accuracy: 0.694118, val loss: 0.605627, val accuracy: 0.670000 -- epoch time: 9.30
# 58:  loss: 0.582271, accuracy: 0.687647, val loss: 0.591353, val accuracy: 0.693333 -- epoch time: 8.53
# Se mejoró el loss de 0.5933315753936768 a 0.5913528800010681
# 59:  loss: 0.582628, accuracy: 0.690000, val loss: 0.590159, val accuracy: 0.693333 -- epoch time: 8.53
# Se mejoró el loss de 0.5913528800010681 a 0.5901585221290588
# 60:  loss: 0.579475, accuracy: 0.687647, val loss: 0.589434, val accuracy: 0.683333 -- epoch time: 8.54
# Se mejoró el loss de 0.5901585221290588 a 0.5894343256950378
# 61:  loss: 0.580728, accuracy: 0.692941, val loss: 0.588238, val accuracy: 0.693333 -- epoch time: 8.53
# Se mejoró el loss de 0.5894343256950378 a 0.5882375836372375
# 62:  loss: 0.581977, accuracy: 0.680000, val loss: 0.587229, val accuracy: 0.693333 -- epoch time: 8.57
# Se mejoró el loss de 0.5882375836372375 a 0.5872288942337036
# 63:  loss: 0.586519, accuracy: 0.675294, val loss: 0.586902, val accuracy: 0.693333 -- epoch time: 9.25
# Se mejoró el loss de 0.5872288942337036 a 0.5869017839431763
# 64:  loss: 0.577088, accuracy: 0.692353, val loss: 0.585324, val accuracy: 0.690000 -- epoch time: 9.56
# Se mejoró el loss de 0.5869017839431763 a 0.5853235721588135
# 65:  loss: 0.574700, accuracy: 0.701765, val loss: 0.586207, val accuracy: 0.676667 -- epoch time: 8.55
# 66:  loss: 0.577240, accuracy: 0.693529, val loss: 0.583371, val accuracy: 0.696667 -- epoch time: 8.56
# Se mejoró el loss de 0.5853235721588135 a 0.583371102809906
# 67:  loss: 0.576690, accuracy: 0.697059, val loss: 0.582868, val accuracy: 0.696667 -- epoch time: 8.50
# Se mejoró el loss de 0.583371102809906 a 0.5828681588172913
# 68:  loss: 0.570044, accuracy: 0.697647, val loss: 0.582676, val accuracy: 0.696667 -- epoch time: 8.57
# Se mejoró el loss de 0.5828681588172913 a 0.5826758742332458
# 69:  loss: 0.572292, accuracy: 0.701176, val loss: 0.581500, val accuracy: 0.690000 -- epoch time: 9.60
# Se mejoró el loss de 0.5826758742332458 a 0.5814998745918274
# time: 616.30

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# Vemos que el overfitting está bastante controlado, aunque se demora muchas épocas en reducirse el loss. Intentamos con un LR mayor.

# %%
start = time.time()
reset_seed()
modelo_base_dropout_5e5, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_Dropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=5e-5, epocas=50, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.693302, accuracy: 0.503529, val loss: 0.692635, val accuracy: 0.483333 -- epoch time: 8.68
# Se mejoró el loss de inf a 0.6926354765892029
# 1:  loss: 0.693252, accuracy: 0.508235, val loss: 0.690714, val accuracy: 0.626667 -- epoch time: 8.68
# Se mejoró el loss de 0.6926354765892029 a 0.6907142996788025
# 2:  loss: 0.688629, accuracy: 0.545294, val loss: 0.680132, val accuracy: 0.556667 -- epoch time: 8.58
# Se mejoró el loss de 0.6907142996788025 a 0.6801316738128662
# 3:  loss: 0.679061, accuracy: 0.568824, val loss: 0.665777, val accuracy: 0.603333 -- epoch time: 8.55
# Se mejoró el loss de 0.6801316738128662 a 0.6657766699790955
# 4:  loss: 0.662156, accuracy: 0.615294, val loss: 0.636439, val accuracy: 0.653333 -- epoch time: 8.59
# Se mejoró el loss de 0.6657766699790955 a 0.6364393830299377
# 5:  loss: 0.643757, accuracy: 0.638824, val loss: 0.619218, val accuracy: 0.670000 -- epoch time: 9.63
# Se mejoró el loss de 0.6364393830299377 a 0.6192178726196289
# 6:  loss: 0.627870, accuracy: 0.652941, val loss: 0.621693, val accuracy: 0.650000 -- epoch time: 8.54
# 7:  loss: 0.630612, accuracy: 0.645294, val loss: 0.620223, val accuracy: 0.670000 -- epoch time: 8.68
# 8:  loss: 0.625459, accuracy: 0.640000, val loss: 0.611357, val accuracy: 0.680000 -- epoch time: 8.67
# Se mejoró el loss de 0.6192178726196289 a 0.6113571524620056
# 9:  loss: 0.612851, accuracy: 0.668824, val loss: 0.605374, val accuracy: 0.676667 -- epoch time: 8.60
# Se mejoró el loss de 0.6113571524620056 a 0.6053739786148071
# 10:  loss: 0.615559, accuracy: 0.667647, val loss: 0.607049, val accuracy: 0.676667 -- epoch time: 8.62
# 11:  loss: 0.605043, accuracy: 0.677059, val loss: 0.599415, val accuracy: 0.673333 -- epoch time: 9.63
# Se mejoró el loss de 0.6053739786148071 a 0.5994153618812561
# 12:  loss: 0.593921, accuracy: 0.688235, val loss: 0.610873, val accuracy: 0.666667 -- epoch time: 8.69
# 13:  loss: 0.586233, accuracy: 0.680000, val loss: 0.583220, val accuracy: 0.693333 -- epoch time: 9.60
# Se mejoró el loss de 0.5994153618812561 a 0.5832201242446899
# 14:  loss: 0.578997, accuracy: 0.689412, val loss: 0.572188, val accuracy: 0.686667 -- epoch time: 8.57
# Se mejoró el loss de 0.5832201242446899 a 0.5721875429153442
# 15:  loss: 0.572027, accuracy: 0.708235, val loss: 0.572490, val accuracy: 0.693333 -- epoch time: 8.67
# 16:  loss: 0.563466, accuracy: 0.711176, val loss: 0.550101, val accuracy: 0.700000 -- epoch time: 9.74
# Se mejoró el loss de 0.5721875429153442 a 0.5501006245613098
# 17:  loss: 0.556122, accuracy: 0.708824, val loss: 0.557656, val accuracy: 0.720000 -- epoch time: 8.67
# 18:  loss: 0.550559, accuracy: 0.714706, val loss: 0.545960, val accuracy: 0.716667 -- epoch time: 8.55
# Se mejoró el loss de 0.5501006245613098 a 0.5459597706794739
# 19:  loss: 0.535539, accuracy: 0.731176, val loss: 0.548719, val accuracy: 0.720000 -- epoch time: 8.59
# 20:  loss: 0.529223, accuracy: 0.725294, val loss: 0.550619, val accuracy: 0.686667 -- epoch time: 8.61
# 21:  loss: 0.528936, accuracy: 0.733529, val loss: 0.532441, val accuracy: 0.736667 -- epoch time: 8.54
# Se mejoró el loss de 0.5459597706794739 a 0.5324414968490601
# 22:  loss: 0.514901, accuracy: 0.738824, val loss: 0.516706, val accuracy: 0.733333 -- epoch time: 9.61
# Se mejoró el loss de 0.5324414968490601 a 0.5167063474655151
# 23:  loss: 0.513454, accuracy: 0.738235, val loss: 0.518126, val accuracy: 0.723333 -- epoch time: 8.56
# 24:  loss: 0.509446, accuracy: 0.750588, val loss: 0.519559, val accuracy: 0.733333 -- epoch time: 8.61
# 25:  loss: 0.498911, accuracy: 0.755294, val loss: 0.519573, val accuracy: 0.753333 -- epoch time: 8.55
# 26:  loss: 0.494829, accuracy: 0.758235, val loss: 0.509238, val accuracy: 0.736667 -- epoch time: 8.65
# Se mejoró el loss de 0.5167063474655151 a 0.509238064289093
# 27:  loss: 0.490488, accuracy: 0.754118, val loss: 0.502874, val accuracy: 0.750000 -- epoch time: 8.60
# Se mejoró el loss de 0.509238064289093 a 0.5028736591339111
# 28:  loss: 0.483112, accuracy: 0.764118, val loss: 0.545120, val accuracy: 0.726667 -- epoch time: 13.36
# 29:  loss: 0.467866, accuracy: 0.768824, val loss: 0.501190, val accuracy: 0.753333 -- epoch time: 12.21
# Se mejoró el loss de 0.5028736591339111 a 0.5011900663375854
# 30:  loss: 0.477307, accuracy: 0.758824, val loss: 0.509002, val accuracy: 0.756667 -- epoch time: 8.64
# 31:  loss: 0.468278, accuracy: 0.774118, val loss: 0.493071, val accuracy: 0.736667 -- epoch time: 8.59
# Se mejoró el loss de 0.5011900663375854 a 0.4930711090564728
# 32:  loss: 0.459776, accuracy: 0.780588, val loss: 0.489347, val accuracy: 0.746667 -- epoch time: 8.58
# Se mejoró el loss de 0.4930711090564728 a 0.48934710025787354
# 33:  loss: 0.453415, accuracy: 0.766471, val loss: 0.479023, val accuracy: 0.760000 -- epoch time: 9.55
# Se mejoró el loss de 0.48934710025787354 a 0.4790225327014923
# 34:  loss: 0.438803, accuracy: 0.789412, val loss: 0.481525, val accuracy: 0.766667 -- epoch time: 8.71
# 35:  loss: 0.428660, accuracy: 0.797059, val loss: 0.467883, val accuracy: 0.756667 -- epoch time: 8.63
# Se mejoró el loss de 0.4790225327014923 a 0.46788331866264343
# 36:  loss: 0.428225, accuracy: 0.799412, val loss: 0.457661, val accuracy: 0.770000 -- epoch time: 8.54
# Se mejoró el loss de 0.46788331866264343 a 0.45766082406044006
# 37:  loss: 0.427390, accuracy: 0.788824, val loss: 0.484465, val accuracy: 0.746667 -- epoch time: 8.68
# 38:  loss: 0.416413, accuracy: 0.813529, val loss: 0.469171, val accuracy: 0.770000 -- epoch time: 9.62
# 39:  loss: 0.431133, accuracy: 0.790000, val loss: 0.457185, val accuracy: 0.780000 -- epoch time: 9.68
# Se mejoró el loss de 0.45766082406044006 a 0.45718491077423096
# 40:  loss: 0.406407, accuracy: 0.808824, val loss: 0.453843, val accuracy: 0.766667 -- epoch time: 8.74
# Se mejoró el loss de 0.45718491077423096 a 0.4538425803184509
# 41:  loss: 0.396517, accuracy: 0.810588, val loss: 0.455175, val accuracy: 0.766667 -- epoch time: 8.59
# 42:  loss: 0.417086, accuracy: 0.807647, val loss: 0.483582, val accuracy: 0.730000 -- epoch time: 8.57
# 43:  loss: 0.402787, accuracy: 0.811176, val loss: 0.484095, val accuracy: 0.770000 -- epoch time: 8.68
# 44:  loss: 0.382284, accuracy: 0.828235, val loss: 0.447181, val accuracy: 0.786667 -- epoch time: 8.68
# Se mejoró el loss de 0.4538425803184509 a 0.4471806585788727
# 45:  loss: 0.380645, accuracy: 0.821176, val loss: 0.460493, val accuracy: 0.760000 -- epoch time: 9.67
# 46:  loss: 0.378776, accuracy: 0.827647, val loss: 0.458397, val accuracy: 0.780000 -- epoch time: 8.63
# 47:  loss: 0.365694, accuracy: 0.831176, val loss: 0.448656, val accuracy: 0.756667 -- epoch time: 8.69
# 48:  loss: 0.367553, accuracy: 0.821765, val loss: 0.429437, val accuracy: 0.780000 -- epoch time: 8.56
# Se mejoró el loss de 0.4471806585788727 a 0.4294370710849762
# 49:  loss: 0.372702, accuracy: 0.828824, val loss: 0.434616, val accuracy: 0.776667 -- epoch time: 8.67
# time: 449.83

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# Vemos que después de la época 25 comenzamos a apreciar un overfitting, aunque se sigue mejorando el loss de validación.

# %%
start = time.time()
reset_seed()
modelo_base_dropout_1e4, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_Dropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-4, epocas=50, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.693706, accuracy: 0.505294, val loss: 0.692491, val accuracy: 0.523333 -- epoch time: 11.30
# Se mejoró el loss de inf a 0.692490816116333
# 1:  loss: 0.692627, accuracy: 0.515294, val loss: 0.688823, val accuracy: 0.520000 -- epoch time: 9.39
# Se mejoró el loss de 0.692490816116333 a 0.6888230443000793
# 2:  loss: 0.680413, accuracy: 0.574706, val loss: 0.682720, val accuracy: 0.533333 -- epoch time: 8.69
# Se mejoró el loss de 0.6888230443000793 a 0.6827200651168823
# 3:  loss: 0.672552, accuracy: 0.584706, val loss: 0.655345, val accuracy: 0.633333 -- epoch time: 8.60
# Se mejoró el loss de 0.6827200651168823 a 0.6553447842597961
# 4:  loss: 0.654120, accuracy: 0.623529, val loss: 0.632806, val accuracy: 0.666667 -- epoch time: 8.56
# Se mejoró el loss de 0.6553447842597961 a 0.6328062415122986
# 5:  loss: 0.640761, accuracy: 0.645882, val loss: 0.621226, val accuracy: 0.673333 -- epoch time: 8.57
# Se mejoró el loss de 0.6328062415122986 a 0.621225893497467
# 6:  loss: 0.624353, accuracy: 0.664706, val loss: 0.628202, val accuracy: 0.646667 -- epoch time: 9.67
# 7:  loss: 0.623692, accuracy: 0.648824, val loss: 0.611596, val accuracy: 0.660000 -- epoch time: 8.57
# Se mejoró el loss de 0.621225893497467 a 0.6115957498550415
# 8:  loss: 0.610367, accuracy: 0.662353, val loss: 0.616542, val accuracy: 0.666667 -- epoch time: 9.60
# 9:  loss: 0.602367, accuracy: 0.680588, val loss: 0.595425, val accuracy: 0.673333 -- epoch time: 8.62
# Se mejoró el loss de 0.6115957498550415 a 0.5954252481460571
# 10:  loss: 0.589872, accuracy: 0.689412, val loss: 0.578440, val accuracy: 0.700000 -- epoch time: 8.65
# Se mejoró el loss de 0.5954252481460571 a 0.5784396529197693
# 11:  loss: 0.578378, accuracy: 0.690000, val loss: 0.564206, val accuracy: 0.713333 -- epoch time: 8.71
# Se mejoró el loss de 0.5784396529197693 a 0.5642062425613403
# 12:  loss: 0.557128, accuracy: 0.717059, val loss: 0.555985, val accuracy: 0.716667 -- epoch time: 9.96
# Se mejoró el loss de 0.5642062425613403 a 0.5559847354888916
# 13:  loss: 0.548080, accuracy: 0.711765, val loss: 0.539090, val accuracy: 0.703333 -- epoch time: 8.56
# Se mejoró el loss de 0.5559847354888916 a 0.539090096950531
# 14:  loss: 0.535956, accuracy: 0.723529, val loss: 0.523073, val accuracy: 0.736667 -- epoch time: 8.54
# Se mejoró el loss de 0.539090096950531 a 0.5230734944343567
# 15:  loss: 0.526037, accuracy: 0.736471, val loss: 0.545228, val accuracy: 0.726667 -- epoch time: 8.56
# 16:  loss: 0.515575, accuracy: 0.737059, val loss: 0.498122, val accuracy: 0.763333 -- epoch time: 8.54
# Se mejoró el loss de 0.5230734944343567 a 0.4981216490268707
# 17:  loss: 0.501178, accuracy: 0.749412, val loss: 0.493163, val accuracy: 0.756667 -- epoch time: 8.69
# Se mejoró el loss de 0.4981216490268707 a 0.4931633174419403
# 18:  loss: 0.482502, accuracy: 0.767059, val loss: 0.489800, val accuracy: 0.746667 -- epoch time: 9.44
# Se mejoró el loss de 0.4931633174419403 a 0.4897996187210083
# 19:  loss: 0.478209, accuracy: 0.765882, val loss: 0.489330, val accuracy: 0.766667 -- epoch time: 8.64
# Se mejoró el loss de 0.4897996187210083 a 0.489329993724823
# 20:  loss: 0.466273, accuracy: 0.769412, val loss: 0.501510, val accuracy: 0.746667 -- epoch time: 8.71
# 21:  loss: 0.453143, accuracy: 0.774118, val loss: 0.474449, val accuracy: 0.773333 -- epoch time: 8.56
# Se mejoró el loss de 0.489329993724823 a 0.47444871068000793
# 22:  loss: 0.441627, accuracy: 0.785882, val loss: 0.455090, val accuracy: 0.786667 -- epoch time: 8.56
# Se mejoró el loss de 0.47444871068000793 a 0.4550897777080536
# 23:  loss: 0.433025, accuracy: 0.789412, val loss: 0.468826, val accuracy: 0.763333 -- epoch time: 9.34
# 24:  loss: 0.416503, accuracy: 0.808824, val loss: 0.481627, val accuracy: 0.773333 -- epoch time: 8.57
# 25:  loss: 0.402240, accuracy: 0.812353, val loss: 0.452398, val accuracy: 0.773333 -- epoch time: 8.52
# Se mejoró el loss de 0.4550897777080536 a 0.45239824056625366
# 26:  loss: 0.386004, accuracy: 0.824118, val loss: 0.448331, val accuracy: 0.770000 -- epoch time: 8.57
# Se mejoró el loss de 0.45239824056625366 a 0.448331356048584
# 27:  loss: 0.382078, accuracy: 0.829412, val loss: 0.433060, val accuracy: 0.786667 -- epoch time: 8.60
# Se mejoró el loss de 0.448331356048584 a 0.4330595135688782
# 28:  loss: 0.361915, accuracy: 0.838824, val loss: 0.495493, val accuracy: 0.740000 -- epoch time: 8.58
# 29:  loss: 0.341502, accuracy: 0.846471, val loss: 0.463980, val accuracy: 0.790000 -- epoch time: 9.74
# 30:  loss: 0.345973, accuracy: 0.850588, val loss: 0.516826, val accuracy: 0.746667 -- epoch time: 8.54
# 31:  loss: 0.320040, accuracy: 0.863529, val loss: 0.443119, val accuracy: 0.796667 -- epoch time: 8.60
# 32:  loss: 0.321431, accuracy: 0.858824, val loss: 0.404709, val accuracy: 0.813333 -- epoch time: 8.81
# Se mejoró el loss de 0.4330595135688782 a 0.404709130525589
# 33:  loss: 0.309512, accuracy: 0.867647, val loss: 0.416199, val accuracy: 0.803333 -- epoch time: 9.72
# 34:  loss: 0.291658, accuracy: 0.875294, val loss: 0.436813, val accuracy: 0.783333 -- epoch time: 8.58
# 35:  loss: 0.279817, accuracy: 0.875882, val loss: 0.425878, val accuracy: 0.816667 -- epoch time: 9.68
# 36:  loss: 0.261862, accuracy: 0.897059, val loss: 0.420741, val accuracy: 0.790000 -- epoch time: 8.58
# 37:  loss: 0.268719, accuracy: 0.888235, val loss: 0.487243, val accuracy: 0.756667 -- epoch time: 8.61
# 38:  loss: 0.249968, accuracy: 0.898824, val loss: 0.399329, val accuracy: 0.813333 -- epoch time: 8.65
# Se mejoró el loss de 0.404709130525589 a 0.3993290662765503
# 39:  loss: 0.240044, accuracy: 0.902353, val loss: 0.438276, val accuracy: 0.796667 -- epoch time: 8.81
# 40:  loss: 0.220052, accuracy: 0.915882, val loss: 0.425031, val accuracy: 0.803333 -- epoch time: 8.63
# 41:  loss: 0.209177, accuracy: 0.915294, val loss: 0.409426, val accuracy: 0.813333 -- epoch time: 9.58
# 42:  loss: 0.210812, accuracy: 0.917059, val loss: 0.436645, val accuracy: 0.800000 -- epoch time: 8.59
# 43:  loss: 0.201586, accuracy: 0.927059, val loss: 0.427601, val accuracy: 0.790000 -- epoch time: 8.63
# 44:  loss: 0.205539, accuracy: 0.914706, val loss: 0.446521, val accuracy: 0.803333 -- epoch time: 8.68
# 45:  loss: 0.181420, accuracy: 0.926471, val loss: 0.446110, val accuracy: 0.803333 -- epoch time: 9.00
# 46:  loss: 0.183615, accuracy: 0.924118, val loss: 0.463067, val accuracy: 0.803333 -- epoch time: 12.68
# 47:  loss: 0.184322, accuracy: 0.928235, val loss: 0.492351, val accuracy: 0.773333 -- epoch time: 8.89
# 48:  loss: 0.175876, accuracy: 0.932941, val loss: 0.423823, val accuracy: 0.810000 -- epoch time: 8.64
# 49:  loss: 0.152077, accuracy: 0.942941, val loss: 0.452899, val accuracy: 0.803333 -- epoch time: 8.58
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 449.24

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# Vemos que si bien el modelo sigue reduciendo el nivel de loss de validación después de la época 23, esta disminución se hace a una tasa mucho menor que la del loss de training, cayendo en overfitting.
# Nos interesaría parar en la época 23, en donde no hay overfitting, y llegamos a un loss de 0.4416/0.4551, con accuracies de 78.59%/78.67%.

# %%
start = time.time()
reset_seed()
modelo_base_dropout_5e4, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_Dropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=5e-4, epocas=50, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.694015, accuracy: 0.515882, val loss: 0.692567, val accuracy: 0.516667 -- epoch time: 8.65
# Se mejoró el loss de inf a 0.6925667524337769
# 1:  loss: 0.692288, accuracy: 0.536471, val loss: 0.684180, val accuracy: 0.576667 -- epoch time: 9.68
# Se mejoró el loss de 0.6925667524337769 a 0.6841798424720764
# 2:  loss: 0.680797, accuracy: 0.580588, val loss: 0.674254, val accuracy: 0.570000 -- epoch time: 8.70
# Se mejoró el loss de 0.6841798424720764 a 0.674253523349762
# 3:  loss: 0.671059, accuracy: 0.600588, val loss: 0.671657, val accuracy: 0.586667 -- epoch time: 8.61
# Se mejoró el loss de 0.674253523349762 a 0.6716572046279907
# 4:  loss: 0.654209, accuracy: 0.627059, val loss: 0.636644, val accuracy: 0.680000 -- epoch time: 8.53
# Se mejoró el loss de 0.6716572046279907 a 0.6366440653800964
# 5:  loss: 0.643880, accuracy: 0.619412, val loss: 0.640379, val accuracy: 0.616667 -- epoch time: 8.71
# 6:  loss: 0.624277, accuracy: 0.660000, val loss: 0.630701, val accuracy: 0.603333 -- epoch time: 8.63
# Se mejoró el loss de 0.6366440653800964 a 0.6307007074356079
# 7:  loss: 0.618814, accuracy: 0.651765, val loss: 0.588831, val accuracy: 0.670000 -- epoch time: 9.61
# Se mejoró el loss de 0.6307007074356079 a 0.5888314843177795
# 8:  loss: 0.588295, accuracy: 0.687647, val loss: 0.601648, val accuracy: 0.643333 -- epoch time: 8.55
# 9:  loss: 0.576205, accuracy: 0.695294, val loss: 0.584237, val accuracy: 0.706667 -- epoch time: 8.59
# Se mejoró el loss de 0.5888314843177795 a 0.5842373967170715
# 10:  loss: 0.563203, accuracy: 0.705882, val loss: 0.556370, val accuracy: 0.716667 -- epoch time: 8.60
# Se mejoró el loss de 0.5842373967170715 a 0.5563697218894958
# 11:  loss: 0.538616, accuracy: 0.720000, val loss: 0.534176, val accuracy: 0.746667 -- epoch time: 8.64
# Se mejoró el loss de 0.5563697218894958 a 0.5341755151748657
# 12:  loss: 0.526751, accuracy: 0.744118, val loss: 0.544062, val accuracy: 0.716667 -- epoch time: 9.75
# 13:  loss: 0.504169, accuracy: 0.741765, val loss: 0.560678, val accuracy: 0.673333 -- epoch time: 8.52
# 14:  loss: 0.490383, accuracy: 0.766471, val loss: 0.509380, val accuracy: 0.746667 -- epoch time: 8.56
# Se mejoró el loss de 0.5341755151748657 a 0.5093798041343689
# 15:  loss: 0.452161, accuracy: 0.784118, val loss: 0.506174, val accuracy: 0.753333 -- epoch time: 8.59
# Se mejoró el loss de 0.5093798041343689 a 0.5061743855476379
# 16:  loss: 0.421629, accuracy: 0.798235, val loss: 0.461673, val accuracy: 0.796667 -- epoch time: 8.54
# Se mejoró el loss de 0.5061743855476379 a 0.4616728723049164
# 17:  loss: 0.385678, accuracy: 0.818824, val loss: 0.487596, val accuracy: 0.766667 -- epoch time: 9.64
# 18:  loss: 0.382580, accuracy: 0.835294, val loss: 0.493585, val accuracy: 0.756667 -- epoch time: 9.64
# 19:  loss: 0.363588, accuracy: 0.842353, val loss: 0.478410, val accuracy: 0.793333 -- epoch time: 8.57
# 20:  loss: 0.319624, accuracy: 0.861176, val loss: 0.486088, val accuracy: 0.783333 -- epoch time: 8.56
# 21:  loss: 0.284272, accuracy: 0.880588, val loss: 0.490951, val accuracy: 0.763333 -- epoch time: 8.63
# 22:  loss: 0.269331, accuracy: 0.885294, val loss: 0.489303, val accuracy: 0.790000 -- epoch time: 8.55
# 23:  loss: 0.269568, accuracy: 0.879412, val loss: 0.473053, val accuracy: 0.803333 -- epoch time: 9.49
# 24:  loss: 0.236461, accuracy: 0.898235, val loss: 0.521356, val accuracy: 0.760000 -- epoch time: 8.53
# 25:  loss: 0.198562, accuracy: 0.920000, val loss: 0.549998, val accuracy: 0.776667 -- epoch time: 8.58
# 26:  loss: 0.197195, accuracy: 0.922941, val loss: 0.553078, val accuracy: 0.780000 -- epoch time: 8.53
# 27:  loss: 0.171779, accuracy: 0.925882, val loss: 0.565492, val accuracy: 0.783333 -- epoch time: 8.56
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 247.35

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# **Base**
#
# **0.00010**(18):  loss: 0.4271/0.4590/0.5503, accuracy: 78.88%/77.33%/73.60%
#
# **Dropout**
#
# **0.00001**(70):  loss: 0.5723/0.5815,    accuracy: 70.12%/69.00%
#
# **0.00005**(49):  loss: 0.3676/0.4294,    accuracy: 82.18%/78.00%
#
# **0.00010**(39):  loss: 0.2499/0.3993,    accuracy: 89.88%/81.33%
#
# **0.00010**(23):  loss: 0.4416/0.4551,    accuracy: 78.59%/78.67%  (paro explícito)
#
# **0.00050**(17):  loss: 0.4216/0.4617,    accuracy: 78.82%/79.67%

# %% [markdown]
# Escogemos el modelo con LR 10e-4,  con 23 épocas.
# Como el val loss continuó disminuyendo (aunque con overfitting), es necesario volver a entrenar este modelo, parándolo explícitamente en la época 23.

# %%
start = time.time()
reset_seed()
modelo_base_dropout_1e4_23, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_Dropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-4, epocas=23, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.693706, accuracy: 0.505294, val loss: 0.692491, val accuracy: 0.523333 -- epoch time: 9.88
# Se mejoró el loss de inf a 0.692490816116333
# 1:  loss: 0.692627, accuracy: 0.515294, val loss: 0.688823, val accuracy: 0.520000 -- epoch time: 12.04
# Se mejoró el loss de 0.692490816116333 a 0.6888230443000793
# 2:  loss: 0.680413, accuracy: 0.574706, val loss: 0.682720, val accuracy: 0.533333 -- epoch time: 10.33
# Se mejoró el loss de 0.6888230443000793 a 0.6827200651168823
# 3:  loss: 0.672552, accuracy: 0.584706, val loss: 0.655345, val accuracy: 0.633333 -- epoch time: 8.54
# Se mejoró el loss de 0.6827200651168823 a 0.6553447842597961
# 4:  loss: 0.654120, accuracy: 0.623529, val loss: 0.632806, val accuracy: 0.666667 -- epoch time: 8.57
# Se mejoró el loss de 0.6553447842597961 a 0.6328062415122986
# 5:  loss: 0.640761, accuracy: 0.645882, val loss: 0.621226, val accuracy: 0.673333 -- epoch time: 8.52
# Se mejoró el loss de 0.6328062415122986 a 0.621225893497467
# 6:  loss: 0.624353, accuracy: 0.664706, val loss: 0.628202, val accuracy: 0.646667 -- epoch time: 8.57
# 7:  loss: 0.623692, accuracy: 0.648824, val loss: 0.611596, val accuracy: 0.660000 -- epoch time: 9.62
# Se mejoró el loss de 0.621225893497467 a 0.6115957498550415
# 8:  loss: 0.610367, accuracy: 0.662353, val loss: 0.616542, val accuracy: 0.666667 -- epoch time: 8.62
# 9:  loss: 0.602367, accuracy: 0.680588, val loss: 0.595425, val accuracy: 0.673333 -- epoch time: 8.72
# Se mejoró el loss de 0.6115957498550415 a 0.5954252481460571
# 10:  loss: 0.589872, accuracy: 0.689412, val loss: 0.578440, val accuracy: 0.700000 -- epoch time: 9.03
# Se mejoró el loss de 0.5954252481460571 a 0.5784396529197693
# 11:  loss: 0.578378, accuracy: 0.690000, val loss: 0.564206, val accuracy: 0.713333 -- epoch time: 8.64
# Se mejoró el loss de 0.5784396529197693 a 0.5642062425613403
# 12:  loss: 0.557128, accuracy: 0.717059, val loss: 0.555985, val accuracy: 0.716667 -- epoch time: 8.60
# Se mejoró el loss de 0.5642062425613403 a 0.5559847354888916
# 13:  loss: 0.548080, accuracy: 0.711765, val loss: 0.539090, val accuracy: 0.703333 -- epoch time: 9.71
# Se mejoró el loss de 0.5559847354888916 a 0.539090096950531
# 14:  loss: 0.535956, accuracy: 0.723529, val loss: 0.523073, val accuracy: 0.736667 -- epoch time: 8.57
# Se mejoró el loss de 0.539090096950531 a 0.5230734944343567
# 15:  loss: 0.526037, accuracy: 0.736471, val loss: 0.545228, val accuracy: 0.726667 -- epoch time: 8.58
# 16:  loss: 0.515575, accuracy: 0.737059, val loss: 0.498122, val accuracy: 0.763333 -- epoch time: 8.70
# Se mejoró el loss de 0.5230734944343567 a 0.4981216490268707
# 17:  loss: 0.501178, accuracy: 0.749412, val loss: 0.493163, val accuracy: 0.756667 -- epoch time: 8.64
# Se mejoró el loss de 0.4981216490268707 a 0.4931633174419403
# 18:  loss: 0.482502, accuracy: 0.767059, val loss: 0.489800, val accuracy: 0.746667 -- epoch time: 9.72
# Se mejoró el loss de 0.4931633174419403 a 0.4897996187210083
# 19:  loss: 0.478209, accuracy: 0.765882, val loss: 0.489330, val accuracy: 0.766667 -- epoch time: 8.61
# Se mejoró el loss de 0.4897996187210083 a 0.489329993724823
# 20:  loss: 0.466273, accuracy: 0.769412, val loss: 0.501510, val accuracy: 0.746667 -- epoch time: 9.58
# 21:  loss: 0.453143, accuracy: 0.774118, val loss: 0.474449, val accuracy: 0.773333 -- epoch time: 8.59
# Se mejoró el loss de 0.489329993724823 a 0.47444871068000793
# 22:  loss: 0.441627, accuracy: 0.785882, val loss: 0.455090, val accuracy: 0.786667 -- epoch time: 8.61
# Se mejoró el loss de 0.47444871068000793 a 0.4550897777080536
# time: 209.89

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %%
modelo_base_dropout = modelo_base_dropout_1e4_23

# %% [markdown]
# Evaluamos entonces el dataset de test con el modelo escogido.

# %%
test_loss, test_acc = eval_model(modelo_base_dropout, test_data_loader_small)
print(f"El loss de test es {test_loss}, y el accuracy de test es de {test_acc:.3f}. ")
torch.save(modelo_base_dropout, "cats_and_dogs_small_dropout.pth")
# Out:
# El loss de test es 0.5274034080505371, y el accuracy de test es de 0.725.

# %% [markdown]
# Vemos que el loss del test set se bajó a 0.5274, reduciendo además el overfitting con respecto al mejor modelo precedente (sin dropout), aunque con un accuracy de test del 72.5%.

# %% [markdown]
# ### Batch normalization

# %% [markdown]
# Veamos ahora el efecto que habría tenido la técnica de **Batch normalisation**, que está disponible en PyTorch para tensores 1D y 2D (capas ```nn.BatchNorm1d``` y ```nn.BatchNorm2d```, respectivamente, indicando el número de neuronas de salida), y que tiene como propósito realizar un pretratamiento de estandarización de los inputs (a nivel del conjunto de datos de cada batch) **antes de una función de activación** dentro de una red neuronal.
# Cada batch de instancias tiene entonces la misma contribución al proceso de entrenamiento, y permite amplificar el impacto de cada actualización, posiblemente reduciendo el tiempo de entrenamiento necesario, reduciendo la dependencia en la inicialización de los pesos, permitiendo el aumento del learning rate, y generando un efecto de regularización que puede combatir el overfitting.
#
# Durante el entrenamiento, la salida de esta capa va a ser
# $$batchnorm = \gamma * \frac{(batch - mean(batch))} {sqrt(var(batch) + \epsilon)} + \beta$$
# donde $\gamma$ y $\beta$ son dos factores que se aprenden a medida que se entrena y controlan el escalado y centrado de la estandarización (se pueden deshabilitar con "scale=False" y "center=False", respectivamente), $\epsilon$ es una constante que impide división por cero (se puede indicar como argumento).
#
# Durante la evaluación o predicción, el modelo considera el promedio móvil y varianza móvil de los batches de entrenamiento, teniendo en cuenta un hiperparámetro **momentum**. Los valores de $movingMean$ y $movingVar$ se actualizan cada vez que se ejecuta la capa durante el entrenamiento, y se utilizan para estimar la salida con la fórmula anterior en lugar de $mean(batch)$ y $var(batch)$.
# $$movingMean = movingMean * momentum + mean(batch)$$
# $$movingVar = movingVar * momentum + sqrt(var(batch))$$
#
# Además de los parámetros \gamma  y \beta, aprendidos durante el entrenamiento,
# la capa **Batch Normalization** tiene los siguientes hiper parámetros, entre otros:
# - **momentum**: controla el decaimiento del promedio y varianza móviles. Por defecto es 0.99
# - **epsilon**: $\epsilon$ se usa para asegurar estabilidad numérica durante la normalización del mini batch. por defecto es 0.001.
# - **center**: permite especificar si se quiere corregir con el valor de $\beta$
# - **scale**: permite especificar si se quiere corregir con el valor de $\gamma$
# - inicializadores y regulizadores para los arrays $\beta$ y $\gamma$, por defecto son zeros y unos, respectivamente.
#
# Vamos a crear capas de batch normalization previas a cada función de activación, utilizando los valores por defecto de sus hiper parámetros.

# %%
class BinaryImageClassifierBase_BNorm(nn.Module):

    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding="valid")
        self.conv1_bn = nn.BatchNorm2d(32)
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding="valid")
        self.conv2_bn = nn.BatchNorm2d(64)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding="valid")
        self.conv3_bn = nn.BatchNorm2d(128)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding="valid")
        self.conv4_bn = nn.BatchNorm2d(128)
        self.maxpool4 = nn.MaxPool2d(kernel_size=2)
        self.flatten = nn.Flatten()
        self.linear1 = nn.Linear(in_features=128*7*7, out_features=512)
        self.linear1_bn = nn.BatchNorm1d(512)
        self.linear2 = nn.Linear(in_features=512, out_features=1)

    def forward(self, image):
        x = self.conv1(image)
        x = F.relu(self.conv1_bn(x))
        x = self.maxpool1(x)

        x = self.conv2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.maxpool2(x)

        x = self.conv3(x)
        x = F.relu(self.conv3_bn(x))
        x = self.maxpool3(x)

        x = self.conv4(x)
        x = F.relu(self.conv4_bn(x))
        x = self.maxpool4(x)

        x = self.flatten(x)
        x = self.linear1(x)
        x = F.relu(self.linear1_bn(x))

        logits = self.linear2(x)
        probas = torch.sigmoid(logits)

        return probas

# %%
modelo_base_bnorm = BinaryImageClassifierBase_BNorm()
modelo_base_bnorm.to(DEVICE)
# Out:
# BinaryImageClassifierBase_BNorm(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (conv2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (conv3_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#   (conv4_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear1): Linear(in_features=6272, out_features=512, bias=True)
#   (linear1_bn): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear2): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
summary(modelo_base_bnorm, (3, 150, 150))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 148, 148]             896
#        BatchNorm2d-2         [-1, 32, 148, 148]              64
#          MaxPool2d-3           [-1, 32, 74, 74]               0
#             Conv2d-4           [-1, 64, 72, 72]          18,496
#        BatchNorm2d-5           [-1, 64, 72, 72]             128
#          MaxPool2d-6           [-1, 64, 36, 36]               0
#             Conv2d-7          [-1, 128, 34, 34]          73,856
#        BatchNorm2d-8          [-1, 128, 34, 34]             256
#          MaxPool2d-9          [-1, 128, 17, 17]               0
#            Conv2d-10          [-1, 128, 15, 15]         147,584
#       BatchNorm2d-11          [-1, 128, 15, 15]             256
#         MaxPool2d-12            [-1, 128, 7, 7]               0
#           Flatten-13                 [-1, 6272]               0
#            Linear-14                  [-1, 512]       3,211,776
#       BatchNorm1d-15                  [-1, 512]           1,024
#            Linear-16                    [-1, 1]             513
# ================================================================
# Total params: 3,454,849
# Trainable params: 3,454,849
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.26
# Forward/backward pass size (MB): 20.81
# Params size (MB): 13.18
# Estimated Total Size (MB): 34.25
# ----------------------------------------------------------------

# %% [markdown]
# Vemos que las capas de batch normalization tienen parámetros entrenables:
# - para las capas 2d convolucionales: hay 2 por cada filtro, recordemos que se aplica la función de activación a los net inputs de cada filtro
# - para las capas 1d: hay 1 parámetro por cada neurona densa; se aplica una función de activación a los net inputs de cada una.

# %% [markdown]
# El efecto esperado que tendrá el batch normalization en el entrenamiento es:
# - se reduce el impacto de la escala de los gradientes. Siendo estos mas balanceados se reduce la posibilidad de su explosión o desvanecimiento.
# - se puede propagar más rápidamente los gradientes a las primeras capas
# - se supone que los datos están igualmente distribuidos en el training set y test set
# - el modelo será menos sensible a la inicialización de los parámetros de las capas
# - se podrá utilizar un learning rate mayor, con las capas pudiendo aprender de maneras mas independientes las unas de las otras
#
# Tenemos entonces que buscar un nuevo learning rate.

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_5e5, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNorm(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=5e-5, epocas=50, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.638605, accuracy: 0.648235, val loss: 0.563923, val accuracy: 0.716667 -- epoch time: 8.77
# Se mejoró el loss de inf a 0.5639229416847229
# 1:  loss: 0.415409, accuracy: 0.839412, val loss: 0.502259, val accuracy: 0.746667 -- epoch time: 8.81
# Se mejoró el loss de 0.5639229416847229 a 0.5022589564323425
# 2:  loss: 0.296388, accuracy: 0.912353, val loss: 0.566372, val accuracy: 0.690000 -- epoch time: 8.77
# 3:  loss: 0.222370, accuracy: 0.943529, val loss: 0.471087, val accuracy: 0.773333 -- epoch time: 9.89
# Se mejoró el loss de 0.5022589564323425 a 0.4710868299007416
# 4:  loss: 0.161533, accuracy: 0.969412, val loss: 0.568219, val accuracy: 0.753333 -- epoch time: 9.74
# ----- Se sobrepasó el límite de accuracy del early stopping 0.95)
# time: 46.16

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# Vemos que el LR es demasiado elevado, lo podemos reducir.

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_1e5, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNorm(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-5, epocas=50, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.650403, accuracy: 0.621765, val loss: 0.592229, val accuracy: 0.680000 -- epoch time: 11.58
# Se mejoró el loss de inf a 0.592229425907135
# 1:  loss: 0.552869, accuracy: 0.724118, val loss: 0.565996, val accuracy: 0.700000 -- epoch time: 9.51
# Se mejoró el loss de 0.592229425907135 a 0.5659955143928528
# 2:  loss: 0.489433, accuracy: 0.780588, val loss: 0.543011, val accuracy: 0.723333 -- epoch time: 13.67
# Se mejoró el loss de 0.5659955143928528 a 0.5430113077163696
# 3:  loss: 0.446446, accuracy: 0.837647, val loss: 0.525118, val accuracy: 0.753333 -- epoch time: 9.86
# Se mejoró el loss de 0.5430113077163696 a 0.5251176357269287
# 4:  loss: 0.405963, accuracy: 0.864706, val loss: 0.509134, val accuracy: 0.753333 -- epoch time: 11.84
# Se mejoró el loss de 0.5251176357269287 a 0.5091341733932495
# 5:  loss: 0.363537, accuracy: 0.896471, val loss: 0.496226, val accuracy: 0.773333 -- epoch time: 8.90
# Se mejoró el loss de 0.5091341733932495 a 0.4962260127067566
# 6:  loss: 0.336517, accuracy: 0.908235, val loss: 0.480164, val accuracy: 0.803333 -- epoch time: 8.68
# Se mejoró el loss de 0.4962260127067566 a 0.48016414046287537
# 7:  loss: 0.309100, accuracy: 0.930000, val loss: 0.484828, val accuracy: 0.770000 -- epoch time: 8.84
# 8:  loss: 0.285248, accuracy: 0.940588, val loss: 0.470581, val accuracy: 0.793333 -- epoch time: 8.88
# Se mejoró el loss de 0.48016414046287537 a 0.4705814719200134
# 9:  loss: 0.252874, accuracy: 0.951765, val loss: 0.474571, val accuracy: 0.793333 -- epoch time: 9.97
# ----- Se sobrepasó el límite de accuracy del early stopping 0.95)
# time: 102.15

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_5e6, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNorm(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=5e-6, epocas=50, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.664241, accuracy: 0.608235, val loss: 0.617296, val accuracy: 0.640000 -- epoch time: 8.84
# Se mejoró el loss de inf a 0.6172961592674255
# 1:  loss: 0.596874, accuracy: 0.681765, val loss: 0.591774, val accuracy: 0.693333 -- epoch time: 8.83
# Se mejoró el loss de 0.6172961592674255 a 0.5917741656303406
# 2:  loss: 0.553279, accuracy: 0.721765, val loss: 0.575070, val accuracy: 0.680000 -- epoch time: 10.74
# Se mejoró el loss de 0.5917741656303406 a 0.5750704407691956
# 3:  loss: 0.524285, accuracy: 0.762353, val loss: 0.558597, val accuracy: 0.733333 -- epoch time: 8.76
# Se mejoró el loss de 0.5750704407691956 a 0.5585971474647522
# 4:  loss: 0.495151, accuracy: 0.795294, val loss: 0.548488, val accuracy: 0.716667 -- epoch time: 8.82
# Se mejoró el loss de 0.5585971474647522 a 0.5484877228736877
# 5:  loss: 0.464784, accuracy: 0.821176, val loss: 0.535643, val accuracy: 0.743333 -- epoch time: 8.87
# Se mejoró el loss de 0.5484877228736877 a 0.5356431007385254
# 6:  loss: 0.444665, accuracy: 0.833529, val loss: 0.523661, val accuracy: 0.760000 -- epoch time: 9.92
# Se mejoró el loss de 0.5356431007385254 a 0.5236606001853943
# 7:  loss: 0.423148, accuracy: 0.854118, val loss: 0.518010, val accuracy: 0.750000 -- epoch time: 8.87
# Se mejoró el loss de 0.5236606001853943 a 0.5180104970932007
# 8:  loss: 0.405420, accuracy: 0.873529, val loss: 0.509975, val accuracy: 0.763333 -- epoch time: 8.90
# Se mejoró el loss de 0.5180104970932007 a 0.5099748969078064
# 9:  loss: 0.377808, accuracy: 0.891176, val loss: 0.505345, val accuracy: 0.773333 -- epoch time: 8.74
# Se mejoró el loss de 0.5099748969078064 a 0.5053451657295227
# 10:  loss: 0.355259, accuracy: 0.912941, val loss: 0.499132, val accuracy: 0.780000 -- epoch time: 8.89
# Se mejoró el loss de 0.5053451657295227 a 0.4991321861743927
# 11:  loss: 0.341654, accuracy: 0.921176, val loss: 0.490534, val accuracy: 0.783333 -- epoch time: 8.82
# Se mejoró el loss de 0.4991321861743927 a 0.4905339181423187
# 12:  loss: 0.333601, accuracy: 0.913529, val loss: 0.489940, val accuracy: 0.790000 -- epoch time: 9.66
# Se mejoró el loss de 0.4905339181423187 a 0.4899401068687439
# 13:  loss: 0.319476, accuracy: 0.921765, val loss: 0.485119, val accuracy: 0.796667 -- epoch time: 8.80
# Se mejoró el loss de 0.4899401068687439 a 0.4851188361644745
# 14:  loss: 0.297446, accuracy: 0.930588, val loss: 0.479758, val accuracy: 0.773333 -- epoch time: 8.72
# Se mejoró el loss de 0.4851188361644745 a 0.47975799441337585
# 15:  loss: 0.279923, accuracy: 0.938824, val loss: 0.475881, val accuracy: 0.796667 -- epoch time: 8.90
# Se mejoró el loss de 0.47975799441337585 a 0.4758807420730591
# 16:  loss: 0.264927, accuracy: 0.951176, val loss: 0.473074, val accuracy: 0.793333 -- epoch time: 8.81
# Se mejoró el loss de 0.4758807420730591 a 0.4730741083621979
# ----- Se sobrepasó el límite de accuracy del early stopping 0.95)
# time: 154.71

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_1e6, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNorm(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-6, epocas=50, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.694633, accuracy: 0.535882, val loss: 0.673198, val accuracy: 0.573333 -- epoch time: 10.63
# Se mejoró el loss de inf a 0.6731978058815002
# 1:  loss: 0.662231, accuracy: 0.598235, val loss: 0.648431, val accuracy: 0.623333 -- epoch time: 8.97
# Se mejoró el loss de 0.6731978058815002 a 0.6484310030937195
# 2:  loss: 0.642357, accuracy: 0.630000, val loss: 0.630732, val accuracy: 0.636667 -- epoch time: 10.30
# Se mejoró el loss de 0.6484310030937195 a 0.6307315826416016
# 3:  loss: 0.629527, accuracy: 0.645882, val loss: 0.622630, val accuracy: 0.640000 -- epoch time: 9.08
# Se mejoró el loss de 0.6307315826416016 a 0.622629702091217
# 4:  loss: 0.617916, accuracy: 0.672941, val loss: 0.617610, val accuracy: 0.646667 -- epoch time: 9.04
# Se mejoró el loss de 0.622629702091217 a 0.6176102161407471
# 5:  loss: 0.606292, accuracy: 0.677059, val loss: 0.606982, val accuracy: 0.653333 -- epoch time: 9.06
# Se mejoró el loss de 0.6176102161407471 a 0.6069815754890442
# 6:  loss: 0.597292, accuracy: 0.684706, val loss: 0.603924, val accuracy: 0.670000 -- epoch time: 8.93
# Se mejoró el loss de 0.6069815754890442 a 0.6039236187934875
# 7:  loss: 0.587656, accuracy: 0.695294, val loss: 0.596939, val accuracy: 0.676667 -- epoch time: 9.87
# Se mejoró el loss de 0.6039236187934875 a 0.5969389081001282
# 8:  loss: 0.581462, accuracy: 0.714706, val loss: 0.592400, val accuracy: 0.670000 -- epoch time: 8.83
# Se mejoró el loss de 0.5969389081001282 a 0.592399537563324
# 9:  loss: 0.566337, accuracy: 0.719412, val loss: 0.591645, val accuracy: 0.673333 -- epoch time: 8.83
# Se mejoró el loss de 0.592399537563324 a 0.5916454195976257
# 10:  loss: 0.554442, accuracy: 0.722941, val loss: 0.587056, val accuracy: 0.673333 -- epoch time: 9.95
# Se mejoró el loss de 0.5916454195976257 a 0.5870555639266968
# 11:  loss: 0.550500, accuracy: 0.739412, val loss: 0.580537, val accuracy: 0.676667 -- epoch time: 8.89
# Se mejoró el loss de 0.5870555639266968 a 0.5805371999740601
# 12:  loss: 0.545749, accuracy: 0.740588, val loss: 0.580948, val accuracy: 0.683333 -- epoch time: 9.94
# 13:  loss: 0.542290, accuracy: 0.741176, val loss: 0.575978, val accuracy: 0.686667 -- epoch time: 8.88
# Se mejoró el loss de 0.5805371999740601 a 0.5759783387184143
# 14:  loss: 0.530151, accuracy: 0.760588, val loss: 0.574218, val accuracy: 0.686667 -- epoch time: 8.91
# Se mejoró el loss de 0.5759783387184143 a 0.5742181539535522
# 15:  loss: 0.520915, accuracy: 0.768824, val loss: 0.569574, val accuracy: 0.686667 -- epoch time: 8.84
# Se mejoró el loss de 0.5742181539535522 a 0.5695744156837463
# 16:  loss: 0.514776, accuracy: 0.781765, val loss: 0.568148, val accuracy: 0.700000 -- epoch time: 9.44
# Se mejoró el loss de 0.5695744156837463 a 0.5681477785110474
# 17:  loss: 0.511574, accuracy: 0.775294, val loss: 0.563541, val accuracy: 0.700000 -- epoch time: 9.69
# Se mejoró el loss de 0.5681477785110474 a 0.5635412931442261
# 18:  loss: 0.504358, accuracy: 0.782353, val loss: 0.561118, val accuracy: 0.696667 -- epoch time: 8.79
# Se mejoró el loss de 0.5635412931442261 a 0.5611180067062378
# 19:  loss: 0.497684, accuracy: 0.792353, val loss: 0.560041, val accuracy: 0.683333 -- epoch time: 8.80
# Se mejoró el loss de 0.5611180067062378 a 0.5600411891937256
# 20:  loss: 0.492655, accuracy: 0.793529, val loss: 0.555708, val accuracy: 0.710000 -- epoch time: 8.88
# Se mejoró el loss de 0.5600411891937256 a 0.5557079315185547
# 21:  loss: 0.492669, accuracy: 0.798824, val loss: 0.555112, val accuracy: 0.713333 -- epoch time: 8.85
# Se mejoró el loss de 0.5557079315185547 a 0.5551118850708008
# 22:  loss: 0.481979, accuracy: 0.808824, val loss: 0.550802, val accuracy: 0.720000 -- epoch time: 9.56
# Se mejoró el loss de 0.5551118850708008 a 0.5508023500442505
# 23:  loss: 0.475522, accuracy: 0.819412, val loss: 0.546817, val accuracy: 0.730000 -- epoch time: 8.82
# Se mejoró el loss de 0.5508023500442505 a 0.5468171834945679
# 24:  loss: 0.474277, accuracy: 0.815882, val loss: 0.545594, val accuracy: 0.730000 -- epoch time: 8.74
# Se mejoró el loss de 0.5468171834945679 a 0.5455936789512634
# 25:  loss: 0.460469, accuracy: 0.829412, val loss: 0.541909, val accuracy: 0.736667 -- epoch time: 8.72
# Se mejoró el loss de 0.5455936789512634 a 0.5419092178344727
# 26:  loss: 0.452161, accuracy: 0.828235, val loss: 0.541306, val accuracy: 0.743333 -- epoch time: 8.80
# Se mejoró el loss de 0.5419092178344727 a 0.5413061380386353
# 27:  loss: 0.452005, accuracy: 0.838824, val loss: 0.537010, val accuracy: 0.743333 -- epoch time: 8.82
# Se mejoró el loss de 0.5413061380386353 a 0.5370098948478699
# 28:  loss: 0.447190, accuracy: 0.834118, val loss: 0.535711, val accuracy: 0.726667 -- epoch time: 9.87
# Se mejoró el loss de 0.5370098948478699 a 0.5357105731964111
# 29:  loss: 0.446937, accuracy: 0.834118, val loss: 0.534809, val accuracy: 0.743333 -- epoch time: 8.85
# Se mejoró el loss de 0.5357105731964111 a 0.5348089933395386
# 30:  loss: 0.440324, accuracy: 0.851765, val loss: 0.533068, val accuracy: 0.740000 -- epoch time: 8.77
# Se mejoró el loss de 0.5348089933395386 a 0.5330684185028076
# 31:  loss: 0.440518, accuracy: 0.841176, val loss: 0.530855, val accuracy: 0.743333 -- epoch time: 8.80
# Se mejoró el loss de 0.5330684185028076 a 0.5308545231819153
# 32:  loss: 0.427531, accuracy: 0.861765, val loss: 0.528455, val accuracy: 0.753333 -- epoch time: 8.84
# Se mejoró el loss de 0.5308545231819153 a 0.5284545421600342
# 33:  loss: 0.421310, accuracy: 0.859412, val loss: 0.524267, val accuracy: 0.746667 -- epoch time: 10.79
# Se mejoró el loss de 0.5284545421600342 a 0.5242670774459839
# 34:  loss: 0.420531, accuracy: 0.863529, val loss: 0.523095, val accuracy: 0.756667 -- epoch time: 8.83
# Se mejoró el loss de 0.5242670774459839 a 0.5230953097343445
# 35:  loss: 0.413864, accuracy: 0.867647, val loss: 0.526207, val accuracy: 0.750000 -- epoch time: 8.79
# 36:  loss: 0.408491, accuracy: 0.868235, val loss: 0.516251, val accuracy: 0.770000 -- epoch time: 8.75
# Se mejoró el loss de 0.5230953097343445 a 0.5162512063980103
# 37:  loss: 0.404565, accuracy: 0.874706, val loss: 0.523562, val accuracy: 0.746667 -- epoch time: 8.76
# 38:  loss: 0.398064, accuracy: 0.878824, val loss: 0.516221, val accuracy: 0.766667 -- epoch time: 10.00
# Se mejoró el loss de 0.5162512063980103 a 0.516221284866333
# 39:  loss: 0.393824, accuracy: 0.886471, val loss: 0.515413, val accuracy: 0.756667 -- epoch time: 8.79
# Se mejoró el loss de 0.516221284866333 a 0.5154130458831787
# 40:  loss: 0.390280, accuracy: 0.894118, val loss: 0.512842, val accuracy: 0.776667 -- epoch time: 8.83
# Se mejoró el loss de 0.5154130458831787 a 0.5128415822982788
# 41:  loss: 0.388189, accuracy: 0.881176, val loss: 0.515773, val accuracy: 0.760000 -- epoch time: 8.82
# 42:  loss: 0.377621, accuracy: 0.903529, val loss: 0.512551, val accuracy: 0.770000 -- epoch time: 8.76
# Se mejoró el loss de 0.5128415822982788 a 0.5125513076782227
# 43:  loss: 0.386372, accuracy: 0.882353, val loss: 0.508521, val accuracy: 0.773333 -- epoch time: 9.93
# Se mejoró el loss de 0.5125513076782227 a 0.5085209608078003
# 44:  loss: 0.378258, accuracy: 0.895294, val loss: 0.507600, val accuracy: 0.770000 -- epoch time: 8.76
# Se mejoró el loss de 0.5085209608078003 a 0.5075998306274414
# 45:  loss: 0.367381, accuracy: 0.903529, val loss: 0.505322, val accuracy: 0.773333 -- epoch time: 8.75
# Se mejoró el loss de 0.5075998306274414 a 0.5053216814994812
# 46:  loss: 0.370233, accuracy: 0.892941, val loss: 0.504104, val accuracy: 0.773333 -- epoch time: 8.78
# Se mejoró el loss de 0.5053216814994812 a 0.504104495048523
# 47:  loss: 0.359885, accuracy: 0.902941, val loss: 0.504030, val accuracy: 0.773333 -- epoch time: 8.91
# Se mejoró el loss de 0.504104495048523 a 0.5040302872657776
# 48:  loss: 0.355998, accuracy: 0.906471, val loss: 0.503296, val accuracy: 0.780000 -- epoch time: 8.84
# Se mejoró el loss de 0.5040302872657776 a 0.503296434879303
# 49:  loss: 0.357594, accuracy: 0.902941, val loss: 0.500617, val accuracy: 0.766667 -- epoch time: 9.76
# Se mejoró el loss de 0.503296434879303 a 0.5006167888641357
# time: 459.09

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# **Base**
#
# **0.00010**(18):  loss: 0.4271/0.4590/0.5503, accuracy: 78.88%/77.33%/73.60%
#
# **Dropout**
#
# **0.00010**(23):  loss: 0.4416/0.4551/0.5274, accuracy: 78.59%/78.67%/72.50%  (paro explícito)
#
# **BatchNorm**
#
# **0.00005**(4):  loss: 0.2223/0.4711,    accuracy: 94.35%/77.33%
#
# **0.00001**(8):  loss: 0.2852/0.4706,    accuracy: 94.06%/79.33%
#
# **0.000005**(17):  loss: 0.2649/0.4731,    accuracy: 95.12%/79.33%
#
# **0.000001**(50):  loss: 0.3576/0.5006,    accuracy: 90.29%/76.67%

# %% [markdown]
# Vemos que usar la técnica de batch normalization no nos aporta por si sola una mejora con respecto a lo previamente obtenido solo con la técnica de dropout.

# %% [markdown]
# ### BatchNorm + Dropout

# %% [markdown]
# Veamos ahora con una combinación de las ds técnicas **Dropout** y **BatchNorm**.

# %%
class BinaryImageClassifierBase_BNormDropout(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, stride=1, padding="valid")
        self.conv1_bn = nn.BatchNorm2d(32)
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding="valid")
        self.conv2_bn = nn.BatchNorm2d(64)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding="valid")
        self.conv3_bn = nn.BatchNorm2d(128)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2)
        self.conv4 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding="valid")
        self.conv4_bn = nn.BatchNorm2d(128)
        self.maxpool4 = nn.MaxPool2d(kernel_size=2)

        self.flatten = nn.Flatten()
        self.dropout1 = nn.Dropout(p=0.5)
        self.linear1 = nn.Linear(in_features=128*7*7, out_features=512)
        self.linear1_bn = nn.BatchNorm1d(512)

        self.dropout2 = nn.Dropout(p=0.5)
        self.linear2 = nn.Linear(in_features=512, out_features=1)

    def forward(self, image):
        x = self.conv1(image)
        x = F.relu(self.conv1_bn(x))
        x = self.maxpool1(x)

        x = self.conv2(x)
        x = F.relu(self.conv2_bn(x))
        x = self.maxpool2(x)

        x = self.conv3(x)
        x = F.relu(self.conv3_bn(x))
        x = self.maxpool3(x)

        x = self.conv4(x)
        x = F.relu(self.conv4_bn(x))
        x = self.maxpool4(x)

        x = self.dropout1(x)
        x = self.flatten(x)

        x = self.linear1(x)
        x = F.relu(self.linear1_bn(x))
        x = self.dropout1(x)

        logits = self.linear2(x)
        probas = torch.sigmoid(logits)
        return probas

# %%
summary(BinaryImageClassifierBase_BNormDropout().to(DEVICE), (3, 150, 150))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 148, 148]             896
#        BatchNorm2d-2         [-1, 32, 148, 148]              64
#          MaxPool2d-3           [-1, 32, 74, 74]               0
#             Conv2d-4           [-1, 64, 72, 72]          18,496
#        BatchNorm2d-5           [-1, 64, 72, 72]             128
#          MaxPool2d-6           [-1, 64, 36, 36]               0
#             Conv2d-7          [-1, 128, 34, 34]          73,856
#        BatchNorm2d-8          [-1, 128, 34, 34]             256
#          MaxPool2d-9          [-1, 128, 17, 17]               0
#            Conv2d-10          [-1, 128, 15, 15]         147,584
#       BatchNorm2d-11          [-1, 128, 15, 15]             256
#         MaxPool2d-12            [-1, 128, 7, 7]               0
#           Dropout-13            [-1, 128, 7, 7]               0
#           Flatten-14                 [-1, 6272]               0
#            Linear-15                  [-1, 512]       3,211,776
#       BatchNorm1d-16                  [-1, 512]           1,024
#           Dropout-17                  [-1, 512]               0
#            Linear-18                    [-1, 1]             513
# ================================================================
# Total params: 3,454,849
# Trainable params: 3,454,849
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.26
# Forward/backward pass size (MB): 20.86
# Params size (MB): 13.18
# Estimated Total Size (MB): 34.30
# ----------------------------------------------------------------

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_dropout_1e5, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNormDropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-5, epocas=70, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.692477, accuracy: 0.577059, val loss: 0.626891, val accuracy: 0.643333 -- epoch time: 10.59
# Se mejoró el loss de inf a 0.6268913745880127
# 1:  loss: 0.663113, accuracy: 0.614118, val loss: 0.603181, val accuracy: 0.670000 -- epoch time: 8.92
# Se mejoró el loss de 0.6268913745880127 a 0.6031810641288757
# 2:  loss: 0.628846, accuracy: 0.645882, val loss: 0.591552, val accuracy: 0.673333 -- epoch time: 8.77
# Se mejoró el loss de 0.6031810641288757 a 0.5915522575378418
# 3:  loss: 0.619251, accuracy: 0.644118, val loss: 0.582318, val accuracy: 0.696667 -- epoch time: 8.81
# Se mejoró el loss de 0.5915522575378418 a 0.5823184251785278
# 4:  loss: 0.608489, accuracy: 0.664118, val loss: 0.574770, val accuracy: 0.686667 -- epoch time: 8.75
# Se mejoró el loss de 0.5823184251785278 a 0.5747696161270142
# 5:  loss: 0.584576, accuracy: 0.692353, val loss: 0.567988, val accuracy: 0.716667 -- epoch time: 8.65
# Se mejoró el loss de 0.5747696161270142 a 0.567987859249115
# 6:  loss: 0.579775, accuracy: 0.694706, val loss: 0.555362, val accuracy: 0.706667 -- epoch time: 8.77
# Se mejoró el loss de 0.567987859249115 a 0.5553617477416992
# 7:  loss: 0.571029, accuracy: 0.698824, val loss: 0.552524, val accuracy: 0.706667 -- epoch time: 8.69
# Se mejoró el loss de 0.5553617477416992 a 0.5525237917900085
# 8:  loss: 0.554516, accuracy: 0.732941, val loss: 0.547198, val accuracy: 0.726667 -- epoch time: 8.80
# Se mejoró el loss de 0.5525237917900085 a 0.5471976399421692
# 9:  loss: 0.545077, accuracy: 0.722941, val loss: 0.538512, val accuracy: 0.740000 -- epoch time: 8.76
# Se mejoró el loss de 0.5471976399421692 a 0.5385124087333679
# 10:  loss: 0.520850, accuracy: 0.744118, val loss: 0.529398, val accuracy: 0.746667 -- epoch time: 8.82
# Se mejoró el loss de 0.5385124087333679 a 0.5293983221054077
# 11:  loss: 0.522522, accuracy: 0.741765, val loss: 0.522102, val accuracy: 0.746667 -- epoch time: 8.78
# Se mejoró el loss de 0.5293983221054077 a 0.5221015810966492
# 12:  loss: 0.503374, accuracy: 0.757059, val loss: 0.516573, val accuracy: 0.760000 -- epoch time: 8.78
# Se mejoró el loss de 0.5221015810966492 a 0.5165730118751526
# 13:  loss: 0.501793, accuracy: 0.750000, val loss: 0.515507, val accuracy: 0.756667 -- epoch time: 8.68
# Se mejoró el loss de 0.5165730118751526 a 0.5155073404312134
# 14:  loss: 0.494959, accuracy: 0.767647, val loss: 0.502837, val accuracy: 0.753333 -- epoch time: 8.86
# Se mejoró el loss de 0.5155073404312134 a 0.5028366446495056
# 15:  loss: 0.473643, accuracy: 0.790588, val loss: 0.498582, val accuracy: 0.753333 -- epoch time: 8.90
# Se mejoró el loss de 0.5028366446495056 a 0.4985821545124054
# 16:  loss: 0.470028, accuracy: 0.777647, val loss: 0.487576, val accuracy: 0.776667 -- epoch time: 8.73
# Se mejoró el loss de 0.4985821545124054 a 0.48757603764533997
# 17:  loss: 0.457697, accuracy: 0.799412, val loss: 0.485133, val accuracy: 0.796667 -- epoch time: 8.79
# Se mejoró el loss de 0.48757603764533997 a 0.48513326048851013
# 18:  loss: 0.448132, accuracy: 0.808235, val loss: 0.480309, val accuracy: 0.780000 -- epoch time: 9.88
# Se mejoró el loss de 0.48513326048851013 a 0.4803086519241333
# 19:  loss: 0.431538, accuracy: 0.814706, val loss: 0.476915, val accuracy: 0.800000 -- epoch time: 8.85
# Se mejoró el loss de 0.4803086519241333 a 0.47691458463668823
# 20:  loss: 0.439907, accuracy: 0.810000, val loss: 0.470296, val accuracy: 0.796667 -- epoch time: 8.67
# Se mejoró el loss de 0.47691458463668823 a 0.47029632329940796
# 21:  loss: 0.419727, accuracy: 0.821176, val loss: 0.467550, val accuracy: 0.786667 -- epoch time: 8.71
# Se mejoró el loss de 0.47029632329940796 a 0.46754980087280273
# 22:  loss: 0.416625, accuracy: 0.819412, val loss: 0.467639, val accuracy: 0.783333 -- epoch time: 8.76
# 23:  loss: 0.406244, accuracy: 0.834118, val loss: 0.463264, val accuracy: 0.800000 -- epoch time: 8.69
# Se mejoró el loss de 0.46754980087280273 a 0.46326395869255066
# 24:  loss: 0.396570, accuracy: 0.841176, val loss: 0.458775, val accuracy: 0.786667 -- epoch time: 8.70
# Se mejoró el loss de 0.46326395869255066 a 0.4587749242782593
# 25:  loss: 0.387780, accuracy: 0.827647, val loss: 0.457671, val accuracy: 0.786667 -- epoch time: 8.72
# Se mejoró el loss de 0.4587749242782593 a 0.4576707184314728
# 26:  loss: 0.362194, accuracy: 0.857059, val loss: 0.464708, val accuracy: 0.773333 -- epoch time: 8.62
# 27:  loss: 0.372058, accuracy: 0.855882, val loss: 0.448717, val accuracy: 0.800000 -- epoch time: 8.63
# Se mejoró el loss de 0.4576707184314728 a 0.44871729612350464
# 28:  loss: 0.365242, accuracy: 0.854118, val loss: 0.451802, val accuracy: 0.780000 -- epoch time: 8.75
# 29:  loss: 0.362811, accuracy: 0.846471, val loss: 0.444843, val accuracy: 0.800000 -- epoch time: 8.82
# Se mejoró el loss de 0.44871729612350464 a 0.44484269618988037
# 30:  loss: 0.347667, accuracy: 0.866471, val loss: 0.445489, val accuracy: 0.796667 -- epoch time: 8.74
# 31:  loss: 0.357052, accuracy: 0.856471, val loss: 0.439488, val accuracy: 0.810000 -- epoch time: 8.68
# Se mejoró el loss de 0.44484269618988037 a 0.43948766589164734
# 32:  loss: 0.330232, accuracy: 0.871765, val loss: 0.434631, val accuracy: 0.820000 -- epoch time: 8.66
# Se mejoró el loss de 0.43948766589164734 a 0.43463134765625
# 33:  loss: 0.329970, accuracy: 0.871176, val loss: 0.437774, val accuracy: 0.796667 -- epoch time: 8.77
# 34:  loss: 0.324035, accuracy: 0.874706, val loss: 0.439274, val accuracy: 0.793333 -- epoch time: 8.64
# 35:  loss: 0.316645, accuracy: 0.879412, val loss: 0.430723, val accuracy: 0.810000 -- epoch time: 8.66
# Se mejoró el loss de 0.43463134765625 a 0.4307231307029724
# 36:  loss: 0.310674, accuracy: 0.882941, val loss: 0.432650, val accuracy: 0.803333 -- epoch time: 9.85
# 37:  loss: 0.306626, accuracy: 0.880588, val loss: 0.437662, val accuracy: 0.800000 -- epoch time: 8.85
# 38:  loss: 0.304810, accuracy: 0.890000, val loss: 0.434384, val accuracy: 0.790000 -- epoch time: 8.85
# 39:  loss: 0.291814, accuracy: 0.895882, val loss: 0.430676, val accuracy: 0.816667 -- epoch time: 8.71
# Se mejoró el loss de 0.4307231307029724 a 0.4306756258010864
# 40:  loss: 0.284501, accuracy: 0.902941, val loss: 0.425553, val accuracy: 0.790000 -- epoch time: 8.63
# Se mejoró el loss de 0.4306756258010864 a 0.4255533516407013
# 41:  loss: 0.279641, accuracy: 0.897059, val loss: 0.449072, val accuracy: 0.806667 -- epoch time: 8.63
# 42:  loss: 0.270235, accuracy: 0.902941, val loss: 0.421752, val accuracy: 0.816667 -- epoch time: 8.81
# Se mejoró el loss de 0.4255533516407013 a 0.42175155878067017
# 43:  loss: 0.284524, accuracy: 0.889412, val loss: 0.417785, val accuracy: 0.806667 -- epoch time: 8.69
# Se mejoró el loss de 0.42175155878067017 a 0.41778475046157837
# 44:  loss: 0.262393, accuracy: 0.904118, val loss: 0.419241, val accuracy: 0.813333 -- epoch time: 8.83
# 45:  loss: 0.260113, accuracy: 0.902353, val loss: 0.418619, val accuracy: 0.816667 -- epoch time: 8.75
# 46:  loss: 0.258509, accuracy: 0.910588, val loss: 0.425269, val accuracy: 0.796667 -- epoch time: 8.75
# 47:  loss: 0.241375, accuracy: 0.924118, val loss: 0.421248, val accuracy: 0.793333 -- epoch time: 8.82
# 48:  loss: 0.229327, accuracy: 0.930588, val loss: 0.416712, val accuracy: 0.806667 -- epoch time: 8.64
# Se mejoró el loss de 0.41778475046157837 a 0.4167124032974243
# 49:  loss: 0.239295, accuracy: 0.920000, val loss: 0.419652, val accuracy: 0.803333 -- epoch time: 8.81
# 50:  loss: 0.236014, accuracy: 0.912941, val loss: 0.418611, val accuracy: 0.816667 -- epoch time: 8.77
# 51:  loss: 0.221800, accuracy: 0.928824, val loss: 0.416304, val accuracy: 0.816667 -- epoch time: 8.83
# Se mejoró el loss de 0.4167124032974243 a 0.41630396246910095
# 52:  loss: 0.216989, accuracy: 0.931176, val loss: 0.421017, val accuracy: 0.806667 -- epoch time: 8.77
# 53:  loss: 0.217417, accuracy: 0.923529, val loss: 0.431029, val accuracy: 0.806667 -- epoch time: 8.63
# 54:  loss: 0.210480, accuracy: 0.932353, val loss: 0.416762, val accuracy: 0.813333 -- epoch time: 9.62
# 55:  loss: 0.216148, accuracy: 0.926471, val loss: 0.425044, val accuracy: 0.796667 -- epoch time: 8.73
# 56:  loss: 0.205938, accuracy: 0.936471, val loss: 0.430134, val accuracy: 0.796667 -- epoch time: 8.72
# 57:  loss: 0.204579, accuracy: 0.937647, val loss: 0.429265, val accuracy: 0.800000 -- epoch time: 8.74
# 58:  loss: 0.203948, accuracy: 0.940588, val loss: 0.426296, val accuracy: 0.810000 -- epoch time: 8.76
# 59:  loss: 0.198296, accuracy: 0.930000, val loss: 0.421911, val accuracy: 0.800000 -- epoch time: 8.64
# 60:  loss: 0.209231, accuracy: 0.925882, val loss: 0.423830, val accuracy: 0.806667 -- epoch time: 8.64
# 61:  loss: 0.191553, accuracy: 0.941765, val loss: 0.439521, val accuracy: 0.803333 -- epoch time: 8.69
# 62:  loss: 0.183541, accuracy: 0.940000, val loss: 0.436302, val accuracy: 0.793333 -- epoch time: 8.67
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 557.37

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# Vemos que se desata la parada forzada por fuerte overfitting en la época 63.
# Hasta la época 17 no hay oevrfitting.

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_dropout_5e5, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNormDropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=5e-5, epocas=50, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.666309, accuracy: 0.607647, val loss: 0.584986, val accuracy: 0.700000 -- epoch time: 8.70
# Se mejoró el loss de inf a 0.5849859714508057
# 1:  loss: 0.603764, accuracy: 0.673529, val loss: 0.560165, val accuracy: 0.690000 -- epoch time: 8.71
# Se mejoró el loss de 0.5849859714508057 a 0.5601646900177002
# 2:  loss: 0.538083, accuracy: 0.727059, val loss: 0.535202, val accuracy: 0.756667 -- epoch time: 8.82
# Se mejoró el loss de 0.5601646900177002 a 0.5352016091346741
# 3:  loss: 0.518062, accuracy: 0.742353, val loss: 0.521571, val accuracy: 0.740000 -- epoch time: 8.87
# Se mejoró el loss de 0.5352016091346741 a 0.5215705633163452
# 4:  loss: 0.483042, accuracy: 0.767059, val loss: 0.512861, val accuracy: 0.746667 -- epoch time: 8.71
# Se mejoró el loss de 0.5215705633163452 a 0.5128605365753174
# 5:  loss: 0.429717, accuracy: 0.804706, val loss: 0.485030, val accuracy: 0.763333 -- epoch time: 8.75
# Se mejoró el loss de 0.5128605365753174 a 0.48503002524375916
# 6:  loss: 0.404720, accuracy: 0.825882, val loss: 0.442763, val accuracy: 0.793333 -- epoch time: 8.73
# Se mejoró el loss de 0.48503002524375916 a 0.44276317954063416
# 7:  loss: 0.389533, accuracy: 0.823529, val loss: 0.459299, val accuracy: 0.800000 -- epoch time: 8.76
# 8:  loss: 0.360589, accuracy: 0.850588, val loss: 0.448232, val accuracy: 0.810000 -- epoch time: 8.77
# 9:  loss: 0.332266, accuracy: 0.863529, val loss: 0.455117, val accuracy: 0.786667 -- epoch time: 8.85
# 10:  loss: 0.297516, accuracy: 0.885294, val loss: 0.419716, val accuracy: 0.826667 -- epoch time: 9.88
# Se mejoró el loss de 0.44276317954063416 a 0.4197157025337219
# 11:  loss: 0.279271, accuracy: 0.886471, val loss: 0.418096, val accuracy: 0.806667 -- epoch time: 8.86
# Se mejoró el loss de 0.4197157025337219 a 0.41809624433517456
# 12:  loss: 0.259856, accuracy: 0.901176, val loss: 0.462675, val accuracy: 0.770000 -- epoch time: 8.65
# 13:  loss: 0.253948, accuracy: 0.891765, val loss: 0.492468, val accuracy: 0.770000 -- epoch time: 8.63
# 14:  loss: 0.229649, accuracy: 0.913529, val loss: 0.398612, val accuracy: 0.823333 -- epoch time: 8.79
# Se mejoró el loss de 0.41809624433517456 a 0.3986116647720337
# 15:  loss: 0.206087, accuracy: 0.925882, val loss: 0.421730, val accuracy: 0.806667 -- epoch time: 8.80
# 16:  loss: 0.194414, accuracy: 0.930588, val loss: 0.419654, val accuracy: 0.816667 -- epoch time: 8.76
# 17:  loss: 0.176279, accuracy: 0.944118, val loss: 0.433231, val accuracy: 0.816667 -- epoch time: 8.76
# 18:  loss: 0.172908, accuracy: 0.944706, val loss: 0.433794, val accuracy: 0.800000 -- epoch time: 8.80
# 19:  loss: 0.155499, accuracy: 0.946471, val loss: 0.467434, val accuracy: 0.810000 -- epoch time: 8.79
# 20:  loss: 0.163243, accuracy: 0.940000, val loss: 0.410910, val accuracy: 0.826667 -- epoch time: 8.86
# 21:  loss: 0.149611, accuracy: 0.952353, val loss: 0.472585, val accuracy: 0.796667 -- epoch time: 8.87
# ----- Se sobrepasó el límite de accuracy del early stopping 0.95)
# time: 194.63

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# Ocurre algo similar al run anterior. DEspués de la época 5 empieza un overfitting fuerte.

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_dropout_1e4, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNormDropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-4, epocas=50, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.663132, accuracy: 0.617059, val loss: 0.566375, val accuracy: 0.700000 -- epoch time: 8.90
# Se mejoró el loss de inf a 0.5663747191429138
# 1:  loss: 0.584540, accuracy: 0.688235, val loss: 0.550465, val accuracy: 0.716667 -- epoch time: 8.85
# Se mejoró el loss de 0.5663747191429138 a 0.5504652261734009
# 2:  loss: 0.499757, accuracy: 0.755294, val loss: 0.545294, val accuracy: 0.720000 -- epoch time: 8.71
# Se mejoró el loss de 0.5504652261734009 a 0.545293927192688
# 3:  loss: 0.464618, accuracy: 0.778235, val loss: 0.479539, val accuracy: 0.766667 -- epoch time: 8.76
# Se mejoró el loss de 0.545293927192688 a 0.4795386791229248
# 4:  loss: 0.422658, accuracy: 0.811176, val loss: 0.541247, val accuracy: 0.730000 -- epoch time: 8.76
# 5:  loss: 0.357159, accuracy: 0.844118, val loss: 0.455769, val accuracy: 0.773333 -- epoch time: 8.73
# Se mejoró el loss de 0.4795386791229248 a 0.45576900243759155
# 6:  loss: 0.331887, accuracy: 0.866471, val loss: 0.425921, val accuracy: 0.796667 -- epoch time: 8.76
# Se mejoró el loss de 0.45576900243759155 a 0.42592108249664307
# 7:  loss: 0.307471, accuracy: 0.872941, val loss: 0.451778, val accuracy: 0.800000 -- epoch time: 9.91
# 8:  loss: 0.283067, accuracy: 0.885882, val loss: 0.519660, val accuracy: 0.750000 -- epoch time: 8.86
# 9:  loss: 0.249298, accuracy: 0.900588, val loss: 0.506145, val accuracy: 0.763333 -- epoch time: 8.92
# 10:  loss: 0.218540, accuracy: 0.919412, val loss: 0.464478, val accuracy: 0.803333 -- epoch time: 8.75
# 11:  loss: 0.193099, accuracy: 0.923529, val loss: 0.443057, val accuracy: 0.796667 -- epoch time: 8.84
# 12:  loss: 0.192312, accuracy: 0.932941, val loss: 0.481766, val accuracy: 0.786667 -- epoch time: 8.88
# 13:  loss: 0.185381, accuracy: 0.926471, val loss: 0.566322, val accuracy: 0.750000 -- epoch time: 8.87
# 14:  loss: 0.173682, accuracy: 0.931765, val loss: 0.433553, val accuracy: 0.806667 -- epoch time: 8.83
# 15:  loss: 0.144299, accuracy: 0.945882, val loss: 0.463111, val accuracy: 0.803333 -- epoch time: 8.86
# 16:  loss: 0.143966, accuracy: 0.950000, val loss: 0.561509, val accuracy: 0.740000 -- epoch time: 8.86
# 17:  loss: 0.129151, accuracy: 0.954706, val loss: 0.502575, val accuracy: 0.806667 -- epoch time: 8.86
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 160.24

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# **Base**
#
# **0.00010**(18):  loss: 0.4271/0.4590/0.5503, accuracy: 78.88%/77.33%/73.60%
#
# **Dropout**
#
# **0.00010**(23):  loss: 0.4416/0.4551/0.5274, accuracy: 78.59%/78.67%/72.50%  (paro explícito)
#
# **BatchNorm**
#
# **0.00001**(08):  loss: 0.2852/0.4706,    accuracy: 94.06%/79.33%
#
# **Dropout+BatchNorm**
#
# **0.00001**(63):  loss: 0.1835/0.4363,    accuracy: 94.00%/79.33%
#
# **0.00001**(17):  loss: 0.4700/0.4876,    accuracy: 77.77%/77.67% (paro explícito)
#
# **0.00005**(22):  loss: 0.1496/0.4726,    accuracy: 95.23%/79.67%
#
# **0.00005**(05):  loss: 0.4830/0.5129,    accuracy: 76.71%/74.67% (paro explícito)
#
# **0.00010**(18):  loss: 0.1291/0.5026,    accuracy: 95.47%/80.67%
#
# **0.00010**(04):  loss: 0.4646/0.4795,    accuracy: 77.82%/78.67% (paro explícito)

# %% [markdown]
# Vemos que el modelo con LR 10e-4, con un paro explícito en la época 4 encontramos el mejor comportamento de la configuración Dropout + Batch Norm.
# Vamos a evaluarlo sobre el test set.

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_dropout, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNormDropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-4, epocas=4, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.663132, accuracy: 0.617059, val loss: 0.566375, val accuracy: 0.700000 -- epoch time: 9.74
# Se mejoró el loss de inf a 0.5663747191429138
# 1:  loss: 0.584540, accuracy: 0.688235, val loss: 0.550465, val accuracy: 0.716667 -- epoch time: 8.85
# Se mejoró el loss de 0.5663747191429138 a 0.5504652261734009
# 2:  loss: 0.499757, accuracy: 0.755294, val loss: 0.545294, val accuracy: 0.720000 -- epoch time: 8.66
# Se mejoró el loss de 0.5504652261734009 a 0.545293927192688
# 3:  loss: 0.464618, accuracy: 0.778235, val loss: 0.479539, val accuracy: 0.766667 -- epoch time: 8.62
# Se mejoró el loss de 0.545293927192688 a 0.4795386791229248
# time: 36.14

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %%
test_loss, test_acc = eval_model(modelo_base_bnorm_dropout, test_data_loader_small)
print(f"El loss de test es {test_loss}, y el accuracy de test es de {test_acc:.3f}. ")
torch.save(modelo_base_bnorm_dropout, "cats_and_dogs_small_dropout_batchnorm.pth")
# Out:
# El loss de test es 0.521723984003067, y el accuracy de test es de 0.740.

# %% [markdown]
# Vemos que el loss del test set se bajó a 0.5217 (casi lo mismo que con dropout)pero reduciendo aún mas el overfitting. Incidentalmente, el accuracy aumento a 74%.

# %% [markdown]
# ## Parte 6. Dataset reducido - modelo con data augmentation

# %% [markdown]
# Escogemos el modelo que incluye dropout y batch normalization como la base para aplicar data augmentation.

# %% [markdown]
# La mejor manera de combatir el overfitting es obteniendo un dataset de aprendizaje mayor.
# Vamos a generar sintéticamente mas datos, algo que se puede hacer el caso de imágenes con una técnica llamada **data augmentation**.
#
# Para mitigar el problema de overfitting en el caso de datasets con pocas imágenes, se pueden crear nuevas imágenes aplicando transformaciones gráficas a las imágenes disponibles, "aumentando" así el dataset de entrenamiento de manera artificial.
#
# Como lo vimos previamente en la sección de carga de datos, se pueden utilizar las clases que se encuentran en el paquete ```torchvision.transforms```, existen además funciones equivalentes que permiten crear las transformaciones sin necesidad de instanciación.
#
# Vale la pena aclarar que estas operaciones se realizan solo sobre el dataset de entrenamiento, y que las transformaciones deben producir imágenes que corerspondan a las que se pueda encontrar el dataset de evaluación, de lo contrario, el modelo aprendería patrones lejanos a los de la distribución real de los datos.

# %% [markdown]
# Las transformaciones mas comunes a aplicar a todas las imágenes (ya sea una imagen o un batch de imágenes de train o de test) son:
# * `Resize`: establece un tamaño de las imágenes
# * `GrayScale`: modifica las imágenes entrantes de 3 canales de color a imágenes en escala de gris, ya sea con un solo canal o 3 canales iguales.
#
# Adicionalmente, las transformacipnes mas comunes a aplicar a imágenes (ya sea una imagen o un batch de imágenes) son:
#
#
# * `RandomHorizontalFlip`: crea una imagen espejo horizontal con una probabilidad dada por el argumento `p`.
# * `RandomVerticalFlip`: crea una imagen espejo vertical con una probabilidad dada por el argumento `p`.
# * `RandomAffineTransform`: permite generar varias transformaciones al tiempo, configuradas según ciertos argumentos:
#     - `degrees`: se puede establecer un un intervalo (min, max) o un escalar `d`, caso en el que se supone un rango (`-d`, `+d`).
#     - `translate`: tupla con los valores de fracción relativa máximos de traslación para cada eje. Por ejemplo, una tupla (`a`, `b`), indica que la imágen se puede trasladar hasta a\*ancho (hacia la izquierda o la derecha), y hasta a\*alto (hacia arriba o abajo). Por defecto no hay traslación.
#     - `scale`: establece una tupla con los factores de escalamiento para realizar un zoom de la imagen. Por ejemplo, una tupla (`a`, `b`), indica que la imágen va a escalar escogiendo aleatoriamente un factor entre `a` y `b`.
#     - `interpolation` permite establecer la estrategia a seguir para generar nuevos pixeles que puedan ser necesarios para las transformaciones de rotación, traslación o deformación; por defecto se copia el pixel más cercano.
#     - `shear`: permite modificar la imagen estirándola horizontal y o verticalmente. Se recibe una tupla de 4 valores definiendo los intervalos horizontales y verticales sobre los cuales se hará el tiraje aleatorio para las deformaciones.
#
# Es importante notar que existen otras transformaciones aleatorias atómicas que se pueden llegar a definir desde `RandomAffineTransform`. Particularmente tenemos `RandomRotation`, que rota las imágenes escogiendo un ángulo aleatorio; `RandomCrop`, que corta las imágenes escogiendo una región, creado un efecto de zoom, dado un tamaño aleatorio; y `RandomPerspective`, que modifica la imagen estirándola

# %% [markdown]
# Vamos a crear un flujo de transformación que incluye una `RandomAffineTransform` seguido de una `RandomHorizontalFlip`. Como esperamos que las imágenes analizadas por el modelo no estén invertidas de arribe a abajo, no es necesario aplicar una transformación `RandomVerticalFlip`.

# %%
DATA_AUG_TRANSFORMS = T.Compose([
    T.RandomAffine(degrees=(15),
                   translate=(0.15, 0.15),
                   scale=(1.15, 1.15),
                   shear=(0., 0.08*IMG_SIZE, 0., 0.08*IMG_SIZE),
                   interpolation=T.InterpolationMode.NEAREST
                   ),
    T.RandomHorizontalFlip(p=0.5)
])

# %%
imagenes, labels = next(iter(train_data_loader_small))

# %%
reset_seed()

nrows = 4 # no puede ser mas que el tamaño del batch de imágenes
ncols = 4 # número de modificaciones (-1) con la misma imagen

fig = plt.gcf()
fig.set_size_inches(ncols*2, nrows*2)

for i, (img_original, label) in enumerate(zip(imagenes[:nrows], labels[:nrows])):
    sp = plt.subplot(nrows, ncols, i*ncols+1)
    sp.axis('Off') # Don't show axes (or gridlines)
    img_canal = img_original.permute(1, 2, 0) # cambiar los canales
    plt.imshow(img_canal)

    # Creamos rotaciones de -30 a 30 grados
    #imagenes_transformadas = [T.RandomRotation(degrees=30)(img_original).permute(1, 2, 0) for i in range(3)]
    #imagenes_transformadas = [T.RandomCrop(size=np.floor(0.75*IMG_SIZE), pad_if_needed=True)(img_original).permute(1, 2, 0) for i in range(3)]
    #imagenes_transformadas = [T.RandomPerspective(distortion_scale=0.5, p=0.5)(img_original).permute(1, 2, 0) for i in range(3)]
    #imagenes_transformadas = [T.RandomAffine(degrees=30)(img_original).permute(1, 2, 0) for i in range(3)] # rotación
    #imagenes_transformadas = [T.RandomAffine(degrees=0, translate=(0.2, 0.2))(img_original).permute(1, 2, 0) for i in range(3)] # translación
    #imagenes_transformadas = [T.RandomAffine(degrees=0, scale=(1.0, 1.5))(img_original).permute(1, 2, 0) for i in range(3)] #  zoom y crop
    #imagenes_transformadas = [T.RandomAffine(degrees=0, shear=(0., 0.2*IMG_SIZE, 0., 0.2*IMG_SIZE))(img_original).permute(1, 2, 0) for i in range(3)] #  deformación
    #imagenes_transformadas = [T.RandomAffine(degrees=(20), translate=(0.2, 0.2), scale=(1.2, 1.2), shear=(0., 0.10*IMG_SIZE, 0., 0.10*IMG_SIZE))(img_original).permute(1, 2, 0) for i in range(3)] #  de todo
    #imagenes_transformadas = [T.RandomHorizontalFlip(p=0.5)(img_original).permute(1, 2, 0) for i in range(3)]
    #imagenes_transformadas = [T.RandomVerticalFlip(p=0.5)(img_original).permute(1, 2, 0) for i in range(3)]
    imagenes_transformadas = [DATA_AUG_TRANSFORMS(img_original).permute(1, 2, 0) for i in range(3)] #  de todo

    for j, img_trans in enumerate(imagenes_transformadas):
        sp = plt.subplot(nrows, ncols, i*ncols+2+j)
        sp.axis('Off') # Don't show axes (or gridlines)
        plt.imshow(img_trans)

plt.show()

# %%
DATA_AUG_TRANSFORMS = T.Compose([
    T.RandomAffine(degrees=(30),
                   translate=(0.2, 0.2),
                   scale=(1.10, 1.10),
                   shear=(0., 0.2*IMG_SIZE, 0., 0.2*IMG_SIZE),
                   interpolation=T.InterpolationMode.NEAREST
                   ),
    T.RandomHorizontalFlip(p=0.5)
])

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_dropout_dataaug_1e5, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNormDropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-5, epocas=100, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, transformaciones=DATA_AUG_TRANSFORMS, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.701591, accuracy: 0.533529, val loss: 0.644087, val accuracy: 0.646667 -- epoch time: 8.92
# Se mejoró el loss de inf a 0.6440865993499756
# 1:  loss: 0.680661, accuracy: 0.574706, val loss: 0.624726, val accuracy: 0.643333 -- epoch time: 9.47
# Se mejoró el loss de 0.6440865993499756 a 0.6247255802154541
# 2:  loss: 0.667743, accuracy: 0.589412, val loss: 0.625082, val accuracy: 0.683333 -- epoch time: 9.72
# 3:  loss: 0.668625, accuracy: 0.594118, val loss: 0.614421, val accuracy: 0.666667 -- epoch time: 8.90
# Se mejoró el loss de 0.6247255802154541 a 0.6144210696220398
# 4:  loss: 0.669684, accuracy: 0.590588, val loss: 0.611196, val accuracy: 0.670000 -- epoch time: 8.86
# Se mejoró el loss de 0.6144210696220398 a 0.6111955046653748
# 5:  loss: 0.654656, accuracy: 0.612353, val loss: 0.605117, val accuracy: 0.670000 -- epoch time: 8.94
# Se mejoró el loss de 0.6111955046653748 a 0.6051168441772461
# 6:  loss: 0.664386, accuracy: 0.604118, val loss: 0.598576, val accuracy: 0.663333 -- epoch time: 8.95
# Se mejoró el loss de 0.6051168441772461 a 0.5985763072967529
# 7:  loss: 0.648580, accuracy: 0.622941, val loss: 0.598106, val accuracy: 0.696667 -- epoch time: 8.88
# Se mejoró el loss de 0.5985763072967529 a 0.5981061458587646
# 8:  loss: 0.654693, accuracy: 0.619412, val loss: 0.597305, val accuracy: 0.693333 -- epoch time: 8.87
# Se mejoró el loss de 0.5981061458587646 a 0.5973048210144043
# 9:  loss: 0.657776, accuracy: 0.614706, val loss: 0.591089, val accuracy: 0.696667 -- epoch time: 8.94
# Se mejoró el loss de 0.5973048210144043 a 0.5910887122154236
# 10:  loss: 0.636748, accuracy: 0.625882, val loss: 0.581761, val accuracy: 0.703333 -- epoch time: 8.88
# Se mejoró el loss de 0.5910887122154236 a 0.581761360168457
# 11:  loss: 0.642450, accuracy: 0.644118, val loss: 0.577626, val accuracy: 0.703333 -- epoch time: 8.78
# Se mejoró el loss de 0.581761360168457 a 0.5776258111000061
# 12:  loss: 0.632031, accuracy: 0.634706, val loss: 0.571808, val accuracy: 0.683333 -- epoch time: 8.82
# Se mejoró el loss de 0.5776258111000061 a 0.5718080997467041
# 13:  loss: 0.643635, accuracy: 0.631765, val loss: 0.570122, val accuracy: 0.693333 -- epoch time: 9.23
# Se mejoró el loss de 0.5718080997467041 a 0.570121705532074
# 14:  loss: 0.635234, accuracy: 0.630000, val loss: 0.570321, val accuracy: 0.706667 -- epoch time: 9.01
# 15:  loss: 0.638411, accuracy: 0.635294, val loss: 0.564484, val accuracy: 0.706667 -- epoch time: 10.02
# Se mejoró el loss de 0.570121705532074 a 0.5644838809967041
# 16:  loss: 0.618823, accuracy: 0.653529, val loss: 0.560274, val accuracy: 0.706667 -- epoch time: 8.97
# Se mejoró el loss de 0.5644838809967041 a 0.5602744817733765
# 17:  loss: 0.633152, accuracy: 0.632941, val loss: 0.554113, val accuracy: 0.700000 -- epoch time: 8.90
# Se mejoró el loss de 0.5602744817733765 a 0.5541133880615234
# 18:  loss: 0.621372, accuracy: 0.642353, val loss: 0.550445, val accuracy: 0.736667 -- epoch time: 8.90
# Se mejoró el loss de 0.5541133880615234 a 0.5504446029663086
# 19:  loss: 0.631650, accuracy: 0.643529, val loss: 0.547681, val accuracy: 0.736667 -- epoch time: 8.91
# Se mejoró el loss de 0.5504446029663086 a 0.5476809740066528
# 20:  loss: 0.613280, accuracy: 0.662941, val loss: 0.544479, val accuracy: 0.730000 -- epoch time: 8.84
# Se mejoró el loss de 0.5476809740066528 a 0.5444794297218323
# 21:  loss: 0.618334, accuracy: 0.648824, val loss: 0.541415, val accuracy: 0.750000 -- epoch time: 8.90
# Se mejoró el loss de 0.5444794297218323 a 0.5414150357246399
# 22:  loss: 0.620595, accuracy: 0.657647, val loss: 0.544529, val accuracy: 0.720000 -- epoch time: 8.94
# 23:  loss: 0.612701, accuracy: 0.674706, val loss: 0.537664, val accuracy: 0.733333 -- epoch time: 8.96
# Se mejoró el loss de 0.5414150357246399 a 0.5376641750335693
# 24:  loss: 0.614697, accuracy: 0.647059, val loss: 0.529711, val accuracy: 0.736667 -- epoch time: 8.82
# Se mejoró el loss de 0.5376641750335693 a 0.5297110676765442
# 25:  loss: 0.600569, accuracy: 0.670588, val loss: 0.529280, val accuracy: 0.740000 -- epoch time: 9.20
# Se mejoró el loss de 0.5297110676765442 a 0.5292801856994629
# 26:  loss: 0.619703, accuracy: 0.650588, val loss: 0.526378, val accuracy: 0.750000 -- epoch time: 8.87
# Se mejoró el loss de 0.5292801856994629 a 0.5263779163360596
# 27:  loss: 0.604890, accuracy: 0.680000, val loss: 0.527397, val accuracy: 0.743333 -- epoch time: 8.84
# 28:  loss: 0.602379, accuracy: 0.664118, val loss: 0.534040, val accuracy: 0.740000 -- epoch time: 8.94
# 29:  loss: 0.596250, accuracy: 0.681765, val loss: 0.528521, val accuracy: 0.750000 -- epoch time: 8.88
# 30:  loss: 0.584946, accuracy: 0.688235, val loss: 0.528897, val accuracy: 0.740000 -- epoch time: 8.84
# 31:  loss: 0.607398, accuracy: 0.662353, val loss: 0.518057, val accuracy: 0.743333 -- epoch time: 8.89
# Se mejoró el loss de 0.5263779163360596 a 0.5180570483207703
# 32:  loss: 0.612021, accuracy: 0.655882, val loss: 0.520657, val accuracy: 0.743333 -- epoch time: 8.83
# 33:  loss: 0.588679, accuracy: 0.687647, val loss: 0.518813, val accuracy: 0.726667 -- epoch time: 10.04
# 34:  loss: 0.579798, accuracy: 0.692353, val loss: 0.532880, val accuracy: 0.700000 -- epoch time: 8.85
# 35:  loss: 0.589395, accuracy: 0.687059, val loss: 0.515119, val accuracy: 0.743333 -- epoch time: 8.81
# Se mejoró el loss de 0.5180570483207703 a 0.5151187181472778
# 36:  loss: 0.593850, accuracy: 0.674118, val loss: 0.517055, val accuracy: 0.743333 -- epoch time: 8.92
# 37:  loss: 0.567768, accuracy: 0.704118, val loss: 0.503014, val accuracy: 0.766667 -- epoch time: 8.83
# Se mejoró el loss de 0.5151187181472778 a 0.5030141472816467
# 38:  loss: 0.578213, accuracy: 0.688824, val loss: 0.512368, val accuracy: 0.746667 -- epoch time: 8.78
# 39:  loss: 0.594558, accuracy: 0.695882, val loss: 0.500460, val accuracy: 0.760000 -- epoch time: 8.71
# Se mejoró el loss de 0.5030141472816467 a 0.500460147857666
# 40:  loss: 0.562357, accuracy: 0.710588, val loss: 0.504049, val accuracy: 0.750000 -- epoch time: 8.82
# 41:  loss: 0.583912, accuracy: 0.694706, val loss: 0.489448, val accuracy: 0.760000 -- epoch time: 8.94
# Se mejoró el loss de 0.500460147857666 a 0.48944804072380066
# 42:  loss: 0.571858, accuracy: 0.694118, val loss: 0.488908, val accuracy: 0.760000 -- epoch time: 8.76
# Se mejoró el loss de 0.48944804072380066 a 0.48890841007232666
# 43:  loss: 0.579690, accuracy: 0.700588, val loss: 0.492829, val accuracy: 0.770000 -- epoch time: 8.97
# 44:  loss: 0.573113, accuracy: 0.687059, val loss: 0.497138, val accuracy: 0.753333 -- epoch time: 8.85
# 45:  loss: 0.561572, accuracy: 0.714118, val loss: 0.489504, val accuracy: 0.756667 -- epoch time: 8.84
# 46:  loss: 0.569417, accuracy: 0.695294, val loss: 0.504487, val accuracy: 0.766667 -- epoch time: 8.86
# 47:  loss: 0.560234, accuracy: 0.698235, val loss: 0.492692, val accuracy: 0.750000 -- epoch time: 8.71
# 48:  loss: 0.573732, accuracy: 0.705294, val loss: 0.543366, val accuracy: 0.720000 -- epoch time: 8.83
# 49:  loss: 0.568914, accuracy: 0.689412, val loss: 0.483193, val accuracy: 0.770000 -- epoch time: 8.83
# Se mejoró el loss de 0.48890841007232666 a 0.48319292068481445
# 50:  loss: 0.578428, accuracy: 0.696471, val loss: 0.492240, val accuracy: 0.763333 -- epoch time: 8.79
# 51:  loss: 0.562676, accuracy: 0.708235, val loss: 0.482651, val accuracy: 0.760000 -- epoch time: 9.80
# Se mejoró el loss de 0.48319292068481445 a 0.48265111446380615
# 52:  loss: 0.561757, accuracy: 0.700000, val loss: 0.484183, val accuracy: 0.770000 -- epoch time: 8.71
# 53:  loss: 0.561992, accuracy: 0.697059, val loss: 0.473248, val accuracy: 0.780000 -- epoch time: 8.67
# Se mejoró el loss de 0.48265111446380615 a 0.4732482433319092
# 54:  loss: 0.555057, accuracy: 0.715294, val loss: 0.480184, val accuracy: 0.760000 -- epoch time: 8.76
# 55:  loss: 0.546638, accuracy: 0.727647, val loss: 0.475593, val accuracy: 0.770000 -- epoch time: 8.81
# 56:  loss: 0.563887, accuracy: 0.706471, val loss: 0.494215, val accuracy: 0.750000 -- epoch time: 8.77
# 57:  loss: 0.562891, accuracy: 0.719412, val loss: 0.474811, val accuracy: 0.766667 -- epoch time: 8.80
# 58:  loss: 0.562639, accuracy: 0.720588, val loss: 0.474799, val accuracy: 0.776667 -- epoch time: 8.85
# 59:  loss: 0.549815, accuracy: 0.714706, val loss: 0.476183, val accuracy: 0.780000 -- epoch time: 8.81
# 60:  loss: 0.551427, accuracy: 0.724118, val loss: 0.489481, val accuracy: 0.763333 -- epoch time: 8.77
# 61:  loss: 0.545496, accuracy: 0.725882, val loss: 0.479486, val accuracy: 0.776667 -- epoch time: 8.81
# 62:  loss: 0.567309, accuracy: 0.710000, val loss: 0.480205, val accuracy: 0.773333 -- epoch time: 8.81
# 63:  loss: 0.538400, accuracy: 0.732941, val loss: 0.476194, val accuracy: 0.773333 -- epoch time: 8.83
# 64:  loss: 0.549542, accuracy: 0.721176, val loss: 0.527946, val accuracy: 0.736667 -- epoch time: 8.83
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 582.38

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# Podemos ver que con el data augmentation y la creación de instancias modificadas el problema del overfitting se ha arreglado con una evolución del loss de validación reduciéndose más rápidamente que el loss del training. Alcanzamos con un LR muy bajo de 5e-5 un nivel de loss en validación inferior a los modelos previos (0.4732) con un accuracy del 78%.
# La velocidad de reducción del loss no es mu alta, por lo que vamos a intentar aumentando el LR.

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_dropout_dataaug_5e5, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNormDropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=5e-5, epocas=100, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, transformaciones=DATA_AUG_TRANSFORMS, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.686520, accuracy: 0.581176, val loss: 0.612343, val accuracy: 0.663333 -- epoch time: 8.84
# Se mejoró el loss de inf a 0.6123427748680115
# 1:  loss: 0.653427, accuracy: 0.624118, val loss: 0.582377, val accuracy: 0.686667 -- epoch time: 8.82
# Se mejoró el loss de 0.6123427748680115 a 0.5823767185211182
# 2:  loss: 0.656350, accuracy: 0.608235, val loss: 0.601644, val accuracy: 0.676667 -- epoch time: 8.82
# 3:  loss: 0.650712, accuracy: 0.620000, val loss: 0.580702, val accuracy: 0.686667 -- epoch time: 8.85
# Se mejoró el loss de 0.5823767185211182 a 0.5807019472122192
# 4:  loss: 0.647371, accuracy: 0.631765, val loss: 0.570602, val accuracy: 0.703333 -- epoch time: 9.90
# Se mejoró el loss de 0.5807019472122192 a 0.5706015229225159
# 5:  loss: 0.622456, accuracy: 0.647647, val loss: 0.560937, val accuracy: 0.730000 -- epoch time: 8.87
# Se mejoró el loss de 0.5706015229225159 a 0.5609365701675415
# 6:  loss: 0.635652, accuracy: 0.640588, val loss: 0.543890, val accuracy: 0.723333 -- epoch time: 8.74
# Se mejoró el loss de 0.5609365701675415 a 0.543890118598938
# 7:  loss: 0.603295, accuracy: 0.678824, val loss: 0.543396, val accuracy: 0.740000 -- epoch time: 8.91
# Se mejoró el loss de 0.543890118598938 a 0.5433959364891052
# 8:  loss: 0.618495, accuracy: 0.654118, val loss: 0.539979, val accuracy: 0.716667 -- epoch time: 8.79
# Se mejoró el loss de 0.5433959364891052 a 0.5399792790412903
# 9:  loss: 0.610368, accuracy: 0.670000, val loss: 0.549915, val accuracy: 0.710000 -- epoch time: 8.89
# 10:  loss: 0.591571, accuracy: 0.682353, val loss: 0.511604, val accuracy: 0.756667 -- epoch time: 8.80
# Se mejoró el loss de 0.5399792790412903 a 0.5116040110588074
# 11:  loss: 0.596572, accuracy: 0.670588, val loss: 0.516411, val accuracy: 0.756667 -- epoch time: 8.79
# 12:  loss: 0.584558, accuracy: 0.690000, val loss: 0.512607, val accuracy: 0.740000 -- epoch time: 8.77
# 13:  loss: 0.596313, accuracy: 0.680588, val loss: 0.505634, val accuracy: 0.746667 -- epoch time: 8.67
# Se mejoró el loss de 0.5116040110588074 a 0.5056337118148804
# 14:  loss: 0.577768, accuracy: 0.708824, val loss: 0.507225, val accuracy: 0.763333 -- epoch time: 8.72
# 15:  loss: 0.587131, accuracy: 0.695882, val loss: 0.495702, val accuracy: 0.753333 -- epoch time: 8.81
# Se mejoró el loss de 0.5056337118148804 a 0.4957020580768585
# 16:  loss: 0.557859, accuracy: 0.714118, val loss: 0.480226, val accuracy: 0.773333 -- epoch time: 8.93
# Se mejoró el loss de 0.4957020580768585 a 0.48022645711898804
# 17:  loss: 0.569059, accuracy: 0.710588, val loss: 0.507633, val accuracy: 0.760000 -- epoch time: 8.79
# 18:  loss: 0.552917, accuracy: 0.705294, val loss: 0.474120, val accuracy: 0.796667 -- epoch time: 8.83
# Se mejoró el loss de 0.48022645711898804 a 0.4741195738315582
# 19:  loss: 0.575524, accuracy: 0.701765, val loss: 0.453493, val accuracy: 0.773333 -- epoch time: 8.85
# Se mejoró el loss de 0.4741195738315582 a 0.45349326729774475
# 20:  loss: 0.547242, accuracy: 0.724706, val loss: 0.482003, val accuracy: 0.773333 -- epoch time: 8.76
# 21:  loss: 0.557129, accuracy: 0.710588, val loss: 0.484231, val accuracy: 0.780000 -- epoch time: 8.92
# 22:  loss: 0.542600, accuracy: 0.717647, val loss: 0.464437, val accuracy: 0.766667 -- epoch time: 9.86
# 23:  loss: 0.535783, accuracy: 0.728235, val loss: 0.449245, val accuracy: 0.796667 -- epoch time: 8.85
# Se mejoró el loss de 0.45349326729774475 a 0.44924455881118774
# 24:  loss: 0.551629, accuracy: 0.714118, val loss: 0.480398, val accuracy: 0.743333 -- epoch time: 8.83
# 25:  loss: 0.531809, accuracy: 0.727647, val loss: 0.448771, val accuracy: 0.763333 -- epoch time: 8.88
# Se mejoró el loss de 0.44924455881118774 a 0.448771208524704
# 26:  loss: 0.538364, accuracy: 0.731765, val loss: 0.475779, val accuracy: 0.766667 -- epoch time: 8.78
# 27:  loss: 0.528968, accuracy: 0.732941, val loss: 0.456508, val accuracy: 0.773333 -- epoch time: 8.75
# 28:  loss: 0.532703, accuracy: 0.737647, val loss: 0.482293, val accuracy: 0.766667 -- epoch time: 8.88
# 29:  loss: 0.508832, accuracy: 0.749412, val loss: 0.465511, val accuracy: 0.780000 -- epoch time: 8.86
# 30:  loss: 0.530614, accuracy: 0.744118, val loss: 0.466518, val accuracy: 0.773333 -- epoch time: 8.82
# 31:  loss: 0.536233, accuracy: 0.725882, val loss: 0.454849, val accuracy: 0.780000 -- epoch time: 8.77
# 32:  loss: 0.539633, accuracy: 0.710588, val loss: 0.449470, val accuracy: 0.796667 -- epoch time: 8.77
# 33:  loss: 0.509519, accuracy: 0.734706, val loss: 0.460214, val accuracy: 0.780000 -- epoch time: 8.87
# 34:  loss: 0.495610, accuracy: 0.752353, val loss: 0.583273, val accuracy: 0.706667 -- epoch time: 8.80
# 35:  loss: 0.513748, accuracy: 0.750000, val loss: 0.452276, val accuracy: 0.800000 -- epoch time: 8.90
# 36:  loss: 0.510483, accuracy: 0.764706, val loss: 0.456373, val accuracy: 0.773333 -- epoch time: 8.83
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 329.31

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_dropout_dataaug_1e4, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNormDropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-4, epocas=100, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, transformaciones=DATA_AUG_TRANSFORMS, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.690383, accuracy: 0.579412, val loss: 0.602223, val accuracy: 0.680000 -- epoch time: 8.91
# Se mejoró el loss de inf a 0.6022225022315979
# 1:  loss: 0.660901, accuracy: 0.615294, val loss: 0.566002, val accuracy: 0.716667 -- epoch time: 8.86
# Se mejoró el loss de 0.6022225022315979 a 0.5660020112991333
# 2:  loss: 0.669430, accuracy: 0.602941, val loss: 0.585113, val accuracy: 0.693333 -- epoch time: 8.98
# 3:  loss: 0.642840, accuracy: 0.637059, val loss: 0.557541, val accuracy: 0.716667 -- epoch time: 9.84
# Se mejoró el loss de 0.5660020112991333 a 0.5575411319732666
# 4:  loss: 0.635217, accuracy: 0.658824, val loss: 0.539566, val accuracy: 0.726667 -- epoch time: 8.84
# Se mejoró el loss de 0.5575411319732666 a 0.5395659804344177
# 5:  loss: 0.620759, accuracy: 0.656471, val loss: 0.533838, val accuracy: 0.740000 -- epoch time: 8.86
# Se mejoró el loss de 0.5395659804344177 a 0.5338376760482788
# 6:  loss: 0.634856, accuracy: 0.650000, val loss: 0.547985, val accuracy: 0.720000 -- epoch time: 8.83
# 7:  loss: 0.597950, accuracy: 0.670588, val loss: 0.507682, val accuracy: 0.763333 -- epoch time: 8.83
# Se mejoró el loss de 0.5338376760482788 a 0.5076823830604553
# 8:  loss: 0.602361, accuracy: 0.685882, val loss: 0.514901, val accuracy: 0.740000 -- epoch time: 8.82
# 9:  loss: 0.600317, accuracy: 0.689412, val loss: 0.527904, val accuracy: 0.743333 -- epoch time: 8.77
# 10:  loss: 0.580511, accuracy: 0.699412, val loss: 0.488188, val accuracy: 0.760000 -- epoch time: 8.87
# Se mejoró el loss de 0.5076823830604553 a 0.4881877303123474
# 11:  loss: 0.571923, accuracy: 0.699412, val loss: 0.508056, val accuracy: 0.780000 -- epoch time: 8.88
# 12:  loss: 0.567395, accuracy: 0.711176, val loss: 0.478319, val accuracy: 0.770000 -- epoch time: 8.81
# Se mejoró el loss de 0.4881877303123474 a 0.4783194661140442
# 13:  loss: 0.577155, accuracy: 0.707647, val loss: 0.492244, val accuracy: 0.786667 -- epoch time: 8.97
# 14:  loss: 0.565068, accuracy: 0.704118, val loss: 0.476269, val accuracy: 0.790000 -- epoch time: 8.74
# Se mejoró el loss de 0.4783194661140442 a 0.4762685298919678
# 15:  loss: 0.569299, accuracy: 0.694706, val loss: 0.463221, val accuracy: 0.766667 -- epoch time: 8.76
# Se mejoró el loss de 0.4762685298919678 a 0.4632205367088318
# 16:  loss: 0.540225, accuracy: 0.725882, val loss: 0.458954, val accuracy: 0.773333 -- epoch time: 8.91
# Se mejoró el loss de 0.4632205367088318 a 0.4589542746543884
# 17:  loss: 0.544764, accuracy: 0.723529, val loss: 0.473868, val accuracy: 0.766667 -- epoch time: 8.89
# 18:  loss: 0.531718, accuracy: 0.724706, val loss: 0.448159, val accuracy: 0.803333 -- epoch time: 8.78
# Se mejoró el loss de 0.4589542746543884 a 0.4481593370437622
# 19:  loss: 0.549656, accuracy: 0.715882, val loss: 0.451585, val accuracy: 0.780000 -- epoch time: 8.88
# 20:  loss: 0.521977, accuracy: 0.742353, val loss: 0.454168, val accuracy: 0.786667 -- epoch time: 8.83
# 21:  loss: 0.538040, accuracy: 0.721765, val loss: 0.471784, val accuracy: 0.783333 -- epoch time: 9.72
# 22:  loss: 0.518273, accuracy: 0.742353, val loss: 0.443300, val accuracy: 0.806667 -- epoch time: 8.86
# Se mejoró el loss de 0.4481593370437622 a 0.4433000683784485
# 23:  loss: 0.512027, accuracy: 0.742941, val loss: 0.444971, val accuracy: 0.773333 -- epoch time: 8.81
# 24:  loss: 0.527863, accuracy: 0.741765, val loss: 0.510046, val accuracy: 0.756667 -- epoch time: 8.85
# 25:  loss: 0.511434, accuracy: 0.745294, val loss: 0.444563, val accuracy: 0.793333 -- epoch time: 8.80
# 26:  loss: 0.510229, accuracy: 0.745882, val loss: 0.469922, val accuracy: 0.763333 -- epoch time: 8.75
# 27:  loss: 0.506504, accuracy: 0.750000, val loss: 0.440269, val accuracy: 0.776667 -- epoch time: 8.87
# Se mejoró el loss de 0.4433000683784485 a 0.4402685761451721
# 28:  loss: 0.512987, accuracy: 0.738824, val loss: 0.447706, val accuracy: 0.780000 -- epoch time: 8.67
# 29:  loss: 0.493369, accuracy: 0.762941, val loss: 0.440839, val accuracy: 0.803333 -- epoch time: 8.93
# 30:  loss: 0.501550, accuracy: 0.752353, val loss: 0.465055, val accuracy: 0.786667 -- epoch time: 8.85
# 31:  loss: 0.510200, accuracy: 0.741176, val loss: 0.406090, val accuracy: 0.806667 -- epoch time: 8.75
# Se mejoró el loss de 0.4402685761451721 a 0.4060896337032318
# 32:  loss: 0.503764, accuracy: 0.737059, val loss: 0.451185, val accuracy: 0.800000 -- epoch time: 8.82
# 33:  loss: 0.491822, accuracy: 0.757059, val loss: 0.428989, val accuracy: 0.796667 -- epoch time: 8.75
# 34:  loss: 0.472049, accuracy: 0.769412, val loss: 0.542542, val accuracy: 0.740000 -- epoch time: 8.75
# 35:  loss: 0.486215, accuracy: 0.777059, val loss: 0.448397, val accuracy: 0.790000 -- epoch time: 8.91
# 36:  loss: 0.486807, accuracy: 0.765882, val loss: 0.441355, val accuracy: 0.793333 -- epoch time: 8.89
# 37:  loss: 0.468657, accuracy: 0.789412, val loss: 0.390015, val accuracy: 0.826667 -- epoch time: 8.82
# Se mejoró el loss de 0.4060896337032318 a 0.39001521468162537
# 38:  loss: 0.475014, accuracy: 0.779412, val loss: 0.457167, val accuracy: 0.776667 -- epoch time: 8.91
# 39:  loss: 0.492224, accuracy: 0.765882, val loss: 0.395523, val accuracy: 0.823333 -- epoch time: 9.74
# 40:  loss: 0.461718, accuracy: 0.787059, val loss: 0.403236, val accuracy: 0.810000 -- epoch time: 8.86
# 41:  loss: 0.498886, accuracy: 0.760588, val loss: 0.390297, val accuracy: 0.823333 -- epoch time: 8.77
# 42:  loss: 0.453959, accuracy: 0.790000, val loss: 0.404077, val accuracy: 0.816667 -- epoch time: 8.86
# 43:  loss: 0.461989, accuracy: 0.785294, val loss: 0.418262, val accuracy: 0.786667 -- epoch time: 8.89
# 44:  loss: 0.470972, accuracy: 0.772353, val loss: 0.434497, val accuracy: 0.820000 -- epoch time: 8.85
# 45:  loss: 0.462680, accuracy: 0.784706, val loss: 0.416244, val accuracy: 0.803333 -- epoch time: 8.81
# 46:  loss: 0.476795, accuracy: 0.779412, val loss: 0.421568, val accuracy: 0.816667 -- epoch time: 8.84
# 47:  loss: 0.433490, accuracy: 0.789412, val loss: 0.401298, val accuracy: 0.790000 -- epoch time: 8.87
# 48:  loss: 0.470911, accuracy: 0.782941, val loss: 0.391550, val accuracy: 0.800000 -- epoch time: 8.92
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 436.79

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_dropout_dataaug_5e4, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNormDropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=5e-4, epocas=100, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, transformaciones=DATA_AUG_TRANSFORMS, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.723811, accuracy: 0.586471, val loss: 0.647371, val accuracy: 0.616667 -- epoch time: 8.87
# Se mejoró el loss de inf a 0.647371232509613
# 1:  loss: 0.675623, accuracy: 0.618235, val loss: 0.583989, val accuracy: 0.713333 -- epoch time: 8.80
# Se mejoró el loss de 0.647371232509613 a 0.5839892029762268
# 2:  loss: 0.648717, accuracy: 0.638235, val loss: 0.611471, val accuracy: 0.650000 -- epoch time: 8.81
# 3:  loss: 0.632892, accuracy: 0.641176, val loss: 0.583369, val accuracy: 0.693333 -- epoch time: 8.81
# Se mejoró el loss de 0.5839892029762268 a 0.5833690762519836
# 4:  loss: 0.628626, accuracy: 0.647647, val loss: 0.557130, val accuracy: 0.700000 -- epoch time: 8.81
# Se mejoró el loss de 0.5833690762519836 a 0.5571302175521851
# 5:  loss: 0.618879, accuracy: 0.664706, val loss: 0.546889, val accuracy: 0.720000 -- epoch time: 8.83
# Se mejoró el loss de 0.5571302175521851 a 0.546889066696167
# 6:  loss: 0.622699, accuracy: 0.648235, val loss: 0.587644, val accuracy: 0.696667 -- epoch time: 8.85
# 7:  loss: 0.602056, accuracy: 0.680588, val loss: 0.524136, val accuracy: 0.743333 -- epoch time: 8.90
# Se mejoró el loss de 0.546889066696167 a 0.5241361260414124
# 8:  loss: 0.595054, accuracy: 0.683529, val loss: 0.537584, val accuracy: 0.703333 -- epoch time: 9.64
# 9:  loss: 0.579238, accuracy: 0.694706, val loss: 0.546589, val accuracy: 0.723333 -- epoch time: 8.82
# 10:  loss: 0.579476, accuracy: 0.692353, val loss: 0.511746, val accuracy: 0.753333 -- epoch time: 8.82
# Se mejoró el loss de 0.5241361260414124 a 0.511745810508728
# 11:  loss: 0.565009, accuracy: 0.710588, val loss: 0.629595, val accuracy: 0.676667 -- epoch time: 8.89
# 12:  loss: 0.563973, accuracy: 0.701176, val loss: 0.576768, val accuracy: 0.693333 -- epoch time: 8.90
# 13:  loss: 0.575196, accuracy: 0.708235, val loss: 0.521572, val accuracy: 0.750000 -- epoch time: 8.91
# 14:  loss: 0.554226, accuracy: 0.730588, val loss: 0.452197, val accuracy: 0.806667 -- epoch time: 8.87
# Se mejoró el loss de 0.511745810508728 a 0.45219680666923523
# 15:  loss: 0.555209, accuracy: 0.715294, val loss: 0.497072, val accuracy: 0.763333 -- epoch time: 8.78
# 16:  loss: 0.541079, accuracy: 0.725294, val loss: 0.545655, val accuracy: 0.736667 -- epoch time: 8.93
# 17:  loss: 0.544806, accuracy: 0.719412, val loss: 0.453235, val accuracy: 0.783333 -- epoch time: 8.98
# 18:  loss: 0.527144, accuracy: 0.743529, val loss: 0.421974, val accuracy: 0.793333 -- epoch time: 8.86
# Se mejoró el loss de 0.45219680666923523 a 0.42197364568710327
# 19:  loss: 0.538031, accuracy: 0.734706, val loss: 0.409844, val accuracy: 0.826667 -- epoch time: 8.78
# Se mejoró el loss de 0.42197364568710327 a 0.40984439849853516
# 20:  loss: 0.513450, accuracy: 0.741176, val loss: 0.454375, val accuracy: 0.783333 -- epoch time: 8.84
# 21:  loss: 0.527665, accuracy: 0.733529, val loss: 0.460712, val accuracy: 0.793333 -- epoch time: 8.75
# 22:  loss: 0.503228, accuracy: 0.751176, val loss: 0.422060, val accuracy: 0.796667 -- epoch time: 8.91
# 23:  loss: 0.521047, accuracy: 0.740000, val loss: 0.462804, val accuracy: 0.750000 -- epoch time: 8.87
# 24:  loss: 0.526579, accuracy: 0.740000, val loss: 0.516523, val accuracy: 0.730000 -- epoch time: 8.83
# 25:  loss: 0.491597, accuracy: 0.762941, val loss: 0.427917, val accuracy: 0.770000 -- epoch time: 8.91
# 26:  loss: 0.496762, accuracy: 0.767059, val loss: 0.473242, val accuracy: 0.760000 -- epoch time: 8.85
# 27:  loss: 0.496825, accuracy: 0.762941, val loss: 0.417732, val accuracy: 0.780000 -- epoch time: 9.93
# 28:  loss: 0.492350, accuracy: 0.757059, val loss: 0.415607, val accuracy: 0.793333 -- epoch time: 8.86
# 29:  loss: 0.480173, accuracy: 0.768235, val loss: 0.402786, val accuracy: 0.820000 -- epoch time: 8.82
# Se mejoró el loss de 0.40984439849853516 a 0.4027857780456543
# 30:  loss: 0.503895, accuracy: 0.757647, val loss: 0.430199, val accuracy: 0.786667 -- epoch time: 8.86
# 31:  loss: 0.499168, accuracy: 0.760588, val loss: 0.398537, val accuracy: 0.820000 -- epoch time: 8.86
# Se mejoró el loss de 0.4027857780456543 a 0.39853745698928833
# 32:  loss: 0.491426, accuracy: 0.747059, val loss: 0.459625, val accuracy: 0.780000 -- epoch time: 8.86
# 33:  loss: 0.479287, accuracy: 0.777647, val loss: 0.385521, val accuracy: 0.826667 -- epoch time: 8.96
# Se mejoró el loss de 0.39853745698928833 a 0.3855205476284027
# 34:  loss: 0.463443, accuracy: 0.787059, val loss: 0.486404, val accuracy: 0.770000 -- epoch time: 8.92
# 35:  loss: 0.487904, accuracy: 0.768824, val loss: 0.472512, val accuracy: 0.790000 -- epoch time: 8.92
# 36:  loss: 0.464577, accuracy: 0.782353, val loss: 0.392639, val accuracy: 0.813333 -- epoch time: 8.81
# 37:  loss: 0.458656, accuracy: 0.788235, val loss: 0.355488, val accuracy: 0.846667 -- epoch time: 8.83
# Se mejoró el loss de 0.3855205476284027 a 0.3554879426956177
# 38:  loss: 0.461160, accuracy: 0.784706, val loss: 0.424060, val accuracy: 0.813333 -- epoch time: 8.89
# 39:  loss: 0.467790, accuracy: 0.771765, val loss: 0.389496, val accuracy: 0.820000 -- epoch time: 8.86
# 40:  loss: 0.436686, accuracy: 0.808824, val loss: 0.348369, val accuracy: 0.833333 -- epoch time: 8.86
# Se mejoró el loss de 0.3554879426956177 a 0.34836938977241516
# 41:  loss: 0.470037, accuracy: 0.774118, val loss: 0.361688, val accuracy: 0.826667 -- epoch time: 8.82
# 42:  loss: 0.440257, accuracy: 0.794706, val loss: 0.370896, val accuracy: 0.846667 -- epoch time: 8.81
# 43:  loss: 0.447880, accuracy: 0.796471, val loss: 0.383091, val accuracy: 0.833333 -- epoch time: 8.85
# 44:  loss: 0.458357, accuracy: 0.781765, val loss: 0.422933, val accuracy: 0.796667 -- epoch time: 8.94
# 45:  loss: 0.450539, accuracy: 0.795882, val loss: 0.355056, val accuracy: 0.846667 -- epoch time: 9.93
# 46:  loss: 0.460637, accuracy: 0.784118, val loss: 0.442698, val accuracy: 0.793333 -- epoch time: 8.94
# 47:  loss: 0.414798, accuracy: 0.812353, val loss: 0.344811, val accuracy: 0.846667 -- epoch time: 8.84
# Se mejoró el loss de 0.34836938977241516 a 0.3448105454444885
# 48:  loss: 0.444298, accuracy: 0.801176, val loss: 0.367828, val accuracy: 0.830000 -- epoch time: 8.87
# 49:  loss: 0.445365, accuracy: 0.802941, val loss: 0.394526, val accuracy: 0.826667 -- epoch time: 8.83
# 50:  loss: 0.447978, accuracy: 0.800000, val loss: 0.337196, val accuracy: 0.846667 -- epoch time: 8.88
# Se mejoró el loss de 0.3448105454444885 a 0.3371959626674652
# 51:  loss: 0.449547, accuracy: 0.792941, val loss: 0.371768, val accuracy: 0.840000 -- epoch time: 8.83
# 52:  loss: 0.442433, accuracy: 0.792941, val loss: 0.406748, val accuracy: 0.823333 -- epoch time: 8.94
# 53:  loss: 0.428554, accuracy: 0.798824, val loss: 0.450818, val accuracy: 0.790000 -- epoch time: 8.95
# 54:  loss: 0.428492, accuracy: 0.799412, val loss: 0.432012, val accuracy: 0.800000 -- epoch time: 8.86
# 55:  loss: 0.425960, accuracy: 0.813529, val loss: 0.352083, val accuracy: 0.836667 -- epoch time: 8.70
# 56:  loss: 0.420912, accuracy: 0.805294, val loss: 0.342491, val accuracy: 0.870000 -- epoch time: 8.97
# 57:  loss: 0.415282, accuracy: 0.807059, val loss: 0.357967, val accuracy: 0.833333 -- epoch time: 8.89
# 58:  loss: 0.431648, accuracy: 0.787647, val loss: 0.356644, val accuracy: 0.840000 -- epoch time: 8.77
# 59:  loss: 0.421281, accuracy: 0.805294, val loss: 0.362554, val accuracy: 0.826667 -- epoch time: 8.87
# 60:  loss: 0.411484, accuracy: 0.813529, val loss: 0.343959, val accuracy: 0.840000 -- epoch time: 8.86
# 61:  loss: 0.393165, accuracy: 0.831176, val loss: 0.399839, val accuracy: 0.816667 -- epoch time: 8.89
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 553.20

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %%
start = time.time()
reset_seed()
modelo_base_bnorm_dropout_dataaug_1e3, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNormDropout(), train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-3, epocas=100, val_split=0.15, early_stopping_acc_training = 0.95, early_stopping_loss_val_patience=10, transformaciones=DATA_AUG_TRANSFORMS, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.729817, accuracy: 0.555882, val loss: 0.647243, val accuracy: 0.636667 -- epoch time: 9.17
# Se mejoró el loss de inf a 0.6472427845001221
# 1:  loss: 0.671276, accuracy: 0.594118, val loss: 0.664422, val accuracy: 0.620000 -- epoch time: 9.03
# 2:  loss: 0.662105, accuracy: 0.621765, val loss: 0.626806, val accuracy: 0.623333 -- epoch time: 9.08
# Se mejoró el loss de 0.6472427845001221 a 0.62680584192276
# 3:  loss: 0.647435, accuracy: 0.615294, val loss: 0.605999, val accuracy: 0.646667 -- epoch time: 9.01
# Se mejoró el loss de 0.62680584192276 a 0.6059991121292114
# 4:  loss: 0.644729, accuracy: 0.632941, val loss: 0.574951, val accuracy: 0.666667 -- epoch time: 9.06
# Se mejoró el loss de 0.6059991121292114 a 0.5749506950378418
# 5:  loss: 0.634461, accuracy: 0.654118, val loss: 0.554368, val accuracy: 0.703333 -- epoch time: 9.13
# Se mejoró el loss de 0.5749506950378418 a 0.5543678998947144
# 6:  loss: 0.635177, accuracy: 0.637647, val loss: 0.660182, val accuracy: 0.656667 -- epoch time: 9.09
# 7:  loss: 0.628331, accuracy: 0.650588, val loss: 0.575890, val accuracy: 0.693333 -- epoch time: 10.12
# 8:  loss: 0.615070, accuracy: 0.667647, val loss: 0.557983, val accuracy: 0.693333 -- epoch time: 9.14
# 9:  loss: 0.600513, accuracy: 0.692941, val loss: 0.555684, val accuracy: 0.713333 -- epoch time: 9.03
# 10:  loss: 0.607669, accuracy: 0.677647, val loss: 0.506558, val accuracy: 0.770000 -- epoch time: 9.17
# Se mejoró el loss de 0.5543678998947144 a 0.5065575242042542
# 11:  loss: 0.589648, accuracy: 0.701765, val loss: 0.713593, val accuracy: 0.606667 -- epoch time: 9.10
# 12:  loss: 0.588936, accuracy: 0.691176, val loss: 0.513335, val accuracy: 0.716667 -- epoch time: 9.11
# 13:  loss: 0.598657, accuracy: 0.689412, val loss: 0.525186, val accuracy: 0.726667 -- epoch time: 9.02
# 14:  loss: 0.587178, accuracy: 0.700588, val loss: 0.485458, val accuracy: 0.760000 -- epoch time: 9.07
# Se mejoró el loss de 0.5065575242042542 a 0.48545756936073303
# 15:  loss: 0.571582, accuracy: 0.705882, val loss: 0.534660, val accuracy: 0.723333 -- epoch time: 8.96
# 16:  loss: 0.565050, accuracy: 0.704706, val loss: 0.594362, val accuracy: 0.710000 -- epoch time: 10.07
# 17:  loss: 0.571102, accuracy: 0.697647, val loss: 0.487585, val accuracy: 0.760000 -- epoch time: 8.96
# 18:  loss: 0.545361, accuracy: 0.738235, val loss: 0.492282, val accuracy: 0.746667 -- epoch time: 8.96
# 19:  loss: 0.556219, accuracy: 0.714118, val loss: 0.450964, val accuracy: 0.783333 -- epoch time: 8.97
# Se mejoró el loss de 0.48545756936073303 a 0.45096448063850403
# 20:  loss: 0.533196, accuracy: 0.739412, val loss: 0.470981, val accuracy: 0.790000 -- epoch time: 8.98
# 21:  loss: 0.546531, accuracy: 0.724706, val loss: 0.495602, val accuracy: 0.773333 -- epoch time: 9.02
# 22:  loss: 0.516147, accuracy: 0.747647, val loss: 0.460955, val accuracy: 0.773333 -- epoch time: 8.96
# 23:  loss: 0.536573, accuracy: 0.728235, val loss: 0.544649, val accuracy: 0.726667 -- epoch time: 8.92
# 24:  loss: 0.546410, accuracy: 0.732353, val loss: 0.569550, val accuracy: 0.683333 -- epoch time: 8.90
# 25:  loss: 0.532571, accuracy: 0.738824, val loss: 0.439459, val accuracy: 0.773333 -- epoch time: 8.86
# Se mejoró el loss de 0.45096448063850403 a 0.4394586384296417
# 26:  loss: 0.500010, accuracy: 0.758824, val loss: 0.493330, val accuracy: 0.773333 -- epoch time: 8.98
# 27:  loss: 0.518587, accuracy: 0.751176, val loss: 0.432784, val accuracy: 0.806667 -- epoch time: 8.89
# Se mejoró el loss de 0.4394586384296417 a 0.43278422951698303
# 28:  loss: 0.517188, accuracy: 0.741176, val loss: 0.462304, val accuracy: 0.766667 -- epoch time: 8.96
# 29:  loss: 0.497771, accuracy: 0.760588, val loss: 0.452824, val accuracy: 0.800000 -- epoch time: 8.92
# 30:  loss: 0.518336, accuracy: 0.744706, val loss: 0.465834, val accuracy: 0.766667 -- epoch time: 8.89
# 31:  loss: 0.515024, accuracy: 0.754706, val loss: 0.542724, val accuracy: 0.716667 -- epoch time: 8.84
# 32:  loss: 0.500082, accuracy: 0.740588, val loss: 0.472957, val accuracy: 0.763333 -- epoch time: 9.03
# 33:  loss: 0.502315, accuracy: 0.757059, val loss: 0.397955, val accuracy: 0.813333 -- epoch time: 10.05
# Se mejoró el loss de 0.43278422951698303 a 0.3979546129703522
# 34:  loss: 0.485820, accuracy: 0.765294, val loss: 0.612790, val accuracy: 0.723333 -- epoch time: 8.99
# 35:  loss: 0.488834, accuracy: 0.767647, val loss: 0.488758, val accuracy: 0.773333 -- epoch time: 11.36
# 36:  loss: 0.481030, accuracy: 0.771765, val loss: 0.413716, val accuracy: 0.800000 -- epoch time: 8.91
# 37:  loss: 0.469569, accuracy: 0.781765, val loss: 0.391718, val accuracy: 0.843333 -- epoch time: 10.93
# Se mejoró el loss de 0.3979546129703522 a 0.39171773195266724
# 38:  loss: 0.467245, accuracy: 0.780588, val loss: 0.488343, val accuracy: 0.816667 -- epoch time: 9.10
# 39:  loss: 0.478239, accuracy: 0.773529, val loss: 0.400780, val accuracy: 0.830000 -- epoch time: 8.91
# 40:  loss: 0.455321, accuracy: 0.786471, val loss: 0.371996, val accuracy: 0.820000 -- epoch time: 8.93
# Se mejoró el loss de 0.39171773195266724 a 0.37199556827545166
# 41:  loss: 0.481638, accuracy: 0.769412, val loss: 0.387576, val accuracy: 0.826667 -- epoch time: 9.00
# 42:  loss: 0.441370, accuracy: 0.785294, val loss: 0.415393, val accuracy: 0.803333 -- epoch time: 9.02
# 43:  loss: 0.461521, accuracy: 0.786471, val loss: 0.377442, val accuracy: 0.823333 -- epoch time: 9.07
# 44:  loss: 0.467935, accuracy: 0.770000, val loss: 0.379735, val accuracy: 0.836667 -- epoch time: 9.13
# 45:  loss: 0.457369, accuracy: 0.794118, val loss: 0.382528, val accuracy: 0.806667 -- epoch time: 9.04
# 46:  loss: 0.484573, accuracy: 0.755294, val loss: 0.399666, val accuracy: 0.816667 -- epoch time: 9.04
# 47:  loss: 0.423948, accuracy: 0.810588, val loss: 0.363510, val accuracy: 0.843333 -- epoch time: 9.33
# Se mejoró el loss de 0.37199556827545166 a 0.36350977420806885
# 48:  loss: 0.453208, accuracy: 0.793529, val loss: 0.367016, val accuracy: 0.833333 -- epoch time: 10.69
# 49:  loss: 0.442875, accuracy: 0.797647, val loss: 0.325905, val accuracy: 0.880000 -- epoch time: 10.12
# Se mejoró el loss de 0.36350977420806885 a 0.3259051740169525
# 50:  loss: 0.452787, accuracy: 0.787059, val loss: 0.386772, val accuracy: 0.810000 -- epoch time: 9.00
# 51:  loss: 0.436525, accuracy: 0.797059, val loss: 0.325055, val accuracy: 0.856667 -- epoch time: 9.10
# Se mejoró el loss de 0.3259051740169525 a 0.32505500316619873
# 52:  loss: 0.440248, accuracy: 0.789412, val loss: 0.452481, val accuracy: 0.796667 -- epoch time: 9.07
# 53:  loss: 0.442582, accuracy: 0.789412, val loss: 0.379812, val accuracy: 0.840000 -- epoch time: 9.07
# 54:  loss: 0.436538, accuracy: 0.796471, val loss: 0.381143, val accuracy: 0.813333 -- epoch time: 9.01
# 55:  loss: 0.443352, accuracy: 0.782353, val loss: 0.377408, val accuracy: 0.823333 -- epoch time: 9.00
# 56:  loss: 0.410311, accuracy: 0.816471, val loss: 0.363824, val accuracy: 0.843333 -- epoch time: 8.92
# 57:  loss: 0.413779, accuracy: 0.805294, val loss: 0.337068, val accuracy: 0.846667 -- epoch time: 8.96
# 58:  loss: 0.429842, accuracy: 0.791176, val loss: 0.322756, val accuracy: 0.863333 -- epoch time: 9.33
# Se mejoró el loss de 0.32505500316619873 a 0.3227561116218567
# 59:  loss: 0.426048, accuracy: 0.803529, val loss: 0.352300, val accuracy: 0.830000 -- epoch time: 8.99
# 60:  loss: 0.411543, accuracy: 0.807059, val loss: 0.294051, val accuracy: 0.870000 -- epoch time: 9.01
# Se mejoró el loss de 0.3227561116218567 a 0.2940508723258972
# 61:  loss: 0.400745, accuracy: 0.829412, val loss: 0.402843, val accuracy: 0.820000 -- epoch time: 8.96
# 62:  loss: 0.415276, accuracy: 0.818235, val loss: 0.342678, val accuracy: 0.853333 -- epoch time: 8.95
# 63:  loss: 0.411424, accuracy: 0.826471, val loss: 0.372487, val accuracy: 0.833333 -- epoch time: 8.96
# 64:  loss: 0.389770, accuracy: 0.820588, val loss: 0.384924, val accuracy: 0.833333 -- epoch time: 9.00
# 65:  loss: 0.406670, accuracy: 0.815294, val loss: 0.327586, val accuracy: 0.866667 -- epoch time: 9.75
# 66:  loss: 0.374822, accuracy: 0.832353, val loss: 0.437460, val accuracy: 0.783333 -- epoch time: 8.99
# 67:  loss: 0.419967, accuracy: 0.800588, val loss: 0.324096, val accuracy: 0.860000 -- epoch time: 8.95
# 68:  loss: 0.391134, accuracy: 0.827059, val loss: 0.516143, val accuracy: 0.766667 -- epoch time: 8.99
# 69:  loss: 0.378846, accuracy: 0.836471, val loss: 0.607507, val accuracy: 0.733333 -- epoch time: 9.01
# 70:  loss: 0.398984, accuracy: 0.810588, val loss: 0.542210, val accuracy: 0.783333 -- epoch time: 12.68
# 71:  loss: 0.394829, accuracy: 0.828824, val loss: 0.308107, val accuracy: 0.876667 -- epoch time: 8.98
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 664.57

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %% [markdown]
# Vemos que con un LR de 0.001, después de 61 épocas, comenzamos a overfittear, por lo que se desata el eary stopping.

# %% [markdown]
# **Base**
#
# **0.00010**(18):  loss: 0.4271/0.4590/0.5503, accuracy: 78.88%/77.33%/73.60%
#
# **Dropout**
#
# **0.00010**(23):  loss: 0.4416/0.4551/0.5274, accuracy: 78.59%/78.67%/72.50%  (paro explícito)
#
# **BatchNorm**
#
# **0.00001**(08):  loss: 0.2852/0.4706,    accuracy: 94.06%/79.33%
#
# **Dropout+BatchNorm**
#
# **0.00010**(04):  loss: 0.4646/0.4795/0.5217,    accuracy: 77.82%/78.67%/74.00% (paro explícito)
#
# **Dropout+BatchNorm+DataAugm**
#
# **0.00001**(54):  loss: 0.5260/0.4732,    accuracy: 69.71%/78.00% (early stopping)
#
# **0.00005**(26):  loss: 0.5318/0.4488,    accuracy: 72.76%/76.33% (early stopping)
#
# **0.00010**(38):  loss: 0.4687/0.3900,    accuracy: 78.94%/82.67% (early stopping)
#
# **0.00050**(51):  loss: 0.4480/0.3372,    accuracy: 80.00%/84.67% (early stopping)
#
# **0.00100**(61):  loss: 0.4115/0.2940,    accuracy: 80.71%/87.00% (early stopping)

# %% [markdown]
# Es claro que con data augmentation estamos llegando al mejor modelo hasta ahora, logrando reducir el los de validación de 0.47 a 0.29. Vamos a evaluar este modelo con el test set.

# %%
modelo_base_bnorm_dropout_dataaug = modelo_base_bnorm_dropout_dataaug_1e3

# %%
test_loss, test_acc = eval_model(modelo_base_bnorm_dropout_dataaug, test_data_loader_small)
print(f"El loss de test es {test_loss}, y el accuracy de test es de {test_acc:.3f}. ")
torch.save(modelo_base_bnorm_dropout_dataaug, "cats_and_dogs_small_dropout_batchnorm_dataaug.pth")
# Out:
# El loss de test es 0.3476037859916687, y el accuracy de test es de 0.847.

# %% [markdown]
# Vemos que el loss del test set se bajó de 0.5217 a 0.3476, con un accuracy sobre el test set pasando de 74% a 84.7%. **Es notable la mejora que proporciona el data augmentation cuando se dispone de un dataset de imágenes reducido.**

# %% [markdown]
# ## Parte 7 - Dataset completo - modelo con Dropout y batch normalization

# %% [markdown]
# Vamos a entrenar el modelo con dropout y batch norm sobre el dataset completo.
# Vamos a poder ver la importancia de tener un dataset de entrenamiento suficientemente grande.
# Cada época va a trabajar sobre el dataset extendido de 22500 imágenes.
# Vamos a aumentar el accuracy máximo sobre el training set, ya que vamos a encontrar que si bien éste puede llegar a muy altos niveles, el loss sobre el validation set seguirá mejorando continuamente.

# %%
train_data_completo = torchvision.datasets.ImageFolder(root=TRAIN_DIR, transform=TRANSFORM_IMG)
test_data_completo = torchvision.datasets.ImageFolder(root=TEST_DIR, transform=TRANSFORM_IMG)

# %%
#import warnings
#warnings.filterwarnings("ignore", "(Possibly )?corrupt EXIF data", UserWarning)

start = time.time()
reset_seed()
modelo_base_bnorm_dropout_completo_1e4, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassifierBase_BNormDropout(), train_data_completo,
    train_batch_size=BATCH_SIZE, learning_rate=1e-4, epocas=100, val_split=0.15, early_stopping_acc_training = 0.98, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 19122, num_validation_instances 3375
# 0:  loss: 0.543258, accuracy: 0.723878, val loss: 0.444391, val accuracy: 0.783704 -- epoch time: 107.36
# Se mejoró el loss de inf a 0.4443914950247164
# 1:  loss: 0.430424, accuracy: 0.801276, val loss: 0.392810, val accuracy: 0.817778 -- epoch time: 97.02
# Se mejoró el loss de 0.4443914950247164 a 0.39281041903849
# 2:  loss: 0.387731, accuracy: 0.824809, val loss: 0.342812, val accuracy: 0.853926 -- epoch time: 100.06
# Se mejoró el loss de 0.39281041903849 a 0.3428121042781406
# 3:  loss: 0.358195, accuracy: 0.840550, val loss: 0.354687, val accuracy: 0.840296 -- epoch time: 99.16
# 4:  loss: 0.326839, accuracy: 0.857599, val loss: 0.421527, val accuracy: 0.812444 -- epoch time: 98.15
# 5:  loss: 0.297498, accuracy: 0.873287, val loss: 0.424328, val accuracy: 0.809778 -- epoch time: 98.93
# 6:  loss: 0.280966, accuracy: 0.881759, val loss: 0.266101, val accuracy: 0.887111 -- epoch time: 98.82
# Se mejoró el loss de 0.3428121042781406 a 0.26610059315628476
# 7:  loss: 0.262940, accuracy: 0.888035, val loss: 0.255948, val accuracy: 0.891259 -- epoch time: 97.23
# Se mejoró el loss de 0.26610059315628476 a 0.25594777765980475
# 8:  loss: 0.254018, accuracy: 0.894990, val loss: 0.272342, val accuracy: 0.882963 -- epoch time: 97.39
# 9:  loss: 0.229024, accuracy: 0.905658, val loss: 0.336410, val accuracy: 0.857778 -- epoch time: 95.37
# 10:  loss: 0.222523, accuracy: 0.909633, val loss: 0.261528, val accuracy: 0.889185 -- epoch time: 95.87
# 11:  loss: 0.207370, accuracy: 0.915229, val loss: 0.408169, val accuracy: 0.842667 -- epoch time: 96.14
# 12:  loss: 0.193692, accuracy: 0.918889, val loss: 0.227075, val accuracy: 0.905778 -- epoch time: 94.52
# Se mejoró el loss de 0.25594777765980475 a 0.22707509395369777
# 13:  loss: 0.178061, accuracy: 0.928198, val loss: 0.264611, val accuracy: 0.889185 -- epoch time: 96.39
# 14:  loss: 0.170779, accuracy: 0.933794, val loss: 0.381738, val accuracy: 0.852444 -- epoch time: 97.28
# 15:  loss: 0.172110, accuracy: 0.930185, val loss: 0.214870, val accuracy: 0.915259 -- epoch time: 95.80
# Se mejoró el loss de 0.22707509395369777 a 0.21486992996268803
# 16:  loss: 0.161027, accuracy: 0.936879, val loss: 0.418019, val accuracy: 0.825185 -- epoch time: 96.93
# 17:  loss: 0.153093, accuracy: 0.936879, val loss: 0.218933, val accuracy: 0.909630 -- epoch time: 97.26
# 18:  loss: 0.142671, accuracy: 0.942579, val loss: 0.233657, val accuracy: 0.902815 -- epoch time: 95.19
# 19:  loss: 0.139406, accuracy: 0.945455, val loss: 0.217862, val accuracy: 0.914370 -- epoch time: 97.00
# 20:  loss: 0.137464, accuracy: 0.947443, val loss: 0.268029, val accuracy: 0.891556 -- epoch time: 97.07
# 21:  loss: 0.126894, accuracy: 0.950685, val loss: 0.234104, val accuracy: 0.905778 -- epoch time: 94.12
# 22:  loss: 0.121706, accuracy: 0.951470, val loss: 0.262505, val accuracy: 0.900741 -- epoch time: 96.06
# 23:  loss: 0.123773, accuracy: 0.950947, val loss: 0.419003, val accuracy: 0.854222 -- epoch time: 95.14
# 24:  loss: 0.113704, accuracy: 0.955339, val loss: 0.237680, val accuracy: 0.909037 -- epoch time: 94.28
# 25:  loss: 0.112021, accuracy: 0.956804, val loss: 0.223613, val accuracy: 0.915852 -- epoch time: 95.86
# 26:  loss: 0.109699, accuracy: 0.958111, val loss: 0.234635, val accuracy: 0.902815 -- epoch time: 95.66
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 2624.47

# %% [markdown]
# El dataset completo tiene 22500, mas de 10 veces el dataset reducido (2000) utilizado para entrenar los modelos anteriores. Consecuentemente, cada época se demora casi 100 segundos (9 anteriormente).
# Vemos rápidamente que se alcanzan niveles de loss de validación mucho mejores que los previamente alcanzados, sin llegar a presentarse overfitting importante.

# %%
plot_losses_and_accuracies(train_losses[:22], train_accuracies[:22], val_losses[:22], val_accuracies[:22])

# %%
modelo_base_bnorm_dropout_completo = modelo_base_bnorm_dropout_completo_1e4

# %%
test_loss, test_acc = eval_model(modelo_base_bnorm_dropout_completo, test_data_loader_small)
print(f"El loss de test es {test_loss}, y el accuracy de test es de {test_acc:.3f}. ")
torch.save(modelo_base_bnorm_dropout_completo, "modelo_base_bnorm_dropout_completo.pth")
# Out:
# El loss de test es 0.08614252804219723, y el accuracy de test es de 0.973.

# %% [markdown]
# En efecto, disponer de más datos de aprendizaje **reales** permite mejorar el entrenamiento del modelo.
# Por un lado, vemos que la evolución del loss del set de train y del set de validación van de la mano (hasta la época 15 (16)).
# Por otro lado, el valor del loss en el set de validación llega a un valor de alrededor 0.21 (inferior al 0.391 anterior), con un accuracy de alrededor 90% (muy superior al 85.7% del mejor modelo anterior (data augmentation)), con un loss y accuracy de 0.1 y 96.2% sobre el test set!

# %% [markdown]
# ## Parte 8. Dataset reducido - transfer learning

# %% [markdown]
# Una de las características mas interesantes de los modelos convolucionales que trabajan con imágenes, es que se pueden reutilizar modelos pre entrenados con datasets suficientemente generales de mucho mayor tamaño, y aplicarlos a tareas diferentes, que no disponen de un gran volúmen de datos.
# La idea es reutilizar las características (los **features**) espaciales aprendidos sobre un dataset general y de gran tamaño, ya que son abstracciones suficientemente generales para poder ser útiles para otros problemas, así estos involucren otras clases diferentes a las de la tarea original.
# La portabilidad de las características a diferentes tipos de problemas es la base del **transfer learning** de modelos conexionistas, que constituye una ventaja sobre modelos de ML tradicionales, y permite aplicar el deep learning a problemas que no dispongan de datasets suficientemente grandes.

# %% [markdown]
# Hay dos maneras de reutilizar modelos pre entrenados
# - se pueden utilizar para hacer **feature extraction** sin tocar las capas convolucionales originales (lo que haremos en este punto),
# - se puede hacer **fine tuning** (lo que haremos en la siguiente parte) que toma el modelo importado como base de inicialización y remodifica algunas de sus capas convolucionales para adaptarlas a la tarea que queremos realizar (en este caso clasificación de perros y gatos)

# %% [markdown]
# El **feature extraction** consiste en utilizar las representaciones aprendidas por una red anterior como base de un nuevo modelo de clasificación.
# Del modelo original se conservarán las capas convolucionales, que luego se conectarán con nuevas capas densas fully connected.
# Los datos de la nueva tarea son entonces pasados por las capas convolucionales originales, cuya salida es luego "aplastada" en un tensor 1D que sirve como inputs de una nueva red neuronal tradicional.
#
# No se reutilizan las capas densas de los modelos originales, ya que son demasiado específicas a los problemas y clases originales con las que fueron entrenadas, sin contener información espacial de la ubicación de los conceptos aprendidos.
# No son genéricas como lo son las capas convolucionales, que sirven como mapas de conceptos genéricos que podrían servir para todo tipo de problemas de computación visual.
#
# El nivel de generalidad y reusabilidad de las representaciones extraídas por una capa convolucional específica depende de la profundidad de la misma. Las capas iniciales extraen conceptos locales mucho mas abstractos y altamente genéricos (lineas, esquinas, curvas), mientras que las capas finales extraen conceptos mas específicos (oreja de perro, nariz de gato).
# Es así como si la tarea de clasificación a la que se quiere transferir un modelo es muy diferente a la tarea original, puede ser mejor no utilizar todas las capas convolucionales, sino solo las primeras.
# En este caso, como las clases de ImageNet comprendían últiples clases de perros y gatos, es provechoso reutilizar todas las capas convolucionales.

# %% [markdown]
# El subpaquete ```torchvision.models``` contiene definiciones de modelos pre entrenados para diferentes tareas (clasificación de imágenes, segmentación semántica, detección de imágenes, segmentación de instancias, clasificación de videos, etc.).
#
# Existen varios modelos disponibles gratuitamente para el transfer learning: VGG, Inception, ResNet, Inception-ResNet, Xception. Vamos a servirnos de `torchvision.models.vgg16` una Convnet con arquitectura **VGG16** que incluye capas de batch normalization, muy utilizada por su simple arquitectura, aunque un poco pesada (tamaño, número de parámetros).
# Para una lista de los modelos disponibles directamente desde **torchvision** se encuentra aquí: https://pytorch.org/vision/stable/models.html

# %% [markdown]
# ### Pre procesamiento de datos del modelo transferido

# %% [markdown]
# La arquitectura de los modelos transferidos se pueden instanciar y especificar los pesos a considerar.
# **Torchvision** proporciona directamente un conjunto de pesos preentrenados par los modelos incluidos. Particularmente, vamos a utilizar los pesos `torchvision.models.vgg.VGG16_BN_Weights.IMAGENET1K_V1`, lo indicamos con el argumento `weights`.
# Estos pesos son el resultado del entrenamiento de una CNN **VGG16** para clasificación de imágenes en 1000 categorias, sobre un dataset llamado **ImageNet**, que incluye 1.4 millones de imágenes.
# Entre las categorías se encuentran diferentes clases de animales, por lo que se estima que la transferencia a nuestro problem de clasificación de perros y gatos funcione bien.

# %%
pesos_vgg16_bn = models.vgg.VGG16_BN_Weights.IMAGENET1K_V1

# %% [markdown]
# Antes de usar un modelo pre entrenado, es necesario tener claras las transformaciones de pre procesamiento aque hay que realizar sobre las imágenes antes de pasarlas por el modelo en sí. Estas incluyen comúnmente operaciones de cambios de tamaño, recortes, y normalizaciones, entre otros, y se encuentran disponibles a través del atributo `transforms` de los pesos.

# %%
preprocesamientos = pesos_vgg16_bn.transforms()
preprocesamientos
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %% [markdown]
# Veamos como queda una imágen pre procesada con este proceso

# %%
imagenes, labels = next(iter(test_data_loader_small))
imagenes.shape
# Out:
# torch.Size([16, 3, 150, 150])

# %%
img = imagenes[0]
plt.imshow(img.permute(1, 2, 0))
print(img.shape)
# Out:
# torch.Size([3, 150, 150])

# %%
img[0, 0:8, 0:8]
# Out:
# tensor([[0.5608, 0.5451, 0.5412, 0.5333, 0.5333, 0.5373, 0.5333, 0.5373],
#         [0.5451, 0.5412, 0.5255, 0.5333, 0.5451, 0.5490, 0.5373, 0.5412],
#         [0.5412, 0.5490, 0.5373, 0.5451, 0.5490, 0.5412, 0.5373, 0.5412],
#         [0.5490, 0.5529, 0.5569, 0.5569, 0.5451, 0.5490, 0.5451, 0.5373],
#         [0.5451, 0.5529, 0.5490, 0.5490, 0.5412, 0.5569, 0.5451, 0.5294],
#         [0.5451, 0.5490, 0.5451, 0.5490, 0.5451, 0.5451, 0.5333, 0.5216],
#         [0.5373, 0.5373, 0.5373, 0.5412, 0.5451, 0.5333, 0.5216, 0.5137],
#         [0.5333, 0.5255, 0.5216, 0.5294, 0.5255, 0.5176, 0.5137, 0.5020]])

# %%
img_transformed = preprocesamientos(img)
img_transformed[0, 0:8, 0:8]
# Out:
# tensor([[-0.1034, -0.1352, -0.1650, -0.1935, -0.1825, -0.1663, -0.1529, -0.1495],
#         [-0.0951, -0.1327, -0.1616, -0.1842, -0.1827, -0.1744, -0.1492, -0.1368],
#         [-0.0809, -0.1244, -0.1504, -0.1637, -0.1624, -0.1562, -0.1363, -0.1256],
#         [-0.0625, -0.1119, -0.1336, -0.1351, -0.1271, -0.1190, -0.1168, -0.1156],
#         [-0.0500, -0.0950, -0.1169, -0.1220, -0.1184, -0.1135, -0.1083, -0.1079],
#         [-0.0460, -0.0832, -0.1052, -0.1163, -0.1177, -0.1160, -0.1059, -0.1051],
#         [-0.0811, -0.1007, -0.1187, -0.1356, -0.1377, -0.1360, -0.1260, -0.1252],
#         [-0.1093, -0.1193, -0.1320, -0.1467, -0.1509, -0.1515, -0.1415, -0.1382]])

# %%
#torch_tensor = torch.from_numpy(img_transformed).long()
plt.imshow(img_transformed.permute(1, 2, 0))
print(img_transformed.shape)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 224, 224])

# %% [markdown]
# Leemos de nuevo el dataset reducido, aplicándole las transformaciones incluidas en el modelo, para poder extraer las features.

# %%
train_data_small_transfer = torchvision.datasets.ImageFolder(root=TRAIN_SMALL_DIR, transform=preprocesamientos)
test_data_small_transfer = torchvision.datasets.ImageFolder(root=TEST_SMALL_DIR, transform=preprocesamientos)
train_data_loader_small_transfer = torch.utils.data.DataLoader(train_data_small_transfer, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2)
test_data_loader_small_transfer = torch.utils.data.DataLoader(test_data_small_transfer, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# Cargamos el modelo transferido y analizamos su arquitectura.

# %%
modelo_vgg16_bn = models.vgg16_bn(weights=pesos_vgg16_bn).to(DEVICE)
summary(modelo_vgg16_bn, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#        BatchNorm2d-2         [-1, 64, 224, 224]             128
#               ReLU-3         [-1, 64, 224, 224]               0
#             Conv2d-4         [-1, 64, 224, 224]          36,928
#        BatchNorm2d-5         [-1, 64, 224, 224]             128
#               ReLU-6         [-1, 64, 224, 224]               0
#          MaxPool2d-7         [-1, 64, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]          73,856
#        BatchNorm2d-9        [-1, 128, 112, 112]             256
#              ReLU-10        [-1, 128, 112, 112]               0
#            Conv2d-11        [-1, 128, 112, 112]         147,584
#       BatchNorm2d-12        [-1, 128, 112, 112]             256
#              ReLU-13        [-1, 128, 112, 112]               0
#         MaxPool2d-14          [-1, 128, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         295,168
#       BatchNorm2d-16          [-1, 256, 56, 56]             512
#              ReLU-17          [-1, 256, 56, 56]               0
#            Conv2d-18          [-1, 256, 56, 56]         590,080
#       BatchNorm2d-19          [-1, 256, 56, 56]             512
#              ReLU-20          [-1, 256, 56, 56]               0
#            Conv2d-21          [-1, 256, 56, 56]         590,080
#       BatchNorm2d-22          [-1, 256, 56, 56]             512
#              ReLU-23          [-1, 256, 56, 56]               0
#         MaxPool2d-24          [-1, 256, 28, 28]               0
#            Conv2d-25          [-1, 512, 28, 28]       1,180,160
#       BatchNorm2d-26          [-1, 512, 28, 28]           1,024
#              ReLU-27          [-1, 512, 28, 28]               0
#            Conv2d-28          [-1, 512, 28, 28]       2,359,808
#       BatchNorm2d-29          [-1, 512, 28, 28]           1,024
#              ReLU-30          [-1, 512, 28, 28]               0
#            Conv2d-31          [-1, 512, 28, 28]       2,359,808
#       BatchNorm2d-32          [-1, 512, 28, 28]           1,024
#              ReLU-33          [-1, 512, 28, 28]               0
#         MaxPool2d-34          [-1, 512, 14, 14]               0
#            Conv2d-35          [-1, 512, 14, 14]       2,359,808
#       BatchNorm2d-36          [-1, 512, 14, 14]           1,024
#              ReLU-37          [-1, 512, 14, 14]               0
#            Conv2d-38          [-1, 512, 14, 14]       2,359,808
#       BatchNorm2d-39          [-1, 512, 14, 14]           1,024
#              ReLU-40          [-1, 512, 14, 14]               0
#            Conv2d-41          [-1, 512, 14, 14]       2,359,808
#       BatchNorm2d-42          [-1, 512, 14, 14]           1,024
#              ReLU-43          [-1, 512, 14, 14]               0
#         MaxPool2d-44            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-45            [-1, 512, 7, 7]               0
#            Linear-46                 [-1, 4096]     102,764,544
#              ReLU-47                 [-1, 4096]               0
#           Dropout-48                 [-1, 4096]               0
#            Linear-49                 [-1, 4096]      16,781,312
#              ReLU-50                 [-1, 4096]               0
#           Dropout-51                 [-1, 4096]               0
#            Linear-52                 [-1, 1000]       4,097,000
# ================================================================
# Total params: 138,365,992
# Trainable params: 138,365,992
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 322.14
# Params size (MB): 527.82
# Estimated Total Size (MB): 850.54
# ----------------------------------------------------------------

# %%
modelo_vgg16_bn
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Vemos que la primera capa lineal se encuentra despues de una capa intermedia de tipo `AdaptiveAvgPool2D`, esta capa se encarga de realizar un pooling con promedios, pero en vez de definir el tamaño de la ventana y el stride, se define el tamaño del feature map deseado, de tal manera que automáticamente se calculan estos dos atributos.
#
# Antes de la capa intermedia tenemos una capa de `MaxPooling2d`, que nos dará los features que reutilizaremos.
# Interesante verificar que este modelo tiene 138 millones de parámetros a entrenar. Sin embargo, como queremos realizar **feature extraction**, no nos interesan las capas densas finales del modelo (responsables de mas de 123 millones de parámetros), nos quedamos con con las anteriores (con 14.7 millones)
#
# Podemos obtener directamente los features del modelo utilizando el atributo `features` (parte del modelo secuencial). Vemos que se retorna un modelo secuencial que para en la última capa `MaxPool2d`.

# %%
summary(modelo_vgg16_bn.features, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#        BatchNorm2d-2         [-1, 64, 224, 224]             128
#               ReLU-3         [-1, 64, 224, 224]               0
#             Conv2d-4         [-1, 64, 224, 224]          36,928
#        BatchNorm2d-5         [-1, 64, 224, 224]             128
#               ReLU-6         [-1, 64, 224, 224]               0
#          MaxPool2d-7         [-1, 64, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]          73,856
#        BatchNorm2d-9        [-1, 128, 112, 112]             256
#              ReLU-10        [-1, 128, 112, 112]               0
#            Conv2d-11        [-1, 128, 112, 112]         147,584
#       BatchNorm2d-12        [-1, 128, 112, 112]             256
#              ReLU-13        [-1, 128, 112, 112]               0
#         MaxPool2d-14          [-1, 128, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         295,168
#       BatchNorm2d-16          [-1, 256, 56, 56]             512
#              ReLU-17          [-1, 256, 56, 56]               0
#            Conv2d-18          [-1, 256, 56, 56]         590,080
#       BatchNorm2d-19          [-1, 256, 56, 56]             512
#              ReLU-20          [-1, 256, 56, 56]               0
#            Conv2d-21          [-1, 256, 56, 56]         590,080
#       BatchNorm2d-22          [-1, 256, 56, 56]             512
#              ReLU-23          [-1, 256, 56, 56]               0
#         MaxPool2d-24          [-1, 256, 28, 28]               0
#            Conv2d-25          [-1, 512, 28, 28]       1,180,160
#       BatchNorm2d-26          [-1, 512, 28, 28]           1,024
#              ReLU-27          [-1, 512, 28, 28]               0
#            Conv2d-28          [-1, 512, 28, 28]       2,359,808
#       BatchNorm2d-29          [-1, 512, 28, 28]           1,024
#              ReLU-30          [-1, 512, 28, 28]               0
#            Conv2d-31          [-1, 512, 28, 28]       2,359,808
#       BatchNorm2d-32          [-1, 512, 28, 28]           1,024
#              ReLU-33          [-1, 512, 28, 28]               0
#         MaxPool2d-34          [-1, 512, 14, 14]               0
#            Conv2d-35          [-1, 512, 14, 14]       2,359,808
#       BatchNorm2d-36          [-1, 512, 14, 14]           1,024
#              ReLU-37          [-1, 512, 14, 14]               0
#            Conv2d-38          [-1, 512, 14, 14]       2,359,808
#       BatchNorm2d-39          [-1, 512, 14, 14]           1,024
#              ReLU-40          [-1, 512, 14, 14]               0
#            Conv2d-41          [-1, 512, 14, 14]       2,359,808
#       BatchNorm2d-42          [-1, 512, 14, 14]           1,024
#              ReLU-43          [-1, 512, 14, 14]               0
#         MaxPool2d-44            [-1, 512, 7, 7]               0
# ================================================================
# Total params: 14,723,136
# Trainable params: 14,723,136
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 321.75
# Params size (MB): 56.16
# Estimated Total Size (MB): 378.49
# ----------------------------------------------------------------

# %% [markdown]
# Intentemos pasar un batch por el feature extraction

# %% [markdown]
# si el modelo para transfer learning no estuviera dividido en features, en este caso escoges features {{43}} que hace referencia a la capa de maxpool2d

# %%
imagenes, labels = next(iter(test_data_loader_small_transfer))
imagenes.shape
# Out:
# torch.Size([16, 3, 224, 224])

# %%
start = time.time()
modelo_vgg16_bn.features.eval()
with torch.no_grad():
    features_extracted = modelo_vgg16_bn.features(imagenes.to(DEVICE))
end = time.time()
print(f"Tiempo de extracción de features de un batch de {BATCH_SIZE} imágenes: {(end-start):.2f} segundos")
features_extracted.shape
# Out:
# Tiempo de extracción de features de un batch de 16 imágenes: 0.21 segundos
# torch.Size([16, 512, 7, 7])

# %% [markdown]
# El tensor final tiene instancias con tensores (512, 7, 7, 512), 512 feature maps ("imágenes") de 7x7, con las características extraídas de los tensores originales, que se conectan luego con la parte densa fully connected de la red encargada de hacer la clasificación.
#
# Hay 2 maneras de proceder en este punto:
# * Procesar el dataset de la tarea de destino (perros y gatos) pasándolo por la base convolucional, para luego grabar en disco el tensor final o conservar en memoria, que luego se puede cargar en una segunda etapa como los inputs de entrenamiento de una nueva red con la base fully connected. Esta solución es rápida y ahorradora en tiempo de ejecución (vemos que un solo batch se demora mas de 10 segundos en CPU, menos de 1 segundo en GPU), pues solo se utilizará la red convolucional una sola vez por cada imágen, la parte más consumidora de procesamiento, sin tener que repetirla por cada paso de entrenamiento. Pero esta técnica impide utilizar un eventual **data augmentation**, pues las imágenes de origen son siempre las mismas.
# * Extender el submodelo convolucional (llamado **features**) de base importado, agregándole la subred fully connected, que serían las únicas capas que serían entrenadas. Esto permite el **data augmentation**, pero es mucho más costosa que la anterior.
#
# Vamos a escoger la primera opción por simplicidad, y luego podríamos evaluar la segunda si necesario. Vamos a conservar en memoria los features extraidos.

# %%
def extract_features (dataset, shuffle=False):
    data_loader = torch.utils.data.DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=shuffle, num_workers=2)

    # se crea un tensor vacío, que luego llenaremos
    features_extracted = torch.empty(size=(len(dataset.imgs), 512, 7, 7))
    labels_extracted = torch.empty(size=(len(dataset.imgs),))
    modelo_vgg16_bn.features.eval()
    with torch.no_grad():
        for i, (imagenes, labels) in enumerate(data_loader):
            # print(f"{i}: desde {i*BATCH_SIZE}, hasta {i*BATCH_SIZE + BATCH_SIZE}")
            # print(features_extracted[i,0])
            features = modelo_vgg16_bn.features(imagenes.to(DEVICE))
            features_extracted[i*BATCH_SIZE: i*BATCH_SIZE + BATCH_SIZE] = features
            labels_extracted[i*BATCH_SIZE: i*BATCH_SIZE + BATCH_SIZE] = labels.to(DEVICE)
            # print(features_extracted[i,0])
    return features_extracted, labels_extracted

# %% [markdown]
# El siguiente código en CPU toma bastante tiempo

# %%
start = time.time()
train_features, train_labels = extract_features(train_data_small_transfer, shuffle=True)
end = time.time()
print(f"Tiempo de extracción de features de imágenes de training: {(end-start):.2f} segundos")

start = time.time()
test_features, test_labels = extract_features(test_data_small_transfer, shuffle=False)
end = time.time()
print(f"Tiempo de extracción de features de imágenes de test: {(end-start):.2f} segundos")
# Out:
# Tiempo de extracción de features de imágenes de training: 21.84 segundos
# Tiempo de extracción de features de imágenes de test: 9.47 segundos

# %% [markdown]
# Ya tenemos en memoria los tensores con los features y labels extraidos

# %%
print(f"train features: {train_features.shape}, labels: {train_labels.shape}")
print(f"train features: {test_features.shape}, labels: {test_labels.shape}")
# Out:
# train features: torch.Size([2000, 512, 7, 7]), labels: torch.Size([2000])
# train features: torch.Size([1000, 512, 7, 7]), labels: torch.Size([1000])

# %% [markdown]
# Creamos ahora un clasificador con red neuronal sencilla únicamente con capas densas.

# %%
class BinaryImageClassfierBase_FeatureExtraction(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear1 = nn.Linear(in_features=512*7*7, out_features=512)
        self.linear2 = nn.Linear(in_features=512, out_features=1)

    def forward(self, features):
        x = self.flatten(features)
        x = self.linear1(x)
        x = F.relu(x)
        logits = self.linear2(x)
        probas = torch.sigmoid(logits)

        #return logits
        return probas

# %%
modelo_feat_extract = BinaryImageClassfierBase_FeatureExtraction()
modelo_feat_extract.to(DEVICE)
# Out:
# BinaryImageClassfierBase_FeatureExtraction(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear1): Linear(in_features=25088, out_features=512, bias=True)
#   (linear2): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
summary(modelo_feat_extract, (512, 7, 7))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                [-1, 25088]               0
#             Linear-2                  [-1, 512]      12,845,568
#             Linear-3                    [-1, 1]             513
# ================================================================
# Total params: 12,846,081
# Trainable params: 12,846,081
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.10
# Forward/backward pass size (MB): 0.20
# Params size (MB): 49.00
# Estimated Total Size (MB): 49.29
# ----------------------------------------------------------------

# %% [markdown]
# Tenemos un modelo con una sola capa escondida con 12.8 millones de parámetros, que vamos a entrenar a partir de un dataloader creado sobre los tensores obtenidos a partir del feature extraction.

# %%
train_data_small_feature_extraction = torch.utils.data.TensorDataset(train_features, train_labels)
test_data_small_feature_extraction = torch.utils.data.TensorDataset(test_features, test_labels)
test_data_loader_small_feature_extraction = torch.utils.data.DataLoader(test_data_small_feature_extraction, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %%
start = time.time()
reset_seed()
modelo_feat_extract_1e5, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    BinaryImageClassfierBase_FeatureExtraction(), train_data_small_feature_extraction,
    train_batch_size=BATCH_SIZE, learning_rate=1e-5, epocas=30, val_split=0.15, early_stopping_acc_training = -1, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.290579, accuracy: 0.954706, val loss: 0.112847, val accuracy: 0.986667 -- epoch time: 1.50
# Se mejoró el loss de inf a 0.11284682154655457
# 1:  loss: 0.074410, accuracy: 0.991176, val loss: 0.071636, val accuracy: 0.990000 -- epoch time: 1.49
# Se mejoró el loss de 0.11284682154655457 a 0.07163649052381516
# 2:  loss: 0.043645, accuracy: 0.994118, val loss: 0.058795, val accuracy: 0.983333 -- epoch time: 1.49
# Se mejoró el loss de 0.07163649052381516 a 0.058795493096113205
# 3:  loss: 0.029297, accuracy: 0.997059, val loss: 0.052012, val accuracy: 0.983333 -- epoch time: 1.47
# Se mejoró el loss de 0.058795493096113205 a 0.05201185867190361
# 4:  loss: 0.020810, accuracy: 0.997647, val loss: 0.049507, val accuracy: 0.990000 -- epoch time: 1.47
# Se mejoró el loss de 0.05201185867190361 a 0.049506787210702896
# 5:  loss: 0.015722, accuracy: 0.998824, val loss: 0.046072, val accuracy: 0.983333 -- epoch time: 1.48
# Se mejoró el loss de 0.049506787210702896 a 0.046072009950876236
# 6:  loss: 0.012500, accuracy: 0.999412, val loss: 0.044670, val accuracy: 0.986667 -- epoch time: 1.48
# Se mejoró el loss de 0.046072009950876236 a 0.044670406728982925
# 7:  loss: 0.009993, accuracy: 0.998824, val loss: 0.043965, val accuracy: 0.990000 -- epoch time: 1.49
# Se mejoró el loss de 0.044670406728982925 a 0.04396538808941841
# 8:  loss: 0.008379, accuracy: 0.998824, val loss: 0.042671, val accuracy: 0.983333 -- epoch time: 1.48
# Se mejoró el loss de 0.04396538808941841 a 0.04267058148980141
# 9:  loss: 0.007064, accuracy: 0.999412, val loss: 0.041984, val accuracy: 0.986667 -- epoch time: 1.48
# Se mejoró el loss de 0.04267058148980141 a 0.041984472423791885
# 10:  loss: 0.006173, accuracy: 0.999412, val loss: 0.041702, val accuracy: 0.990000 -- epoch time: 1.50
# Se mejoró el loss de 0.041984472423791885 a 0.04170222207903862
# 11:  loss: 0.005351, accuracy: 0.998824, val loss: 0.041535, val accuracy: 0.990000 -- epoch time: 1.48
# Se mejoró el loss de 0.04170222207903862 a 0.04153518006205559
# 12:  loss: 0.004820, accuracy: 0.999412, val loss: 0.041155, val accuracy: 0.986667 -- epoch time: 1.48
# Se mejoró el loss de 0.04153518006205559 a 0.041155051440000534
# 13:  loss: 0.004325, accuracy: 0.999412, val loss: 0.041220, val accuracy: 0.990000 -- epoch time: 1.48
# 14:  loss: 0.003953, accuracy: 0.998824, val loss: 0.040717, val accuracy: 0.986667 -- epoch time: 1.49
# Se mejoró el loss de 0.041155051440000534 a 0.04071719944477081
# 15:  loss: 0.003583, accuracy: 0.999412, val loss: 0.040410, val accuracy: 0.986667 -- epoch time: 1.50
# Se mejoró el loss de 0.04071719944477081 a 0.04041022062301636
# 16:  loss: 0.003318, accuracy: 0.999412, val loss: 0.041622, val accuracy: 0.990000 -- epoch time: 1.48
# 17:  loss: 0.002912, accuracy: 0.998824, val loss: 0.040486, val accuracy: 0.986667 -- epoch time: 1.49
# 18:  loss: 0.002883, accuracy: 0.999412, val loss: 0.040534, val accuracy: 0.986667 -- epoch time: 1.47
# 19:  loss: 0.002765, accuracy: 0.998824, val loss: 0.040563, val accuracy: 0.986667 -- epoch time: 1.46
# 20:  loss: 0.002345, accuracy: 0.999412, val loss: 0.040591, val accuracy: 0.990000 -- epoch time: 1.47
# 21:  loss: 0.002480, accuracy: 0.998824, val loss: 0.041673, val accuracy: 0.990000 -- epoch time: 1.47
# 22:  loss: 0.002380, accuracy: 0.999412, val loss: 0.040711, val accuracy: 0.983333 -- epoch time: 1.47
# 23:  loss: 0.002272, accuracy: 0.999412, val loss: 0.042231, val accuracy: 0.990000 -- epoch time: 1.48
# 24:  loss: 0.002231, accuracy: 0.998824, val loss: 0.040791, val accuracy: 0.990000 -- epoch time: 1.47
# 25:  loss: 0.002202, accuracy: 0.998824, val loss: 0.041340, val accuracy: 0.990000 -- epoch time: 1.48
# 26:  loss: 0.002182, accuracy: 0.998824, val loss: 0.041724, val accuracy: 0.990000 -- epoch time: 1.47
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 42.51

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %%
test_loss, test_acc = eval_model(modelo_feat_extract_1e5, test_data_loader_small_feature_extraction)
print(f"El loss de test es {test_loss}, y el accuracy de test es de {test_acc:.3f}. ")
torch.save(modelo_feat_extract_1e5, "cats_and_dogs_small_bnorm_tl_feat_extract.pth")
# Out:
# El loss de test es 0.022164601833210326, y el accuracy de test es de 0.994.

# %% [markdown]
# **Reducido - Base**
#
# **0.00010**(18):  loss: 0.4271/0.4590/0.5503, accuracy: 78.88%/77.33%/73.60%
#
# **Dropout**
#
# **0.00010**(23):  loss: 0.4416/0.4551/0.5274, accuracy: 78.59%/78.67%/72.50%  (paro explícito)
#
# **BatchNorm**
#
# **0.00001**(08):  loss: 0.2852/0.4706,    accuracy: 94.06%/79.33%
#
# **Dropout+BatchNorm**
#
# **0.00010**(04):  loss: 0.4646/0.4795/0.5217,    accuracy: 77.82%/78.67%/74.00% (paro explícito)
#
# **Dropout+BatchNorm+DataAugm**
#
# **0.00100**(61):  loss: 0.4115/0.2940/0.3476,    accuracy: 80.71%/87.00%/84.70% (early stopping)
#
# **TLearning - Feature Extraction**
#
# **0.00001**(16):  loss: 0.0036/0.0404/0.0222,    accuracy: 99.94%/98.67%/99.40% (early stopping)
#
# **Completo - Base**
#
# **0.00001**(16):  loss: 0.1721/0.2149/0.0861,    accuracy: 93.02%/91.53%/97.30% (early stopping)

# %% [markdown]
# Vemos que el modelo con transfer learning con feature extraction alcanza un nivel de loss muy inferior y de accuracy muy superior a los previamentes alcanzados, incluido el modelo entrenado sobre todas las imágenes disponibles.

# %% [markdown]
# ### Fine Tuning

# %% [markdown]
# Normalmente con las métricas logradas con el modelo que utiliza transfer learning a partir de feature extraction sobre el dataset de perros y gatos, ya no sería necesario continuar buscando.
# Sin embargo, por completitud, vamos a ilustrar el proceso de aplicar transfer learning con fine tuning a un modelo de clasificación.
#
# La base del modelo de fine tuning va a ser el modelo preentrenado.
# Lo primero que vamos a hacer es "congelar" el entrenamiento de todos los parámetros del submódulo `features`, seteando su atributo `requires_grad` a `False`, salvo por el último bloque convolucional. Este último bloque comienza en la capa con índice 40.

# %%
for i, module in enumerate(modelo_vgg16_bn.features.children()):
    if i<=39:
        for param in module.parameters():
            param.requires_grad = False
    else:
        print(f"{i}: Capa {module}")
        for param in module.parameters():
            print(f"  Descongelar parámetro {param.shape}")
# Out:
# 40: Capa Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   Descongelar parámetro torch.Size([512, 512, 3, 3])
#   Descongelar parámetro torch.Size([512])
# 41: Capa BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   Descongelar parámetro torch.Size([512])
#   Descongelar parámetro torch.Size([512])
# 42: Capa ReLU(inplace=True)
# 43: Capa MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)

# %% [markdown]
# Como segundo paso, necesitamos adaptar la cabeza de clasificación (submodulo `classifier`) a la nueva tarea. Creamos un submódulo mucho más simple (una sola capa escondida densa con 512 neuronas), similar a la previamente utilizada en el modelo de clasificación de feature extraction. No necesitamos aplanar los features, pues el modelo transferido se encarga de eso.
#
# La salida de las redes previas en el método `forward` aplican una función de activación sigmoide para retornar probabilidades, por lo que aplicamos el loss `nn.BCELoss`.
# Como estamos modificando la cabeza de clasificación tenemos dos opciones, que son completamente equivalentes:
# - Seguir utilizando la función de pérdida `nn.BCELoss` que hemos usado hasta ahora, pero agregando como salida del modelo un módulo `nn.Sigmoid` que convierta los logits a probabilidades.
# - No agregar un módulo final a la salida de la cabeza de clasificación, que retornará logits, y modificar la función de pérdida a `nn.BCEWithLogitsLoss`.
#
# Como en los ejemplos anteriores hemos utilizado la primera aproximación (la que se ve en el curso), en este caso vamos a ilustrar cómo sería el caso de aplicar la segunda opción, que es computacionalmente numéricamente más estable que la primera y por ende mas aconsejable.

# %%
logits = torch.randn(3, requires_grad=False)
labels = torch.empty(3).random_(2)
probas = nn.Sigmoid()(logits)
print(f"logits: {logits}")
print(f"probas: {probas}")
print(f"labels: {labels}")


output = nn.BCELoss()(probas, labels)
print("BCE", output)

output = nn.BCEWithLogitsLoss()(logits, labels)
print("BCE With Logits", output)
# Out:
# logits: tensor([ 1.1430,  1.0481, -0.3597])
# probas: tensor([0.7582, 0.7404, 0.4110])
# labels: tensor([1., 1., 0.])
# BCE tensor(0.3689)
# BCE With Logits tensor(0.3689)

# %%
classif_head = nn.Sequential(
	nn.Linear(in_features=512*7*7, out_features=512),
	nn.ReLU(),
	nn.Linear(in_features=512, out_features=1)
)

# %%
modelo_vgg16_bn.classifier = classif_head

# %%
modelo_vgg16_bn
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (36): ReLU(inplace=True)
#     (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (39): ReLU(inplace=True)
#     (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (42): ReLU(inplace=True)
#     (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# Para verificar que solo se actualizaron los pesos en las capas descongeladas, vamos a imprimir algunos de los parámetros.
# Haremos un seguimiento de los pesos de la capa convolucional congelada de índice 37 y de la capa convolucional descongelada de índice 40.

# %%
print(f"capa congelada {modelo_vgg16_bn.features.get_parameter('37.weight').shape}")
print(modelo_vgg16_bn.features.get_parameter('37.weight')[0, 0])
print(f"capa descongelada {modelo_vgg16_bn.features.get_parameter('40.weight').shape}")
print(modelo_vgg16_bn.features.get_parameter('40.weight')[0, 0])
# Out:
# capa congelada torch.Size([512, 512, 3, 3])
# tensor([[-0.0106, -0.0231, -0.0083],
#         [-0.0096, -0.0031,  0.0060],
#         [-0.0059,  0.0058,  0.0115]], device='cuda:0')
# capa descongelada torch.Size([512, 512, 3, 3])
# tensor([[ 4.8097e-03,  6.9162e-04,  9.9851e-04],
#         [-6.2526e-03, -1.2559e-02, -4.9773e-03],
#         [-7.5619e-07, -3.3279e-03,  6.1700e-03]], device='cuda:0',
#        grad_fn=<SelectBackward0>)

# %% [markdown]
# Ya con el modelo listo, podemos disponernos a reentrenarlo. Solo se verán afectadas la cabeza de clasificación y el último bloque convolucional que no quedó "congelado".
# Con CPU, una época toma 565 segundos (9.4 minutos).
# Con GPU, una época toma 14 segundos (minutos).

# %%
start = time.time()
reset_seed()
modelo_vgg16_bn, train_losses, train_accuracies, val_losses, val_accuracies = train_model(
    modelo_vgg16_bn, train_data_small,
    train_batch_size=BATCH_SIZE, learning_rate=1e-5, epocas=30, loss_fn=nn.BCEWithLogitsLoss(),
    val_split=0.15, early_stopping_acc_training = -1, early_stopping_loss_val_patience=10, verbose=True)
end = time.time()
print(f"time: {end-start:.2f}")
# Out:
# val_split: 0.15, num_training_instances 1700, num_validation_instances 300
# 0:  loss: 0.271511, accuracy: 0.915882, val loss: 0.128348, val accuracy: 0.943333 -- epoch time: 17.80
# Se mejoró el loss de inf a 0.12834757566452026
# 1:  loss: 0.102408, accuracy: 0.960000, val loss: 0.105462, val accuracy: 0.953333 -- epoch time: 19.17
# Se mejoró el loss de 0.12834757566452026 a 0.10546194016933441
# 2:  loss: 0.075386, accuracy: 0.975294, val loss: 0.095136, val accuracy: 0.966667 -- epoch time: 19.10
# Se mejoró el loss de 0.10546194016933441 a 0.0951363816857338
# 3:  loss: 0.054654, accuracy: 0.981176, val loss: 0.092423, val accuracy: 0.966667 -- epoch time: 18.25
# Se mejoró el loss de 0.0951363816857338 a 0.09242275357246399
# 4:  loss: 0.042205, accuracy: 0.986471, val loss: 0.089515, val accuracy: 0.966667 -- epoch time: 17.22
# Se mejoró el loss de 0.09242275357246399 a 0.089514821767807
# 5:  loss: 0.036458, accuracy: 0.987059, val loss: 0.095017, val accuracy: 0.973333 -- epoch time: 17.63
# 6:  loss: 0.034141, accuracy: 0.990000, val loss: 0.093946, val accuracy: 0.966667 -- epoch time: 18.06
# 7:  loss: 0.028073, accuracy: 0.990588, val loss: 0.096795, val accuracy: 0.963333 -- epoch time: 17.57
# 8:  loss: 0.023073, accuracy: 0.995882, val loss: 0.098149, val accuracy: 0.966667 -- epoch time: 17.63
# 9:  loss: 0.015568, accuracy: 0.999412, val loss: 0.094546, val accuracy: 0.970000 -- epoch time: 18.22
# 10:  loss: 0.015867, accuracy: 0.997647, val loss: 0.103793, val accuracy: 0.970000 -- epoch time: 16.71
# 11:  loss: 0.013763, accuracy: 0.997647, val loss: 0.105732, val accuracy: 0.966667 -- epoch time: 16.50
# 12:  loss: 0.015465, accuracy: 0.996471, val loss: 0.118185, val accuracy: 0.956667 -- epoch time: 17.20
# 13:  loss: 0.009159, accuracy: 0.999412, val loss: 0.108429, val accuracy: 0.970000 -- epoch time: 18.04
# 14:  loss: 0.007153, accuracy: 1.000000, val loss: 0.100980, val accuracy: 0.970000 -- epoch time: 17.24
# 15:  loss: 0.009039, accuracy: 0.998235, val loss: 0.113726, val accuracy: 0.966667 -- epoch time: 18.39
# ----- Se sobrepasó el patience del val loss del early stopping 11)
# time: 286.74

# %%
print(f"capa congelada {modelo_vgg16_bn.features.get_parameter('37.weight').shape}")
print(modelo_vgg16_bn.features.get_parameter('37.weight')[0, 0])
print(f"capa descongelada {modelo_vgg16_bn.features.get_parameter('40.weight').shape}")
print(modelo_vgg16_bn.features.get_parameter('40.weight')[0, 0])
# Out:
# capa congelada torch.Size([512, 512, 3, 3])
# tensor([[-0.0106, -0.0231, -0.0083],
#         [-0.0096, -0.0031,  0.0060],
#         [-0.0059,  0.0058,  0.0115]], device='cuda:0')
# capa descongelada torch.Size([512, 512, 3, 3])
# tensor([[ 0.0039,  0.0001,  0.0008],
#         [-0.0071, -0.0131, -0.0052],
#         [-0.0008, -0.0037,  0.0061]], device='cuda:0',
#        grad_fn=<SelectBackward0>)

# %%
plot_losses_and_accuracies(train_losses, train_accuracies, val_losses, val_accuracies)

# %%
test_loss, test_acc = eval_model(modelo_vgg16_bn, test_data_loader_small, loss_fn=nn.BCEWithLogitsLoss())
print(f"El loss de test es {test_loss}, y el accuracy de test es de {test_acc:.3f}. ")
torch.save(modelo_vgg16_bn, "cats_and_dogs_small_bnorm_tl_finetune.pth")
# Out:
# El loss de test es 0.0795209670914337, y el accuracy de test es de 0.966.

# %% [markdown]
# **Reducido - Base**
#
# **0.00010**(18):  loss: 0.4271/0.4590/0.5503, accuracy: 78.88%/77.33%/73.60%
#
# **Dropout**
#
# **0.00010**(23):  loss: 0.4416/0.4551/0.5274, accuracy: 78.59%/78.67%/72.50%  (paro explícito)
#
# **BatchNorm**
#
# **0.00001**(08):  loss: 0.2852/0.4706,    accuracy: 94.06%/79.33%
#
# **Dropout+BatchNorm**
#
# **0.00010**(04):  loss: 0.4646/0.4795/0.5217,    accuracy: 77.82%/78.67%/74.00% (paro explícito)
#
# **Dropout+BatchNorm+DataAugm**
#
# **0.00100**(61):  loss: 0.4115/0.2940/0.3476,    accuracy: 80.71%/87.00%/84.70% (early stopping)
#
# **TLearning - Feature Extraction**
#
# **0.00001**(16):  loss: 0.0036/0.0404/0.0222,    accuracy: 99.94%/98.67%/99.40% (early stopping)
#
# **TLearning - Fine-tuning**
#
# **0.00001**(16):  loss: 0./0./0.,    accuracy: %/%/% (early stopping)
#
# **Completo - Base**
#
# **0.00001**(16):  loss: 0.1721/0.2149/0.0861,    accuracy: 93.02%/91.53%/97.30% (early stopping)
