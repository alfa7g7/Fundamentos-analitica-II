# %% [markdown]
# # Fundamentos de analítica 2 (clase 4)
#
# ## Diego Fernando Agudelo
# ## Universidad ICESI
# ## diegoagudelo30@gmail.com\

# %% [markdown]
# ## **1. Carga de paquetes**

# %%
import numpy as np
import pandas as pd # Operaciones con dataframes
from matplotlib import pyplot as plt # gráficos
from statsmodels.tsa.seasonal import seasonal_decompose # descomposición de series
from statsmodels.tsa.holtwinters import SimpleExpSmoothing  # Holwinters simple
from statsmodels.tsa.holtwinters import ExponentialSmoothing # Holwinters doble y tripe
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
from sklearn.metrics import mean_squared_error
# !pip install fastai wwf bayesian-optimization -q --upgrade
from bayes_opt import BayesianOptimization
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.8/232.8 KB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 4.4 MB/s eta 0:00:00

# %% [markdown]
# ## **2. Carga de datos**
#
# Nuestra primera tarea será leer el archivo de Excel. Para eso podemos emplear el paquete Pandas. Carguemos los datos en un objeto que denominaremos data.

# %%
data = pd.read_excel("/content/datosEmpleo.xlsx",index_col='mes',parse_dates=True)
data.head()
# Out:
#             TD_13ciudades  Ocupados  Desocupados  Inactivos
# mes
# 2001-01-01      20.946380  6923.604     1834.507   4600.718
# 2001-02-01      19.894213  7037.746     1747.820   4596.805
# 2001-03-01      19.221565  6945.973     1652.823   4807.120
# 2001-04-01      17.888575  6973.079     1519.137   4937.280
# 2001-05-01      17.945654  6994.462     1529.720   4928.911

# %%
# imprimiendo el tamano del dataframe
print(data.shape)

# Graficando los datos
plt.title("Tasa de desempleo mensual (13 ciudades)")
plt.xlabel("Mes")
plt.ylabel("Ocupados")
plt.plot(data[["Ocupados"]])
plt.grid()
plt.show()
# Out:
# (220, 4)

# %%
train_len = 208
train_o = data[["Ocupados"]][:train_len]
test_o = data[["Ocupados"]][train_len:]

fig = plt.figure(figsize=(12, 6))
plt.plot(train_o,label="Datos Entrenamiento")
plt.plot(test_o,label="Datos de Prueba")
plt.legend()
plt.show()

# %% [markdown]
# ## **3. Optimización Bayesiana**

# %%
def train_and_evaluate_RMSE(error,trend,seasonal,alpha,beta,gamma):
    """Function we want to maximize (Black box)

    It first trains a model with the training set using the received hyper
    parameterts, and then evaluatesand returns the Min RMSE over the test set.
    """

    alpha = round(alpha,2)
    beta  = round(beta,2)
    gamma = round(gamma,2)

    print(error,trend,seasonal)
    print(alpha,beta,gamma)
    error1 = ["add","mul"]
    trend1 = ["add","mul",None]
    seasonal1 = ["add","mul",None]

    model = ETSModel(endog=train_o["Ocupados"],error=error1[round(error)],trend=trend1[round(trend)],seasonal=seasonal1[round(seasonal)])

    params = {'smoothing_level': alpha,'smoothing_trend': beta,'smoothing_seasonal':gamma}

    if trend1[round(trend)] == None:
      params.pop('smoothing_trend')
    if seasonal1[round(seasonal)] == None:
      params.pop('smoothing_seasonal')

    model_result = model.fit_constrained(params)

    point_forecast=model_result.forecast(12)
    rmse = np.sqrt(mean_squared_error(test_o["Ocupados"],point_forecast ))

    print(" target es: {},Eror test: {},Trend test: {},Seasonal test: {},Alpha model: {},Beta model: {}, Gamma model: {}".
          format(rmse,error1[round(error)],trend1[round(trend)],seasonal1[round(seasonal)],alpha,beta,gamma))

    return -rmse

# %%
pbounds = {'error':  (0,1),'trend':(0,2) , 'seasonal': (0,2), 'alpha':(0.01,0.99) , "beta" :(0.01,0.99),"gamma" :(0.01,0.99) }

# %%
optimizer = BayesianOptimization(
    f=train_and_evaluate_RMSE,
    pbounds=pbounds,
    random_state=1,
    verbose=2
)

# %%
import warnings
warnings.filterwarnings("ignore")
optimizer.maximize(init_points=3, n_iter=100)
# Out:
# |   iter    |  target   |   alpha   |   beta    |   error   |   gamma   | seasonal  |   trend   |
# -------------------------------------------------------------------------------------------------
# 0.00011437481734488664 0.1846771895375956 0.2935117816342261
# 0.42 0.72 0.31
#  target es: 927.5487253080397,Eror test: add,Trend test: add,Seasonal test: add,Alpha model: 0.42,Beta model: 0.72, Gamma model: 0.31
# | 1         | -927.5    | 0.4187    | 0.7159    | 0.0001144 | 0.3063    | 0.2935    | 0.1847    |
# 0.39676747423066994 1.370439000793519 0.8383890288065896
# 0.19 0.35 0.54
#  target es: 10223.012124968964,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.19,Beta model: 0.35, Gamma model: 0.54
# | 2         | -1.022e+0 | 0.1925    | 0.3486    | 0.3968    | 0.538     | 0.8384    | 1.37      |
# 0.027387593197926163 1.1173796568915033 0.8346096047342539
# 0.21 0.87 0.67
#  target es: 232243.5385763226,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.21,Beta model: 0.87, Gamma model: 0.67
# | 3         | -2.322e+0 | 0.2104    | 0.8706    | 0.02739   | 0.6671    | 0.8346    | 1.117     |
# 0.4788970316947826 1.2890326109897356 0.2755213848530631
# 0.56 0.38 0.56
#  target es: 661.0990182188133,Eror test: add,Trend test: mul,Seasonal test: add,Alpha model: 0.56,Beta model: 0.38, Gamma model: 0.56
# | 4         | -661.1    | 0.5602    | 0.3779    | 0.4789    | 0.56      | 0.2755    | 1.289     |
# 0.6630587587235695 0.6058687130274079 0.3444104104386949
# 0.6 0.32 0.45
#  target es: 32780.84058407207,Eror test: mul,Trend test: mul,Seasonal test: add,Alpha model: 0.6,Beta model: 0.32, Gamma model: 0.45
# | 5         | -3.278e+0 | 0.5958    | 0.322     | 0.6631    | 0.4494    | 0.3444    | 0.6059    |
# 0.05899641497139618 0.370266029620234 0.45376497909817903
# 0.89 0.53 0.83
#  target es: 2229.6064511899813,Eror test: add,Trend test: add,Seasonal test: add,Alpha model: 0.89,Beta model: 0.53, Gamma model: 0.83
# | 6         | -2.23e+03 | 0.8892    | 0.529     | 0.059     | 0.8305    | 0.4538    | 0.3703    |
# 0.7299816147894711 0.7899907117248379 1.3257763437163137
# 0.41 0.13 0.86
#  target es: 27448.524717336873,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.41,Beta model: 0.13, Gamma model: 0.86
# | 7         | -2.745e+0 | 0.4113    | 0.1299    | 0.73      | 0.8607    | 1.326     | 0.79      |
# 0.9866433985820416 0.9081386226623189 0.026654423837956243
# 0.91 0.1 0.94
#  target es: 1526.5603418324652,Eror test: mul,Trend test: mul,Seasonal test: add,Alpha model: 0.91,Beta model: 0.1, Gamma model: 0.94
# | 8         | -1.527e+0 | 0.9085    | 0.1027    | 0.9866    | 0.938     | 0.02665   | 0.9081    |
# 0.32908604231260496 0.060745301971308674 1.5948599545923625
# 0.69 0.57 0.71
#  target es: 1160.0660858744488,Eror test: add,Trend test: add,Seasonal test: None,Alpha model: 0.69,Beta model: 0.57, Gamma model: 0.71
# | 9         | -1.16e+03 | 0.6901    | 0.5721    | 0.3291    | 0.7056    | 1.595     | 0.06075   |
# 0.15923106339221182 1.4126804202408707 1.6230471855756556
# 0.21 0.3 0.28
#  target es: 375.4505259971951,Eror test: add,Trend test: mul,Seasonal test: None,Alpha model: 0.21,Beta model: 0.3, Gamma model: 0.28
# | 10        | -375.5    | 0.2078    | 0.2978    | 0.1592    | 0.2846    | 1.623     | 1.413     |
# 0.5124523563471822 1.8905135151514556 1.476794355498355
# 0.01 0.81 0.54
#  target es: 135.08418284863953,Eror test: mul,Trend test: None,Seasonal test: mul,Alpha model: 0.01,Beta model: 0.81, Gamma model: 0.54
# | 11        | -135.1    | 0.01452   | 0.8146    | 0.5125    | 0.5359    | 1.477     | 1.891     |
# 0.863586029286257 0.843809163827042 1.6933909700489878
# 0.04 0.71 0.3
#  target es: 3210.069499042015,Eror test: mul,Trend test: mul,Seasonal test: None,Alpha model: 0.04,Beta model: 0.71, Gamma model: 0.3
# | 12        | -3.21e+03 | 0.04341   | 0.7142    | 0.8636    | 0.3044    | 1.693     | 0.8438    |
# 0.5595428333257875 0.47559043024285574 1.5111424739009283
# 0.89 0.09 0.26
#  target es: 191.3894685274196,Eror test: mul,Trend test: add,Seasonal test: None,Alpha model: 0.89,Beta model: 0.09, Gamma model: 0.26
# | 13        | -191.4    | 0.8902    | 0.09469   | 0.5595    | 0.2597    | 1.511     | 0.4756    |
# 0.3225710494563018 1.1615876200427406 0.652297121762113
# 0.98 0.74 0.38
#  target es: 245.29990182387448,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.98,Beta model: 0.74, Gamma model: 0.38
# | 14        | -245.3    | 0.9791    | 0.741     | 0.3226    | 0.3768    | 0.6523    | 1.162     |
# 0.23341243216694096 1.9315577717855332 1.5333458657033368
# 0.75 0.21 0.58
#  target es: 184.67151422602757,Eror test: add,Trend test: None,Seasonal test: None,Alpha model: 0.75,Beta model: 0.21, Gamma model: 0.58
# | 15        | -184.7    | 0.7532    | 0.2097    | 0.2334    | 0.5836    | 1.533     | 1.932     |
# 0.38852980206310295 1.4498221342801607 1.5830590001903104
# 0.87 0.98 0.86
#  target es: 361.1457371008383,Eror test: add,Trend test: mul,Seasonal test: None,Alpha model: 0.87,Beta model: 0.98, Gamma model: 0.86
# | 16        | -361.1    | 0.8664    | 0.9824    | 0.3885    | 0.8557    | 1.583     | 1.45      |
# 0.4657926659908197 0.7946720454345986 1.2737364530709636
# 0.03 0.33 0.29
#  target es: 69692.77974970685,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.03,Beta model: 0.33, Gamma model: 0.29
# | 17        | -6.969e+0 | 0.02706   | 0.3347    | 0.4658    | 0.2914    | 1.274     | 0.7947    |
# 0.7248007261806554 1.320789703701671 0.8733619147997165
# 0.56 0.59 0.75
#  target es: 399844.81880360015,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.56,Beta model: 0.59, Gamma model: 0.75
# | 18        | -3.998e+0 | 0.5589    | 0.5878    | 0.7248    | 0.7534    | 0.8734    | 1.321     |
# 0.6909316372475801 1.234283898177453 0.5597945245522595
# 0.08 0.67 0.68
#  target es: 787602509485355.6,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.08,Beta model: 0.67, Gamma model: 0.68
# | 19        | -7.876e+1 | 0.08486   | 0.6671    | 0.6909    | 0.682     | 0.5598    | 1.234     |
# 0.03918171092472056 1.5128623442539337 0.1807766695688442
# 0.83 0.02 0.8
#  target es: 249.66437875258126,Eror test: add,Trend test: None,Seasonal test: add,Alpha model: 0.83,Beta model: 0.02, Gamma model: 0.8
# | 20        | -249.7    | 0.8251    | 0.01722   | 0.03918   | 0.8017    | 0.1808    | 1.513     |
# 0.46272769810442216 0.2330209772765317 0.5913792249764112
# 0.1 0.98 0.15
#  target es: 324553.0667285006,Eror test: add,Trend test: add,Seasonal test: mul,Alpha model: 0.1,Beta model: 0.98, Gamma model: 0.15
# | 21        | -3.246e+0 | 0.1007    | 0.9838    | 0.4627    | 0.1465    | 0.5914    | 0.233     |
# 0.9137891329227043 1.281062097430051 0.623371975998964
# 0.16 0.08 0.11
#  target es: 130.52846980192783,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.16,Beta model: 0.08, Gamma model: 0.11
# | 22        | -130.5    | 0.1628    | 0.07505   | 0.9138    | 0.1063    | 0.6234    | 1.281     |
# 0.8565723942143516 0.4994995602163417 1.7090157470573801
# 0.41 0.73 0.98
#  target es: 2729.832181872313,Eror test: mul,Trend test: add,Seasonal test: None,Alpha model: 0.41,Beta model: 0.73, Gamma model: 0.98
# | 23        | -2.73e+03 | 0.4075    | 0.7285    | 0.8566    | 0.981     | 1.709     | 0.4995    |
# 0.016525687657107158 0.45412804012695984 1.8779319052122936
# 0.02 0.64 0.88
#  target es: 621.2680670912493,Eror test: add,Trend test: add,Seasonal test: None,Alpha model: 0.02,Beta model: 0.64, Gamma model: 0.88
# | 24        | -621.3    | 0.02419   | 0.6378    | 0.01653   | 0.8803    | 1.878     | 0.4541    |
# 0.5311869646531169 1.0154856675233124 0.5634003343863672
# 0.06 0.54 0.04
#  target es: 2096.7087056530295,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.06,Beta model: 0.54, Gamma model: 0.04
# | 25        | -2.097e+0 | 0.06227   | 0.5443    | 0.5312    | 0.04278   | 0.5634    | 1.015     |
# 0.8110396677477442 1.4241358595007716 1.7520329159770418
# 0.48 0.76 0.78
#  target es: 2772.7761426136503,Eror test: mul,Trend test: mul,Seasonal test: None,Alpha model: 0.48,Beta model: 0.76, Gamma model: 0.78
# | 26        | -2.773e+0 | 0.4837    | 0.7552    | 0.811     | 0.7754    | 1.752     | 1.424     |
# 0.5072040583559912 0.31205275106117414 0.05795197906142735
# 0.38 0.09 0.43
#  target es: 322.1227339598927,Eror test: mul,Trend test: add,Seasonal test: add,Alpha model: 0.38,Beta model: 0.09, Gamma model: 0.43
# | 27        | -322.1    | 0.3809    | 0.09107   | 0.5072    | 0.426     | 0.05795   | 0.3121    |
# 0.7981423541333276 1.0669806275498943 1.23432457950172
# 0.7 0.14 0.63
#  target es: 415.21507607839766,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.7,Beta model: 0.14, Gamma model: 0.63
# | 28        | -415.2    | 0.7005    | 0.1412    | 0.7981    | 0.6334    | 1.234     | 1.067     |
# 0.4135570011248383 1.3944186938976322 1.9909044067890478
# 0.81 0.85 0.81
#  target es: 475.9931725748484,Eror test: add,Trend test: mul,Seasonal test: None,Alpha model: 0.81,Beta model: 0.85, Gamma model: 0.81
# | 29        | -476.0    | 0.8138    | 0.8492    | 0.4136    | 0.8106    | 1.991     | 1.394     |
# 0.6911336149801262 0.30984588607652874 1.898520578392221
# 0.02 0.74 0.66
#  target es: 2688.2639827998087,Eror test: mul,Trend test: add,Seasonal test: None,Alpha model: 0.02,Beta model: 0.74, Gamma model: 0.66
# | 30        | -2.688e+0 | 0.02034   | 0.7356    | 0.6911    | 0.6595    | 1.899     | 0.3098    |
# 0.3682351204851002 1.1677166843009426 0.6915273196167006
# 0.86 0.65 0.43
#  target es: 926.8303444527337,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.86,Beta model: 0.65, Gamma model: 0.43
# | 31        | -926.8    | 0.8641    | 0.6492    | 0.3682    | 0.4335    | 0.6915    | 1.168     |
# 0.4758840310385707 1.3376103916066342 1.0791169377204657
# 0.57 0.31 0.59
#  target es: 178.44399262167715,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.57,Beta model: 0.31, Gamma model: 0.59
# | 32        | -178.4    | 0.5671    | 0.313     | 0.4759    | 0.5857    | 1.079     | 1.338     |
# 0.12093143979952514 1.4181081187649187 0.2442505652345226
# 0.95 0.95 0.25
#  target es: 2686.5683087148363,Eror test: add,Trend test: mul,Seasonal test: add,Alpha model: 0.95,Beta model: 0.95, Gamma model: 0.25
# | 33        | -2.687e+0 | 0.9543    | 0.9478    | 0.1209    | 0.2541    | 0.2443    | 1.418     |
# 0.20272573737432664 0.22313106280737616 0.6019455127881299
# 0.23 0.56 0.83
#  target es: 2126996.7534400807,Eror test: add,Trend test: add,Seasonal test: mul,Alpha model: 0.23,Beta model: 0.56, Gamma model: 0.83
# | 34        | -2.127e+0 | 0.2258    | 0.5584    | 0.2027    | 0.8336    | 0.6019    | 0.2231    |
# 0.09827002214071667 1.810304693310676 0.6018709775152453
# 0.36 0.46 0.48
#  target es: 135.57070346520112,Eror test: add,Trend test: None,Seasonal test: mul,Alpha model: 0.36,Beta model: 0.46, Gamma model: 0.48
# | 35        | -135.6    | 0.3617    | 0.4551    | 0.09827   | 0.4836    | 0.6019    | 1.81      |
# 0.25612980752255066 0.7583576427159153 1.775192590541123
# 0.33 0.05 0.29
#  target es: 220.89554333000095,Eror test: add,Trend test: mul,Seasonal test: None,Alpha model: 0.33,Beta model: 0.05, Gamma model: 0.29
# | 36        | -220.9    | 0.3286    | 0.05172   | 0.2561    | 0.2863    | 1.775     | 0.7584    |
# 0.5677980381415073 1.9406834156907515 0.2541486120351484
# 0.13 0.17 0.15
#  target es: 117.66643248793336,Eror test: mul,Trend test: None,Seasonal test: add,Alpha model: 0.13,Beta model: 0.17, Gamma model: 0.15
# | 37        | -117.7    | 0.1309    | 0.1704    | 0.5678    | 0.1533    | 0.2541    | 1.941     |
# 0.17888089625364392 1.5181243502796884 1.1169879179359732
# 0.28 0.3 0.42
#  target es: 127.76513908145958,Eror test: add,Trend test: None,Seasonal test: mul,Alpha model: 0.28,Beta model: 0.3, Gamma model: 0.42
# | 38        | -127.8    | 0.28      | 0.2993    | 0.1789    | 0.4161    | 1.117     | 1.518     |
# 0.3329334301043635 0.6781553678006442 1.5526098950600866
# 0.98 0.2 0.95
#  target es: 230.28355657311826,Eror test: add,Trend test: mul,Seasonal test: None,Alpha model: 0.98,Beta model: 0.2, Gamma model: 0.95
# | 39        | -230.3    | 0.9797    | 0.1988    | 0.3329    | 0.9508    | 1.553     | 0.6782    |
# 0.038741682853049686 1.0383291926589786 1.680303977607397
# 0.98 0.17 0.19
#  target es: 216.39362088811586,Eror test: add,Trend test: mul,Seasonal test: None,Alpha model: 0.98,Beta model: 0.17, Gamma model: 0.19
# | 40        | -216.4    | 0.9799    | 0.1726    | 0.03874   | 0.1927    | 1.68      | 1.038     |
# 0.5929358085564578 0.7418656187365031 1.0406820851300271
# 0.8 0.23 0.69
#  target es: 5872.18745403938,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.8,Beta model: 0.23, Gamma model: 0.69
# | 41        | -5.872e+0 | 0.7957    | 0.2339    | 0.5929    | 0.6936    | 1.041     | 0.7419    |
# 0.70775814416089 0.5424040339192087 1.0445168492192942
# 0.19 0.71 0.77
#  target es: 1.0493835864711253e+31,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.19,Beta model: 0.71, Gamma model: 0.77
# | 42        | -1.049e+3 | 0.193     | 0.7112    | 0.7078    | 0.7749    | 1.045     | 0.5424    |
# 0.7056292104849887 0.8130619796620187 1.9293578980115274
# 0.57 0.26 0.77
#  target es: 403.35361780756705,Eror test: mul,Trend test: mul,Seasonal test: None,Alpha model: 0.57,Beta model: 0.26, Gamma model: 0.77
# | 43        | -403.4    | 0.5699    | 0.2604    | 0.7056    | 0.77      | 1.929     | 0.8131    |
# 0.45319083432770324 1.0564491324683523 1.2376352490482445
# 0.39 0.01 0.07
#  target es: 163.51829635506294,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.39,Beta model: 0.01, Gamma model: 0.07
# | 44        | -163.5    | 0.3865    | 0.01      | 0.4532    | 0.06833   | 1.238     | 1.056     |
# 0.6746529145113672 1.1744335877242396 1.616540032130121
# 0.17 0.01 0.54
#  target es: 189.6339025492869,Eror test: mul,Trend test: mul,Seasonal test: None,Alpha model: 0.17,Beta model: 0.01, Gamma model: 0.54
# | 45        | -189.6    | 0.1653    | 0.01      | 0.6747    | 0.5418    | 1.617     | 1.174     |
# 0.5464437614230697 1.0574411750294102 0.5687824442261024
# 0.09 0.57 0.11
#  target es: 918.8962389193678,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.09,Beta model: 0.57, Gamma model: 0.11
# | 46        | -918.9    | 0.09041   | 0.5725    | 0.5464    | 0.1096    | 0.5688    | 1.057     |
# 0.0 0.0016382730324530765 0.17867727393766514
# 0.3 0.34 0.91
#  target es: 916.2731298707537,Eror test: add,Trend test: add,Seasonal test: add,Alpha model: 0.3,Beta model: 0.34, Gamma model: 0.91
# | 47        | -916.3    | 0.2979    | 0.3358    | 0.0       | 0.9124    | 0.1787    | 0.001638  |
# 0.40023299864164685 0.49802772568400777 1.007815053437854
# 0.92 0.77 0.02
#  target es: 129.37790749538811,Eror test: add,Trend test: add,Seasonal test: mul,Alpha model: 0.92,Beta model: 0.77, Gamma model: 0.02
# | 48        | -129.4    | 0.9243    | 0.7714    | 0.4002    | 0.02447   | 1.008     | 0.498     |
# 0.7679659341679457 1.7449074060032825 0.603466446552197
# 0.35 0.75 0.37
#  target es: 122.95564595917445,Eror test: mul,Trend test: None,Seasonal test: mul,Alpha model: 0.35,Beta model: 0.75, Gamma model: 0.37
# | 49        | -123.0    | 0.3499    | 0.748     | 0.768     | 0.366     | 0.6035    | 1.745     |
# 0.8335494597364209 0.2221964866253399 2.0
# 0.79 0.59 0.99
#  target es: 856.2310895629477,Eror test: mul,Trend test: add,Seasonal test: None,Alpha model: 0.79,Beta model: 0.59, Gamma model: 0.99
# | 50        | -856.2    | 0.7903    | 0.5891    | 0.8335    | 0.99      | 2.0       | 0.2222    |
# 0.4764238444494425 0.4433937223240043 1.0009094726368721
# 0.18 0.47 0.03
#  target es: 1355.2785477256084,Eror test: add,Trend test: add,Seasonal test: mul,Alpha model: 0.18,Beta model: 0.47, Gamma model: 0.03
# | 51        | -1.355e+0 | 0.1819    | 0.4684    | 0.4764    | 0.03202   | 1.001     | 0.4434    |
# 0.13447045821178405 0.6792546227611336 0.6683875394922228
# 0.57 0.2 0.01
#  target es: 398.6976365635176,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.57,Beta model: 0.2, Gamma model: 0.01
# | 52        | -398.7    | 0.5735    | 0.199     | 0.1345    | 0.01      | 0.6684    | 0.6793    |
# 0.7220921898347765 0.9859527729769035 1.1982617235551314
# 0.65 0.11 0.63
#  target es: 433.80552755003106,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.65,Beta model: 0.11, Gamma model: 0.63
# | 53        | -433.8    | 0.6466    | 0.1059    | 0.7221    | 0.6281    | 1.198     | 0.986     |
# 0.721689173157254 1.3620909836645085 0.377564009852962
# 0.45 0.64 0.16
#  target es: 535.3400418118874,Eror test: mul,Trend test: mul,Seasonal test: add,Alpha model: 0.45,Beta model: 0.64, Gamma model: 0.16
# | 54        | -535.3    | 0.4518    | 0.6379    | 0.7217    | 0.1622    | 0.3776    | 1.362     |
# 0.0563118061514509 0.9111910268226237 0.843267595636816
# 0.99 0.01 0.65
#  target es: 391.44835463269635,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.99,Beta model: 0.01, Gamma model: 0.65
# | 55        | -391.4    | 0.99      | 0.01      | 0.05631   | 0.6539    | 0.8433    | 0.9112    |
# 0.8075519238644248 0.6866437352646723 1.7332487732537076
# 0.01 0.12 0.01
#  target es: 532.5928251630522,Eror test: mul,Trend test: mul,Seasonal test: None,Alpha model: 0.01,Beta model: 0.12, Gamma model: 0.01
# | 56        | -532.6    | 0.01      | 0.1155    | 0.8076    | 0.01      | 1.733     | 0.6866    |
# 0.23725538612137953 1.549786552898464 0.2901008806685259
# 0.03 0.38 0.82
#  target es: 136.01609699963748,Eror test: add,Trend test: None,Seasonal test: add,Alpha model: 0.03,Beta model: 0.38, Gamma model: 0.82
# | 57        | -136.0    | 0.03054   | 0.3842    | 0.2373    | 0.8227    | 0.2901    | 1.55      |
# 0.0007251009964700517 0.7861487754106946 1.1348819018693732
# 0.07 0.11 0.04
#  target es: 156.61700967950222,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.07,Beta model: 0.11, Gamma model: 0.04
# | 58        | -156.6    | 0.07419   | 0.1079    | 0.0007251 | 0.0374    | 1.135     | 0.7861    |
# 0.15240061830742477 1.4423884971541885 0.29601230083141666
# 0.04 0.99 0.36
#  target es: 6.792644304271012e+40,Eror test: add,Trend test: mul,Seasonal test: add,Alpha model: 0.04,Beta model: 0.99, Gamma model: 0.36
# | 59        | -6.793e+4 | 0.03739   | 0.99      | 0.1524    | 0.3649    | 0.296     | 1.442     |
# 0.6272353585112105 0.5310788694307818 1.1172236056693705
# 0.84 0.79 0.87
#  target es: 2.8352730595518546e+38,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.84,Beta model: 0.79, Gamma model: 0.87
# | 60        | -2.835e+3 | 0.8394    | 0.7901    | 0.6272    | 0.8731    | 1.117     | 0.5311    |
# 0.30995330388801745 0.37614431328587683 0.8007828074237244
# 0.42 0.41 0.06
#  target es: 811.816339516732,Eror test: add,Trend test: add,Seasonal test: mul,Alpha model: 0.42,Beta model: 0.41, Gamma model: 0.06
# | 61        | -811.8    | 0.4185    | 0.4131    | 0.31      | 0.06448   | 0.8008    | 0.3761    |
# 0.4115864580138484 1.918771536044472 0.5279922335619482
# 0.24 0.04 0.98
#  target es: 153.20911675228686,Eror test: add,Trend test: None,Seasonal test: mul,Alpha model: 0.24,Beta model: 0.04, Gamma model: 0.98
# | 62        | -153.2    | 0.2381    | 0.04485   | 0.4116    | 0.9847    | 0.528     | 1.919     |
# 0.0 0.9669288587130304 1.2234609364824043
# 0.32 0.73 0.99
#  target es: 2.525571008558733e+29,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.32,Beta model: 0.73, Gamma model: 0.99
# | 63        | -2.526e+2 | 0.3213    | 0.7272    | 0.0       | 0.99      | 1.223     | 0.9669    |
# 0.86055835526936 1.2806001952885382 0.6145191239530392
# 0.15 0.03 0.13
#  target es: 124.49801771265649,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.15,Beta model: 0.03, Gamma model: 0.13
# | 64        | -124.5    | 0.1536    | 0.02847   | 0.8606    | 0.128     | 0.6145    | 1.281     |
# 0.14003688928623848 0.028026994271269423 0.26693533904747335
# 0.26 0.94 0.23
#  target es: 1607.211675655723,Eror test: add,Trend test: add,Seasonal test: add,Alpha model: 0.26,Beta model: 0.94, Gamma model: 0.23
# | 65        | -1.607e+0 | 0.2591    | 0.9355    | 0.14      | 0.227     | 0.2669    | 0.02803   |
# 0.5515565247625168 1.9775273968315372 0.586026753872526
# 0.94 0.32 0.23
#  target es: 130.39451610326353,Eror test: mul,Trend test: None,Seasonal test: mul,Alpha model: 0.94,Beta model: 0.32, Gamma model: 0.23
# | 66        | -130.4    | 0.9421    | 0.3228    | 0.5516    | 0.2309    | 0.586     | 1.978     |
# 0.020944774068269 1.0859579378141226 0.5867196823365313
# 0.82 0.31 0.6
#  target es: 764.6982775609026,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.82,Beta model: 0.31, Gamma model: 0.6
# | 67        | -764.7    | 0.8221    | 0.3067    | 0.02094   | 0.5975    | 0.5867    | 1.086     |
# 0.6287055672094555 1.1369506089277073 0.3117748382041368
# 0.01 0.02 0.99
#  target es: 2.0367043953763814e+105,Eror test: mul,Trend test: mul,Seasonal test: add,Alpha model: 0.01,Beta model: 0.02, Gamma model: 0.99
# | 68        | -2.037e+1 | 0.01      | 0.01666   | 0.6287    | 0.99      | 0.3118    | 1.137     |
# 0.0683591423447727 1.8249770726862864 0.016396941934634368
# 0.44 0.65 0.95
#  target es: 155.06739418374465,Eror test: add,Trend test: None,Seasonal test: add,Alpha model: 0.44,Beta model: 0.65, Gamma model: 0.95
# | 69        | -155.1    | 0.4425    | 0.6479    | 0.06836   | 0.9473    | 0.0164    | 1.825     |
# 1.0 0.06918646455199016 0.0
# 0.99 0.37 0.38
#  target es: 139.00392091191114,Eror test: mul,Trend test: add,Seasonal test: add,Alpha model: 0.99,Beta model: 0.37, Gamma model: 0.38
# | 70        | -139.0    | 0.99      | 0.3731    | 1.0       | 0.3757    | 0.0       | 0.06919   |
# 0.6081303898441438 1.025316648092482 0.0
# 0.99 0.06 0.01
#  target es: 303.36702363261,Eror test: mul,Trend test: mul,Seasonal test: add,Alpha model: 0.99,Beta model: 0.06, Gamma model: 0.01
# | 71        | -303.4    | 0.99      | 0.06103   | 0.6081    | 0.01      | 0.0       | 1.025     |
# 0.25150183672163007 1.6226382670764996 1.5594727865738023
# 0.04 0.03 0.59
#  target es: 256.13262916210135,Eror test: add,Trend test: None,Seasonal test: None,Alpha model: 0.04,Beta model: 0.03, Gamma model: 0.59
# | 72        | -256.1    | 0.04452   | 0.0299    | 0.2515    | 0.5925    | 1.559     | 1.623     |
# 0.0782032190399079 1.8513281123656677 0.6444555574807818
# 0.42 0.42 0.43
#  target es: 134.19958565157373,Eror test: add,Trend test: None,Seasonal test: mul,Alpha model: 0.42,Beta model: 0.42, Gamma model: 0.43
# | 73        | -134.2    | 0.4244    | 0.4241    | 0.0782    | 0.4268    | 0.6445    | 1.851     |
# 0.9301768804803906 0.9261069729038592 0.0
# 0.99 0.99 0.69
#  target es: 298856907702187.9,Eror test: mul,Trend test: mul,Seasonal test: add,Alpha model: 0.99,Beta model: 0.99, Gamma model: 0.69
# | 74        | -2.989e+1 | 0.99      | 0.99      | 0.9302    | 0.6934    | 0.0       | 0.9261    |
# 0.4864026520910961 0.5163950626297025 1.4669907480082882
# 0.87 0.11 0.32
#  target es: 125.19716317887212,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.87,Beta model: 0.11, Gamma model: 0.32
# | 75        | -125.2    | 0.8701    | 0.1144    | 0.4864    | 0.3199    | 1.467     | 0.5164    |
# 0.06171080055943507 0.0 0.0
# 0.99 0.01 0.01
#  target es: 202.06692544061113,Eror test: add,Trend test: add,Seasonal test: add,Alpha model: 0.99,Beta model: 0.01, Gamma model: 0.01
# | 76        | -202.1    | 0.99      | 0.01      | 0.06171   | 0.01      | 0.0       | 0.0       |
# 1.0 2.0 2.0
# 0.99 0.99 0.01
#  target es: 184.81962782960665,Eror test: mul,Trend test: None,Seasonal test: None,Alpha model: 0.99,Beta model: 0.99, Gamma model: 0.01
# | 77        | -184.8    | 0.99      | 0.99      | 1.0       | 0.01      | 2.0       | 2.0       |
# 1.0 2.0 2.0
# 0.01 0.01 0.01
#  target es: 1199.0561269276136,Eror test: mul,Trend test: None,Seasonal test: None,Alpha model: 0.01,Beta model: 0.01, Gamma model: 0.01
# | 78        | -1.199e+0 | 0.01      | 0.01      | 1.0       | 0.01      | 2.0       | 2.0       |
# 0.0 0.0 2.0
# 0.99 0.99 0.01
#  target es: 719.6093700850087,Eror test: add,Trend test: add,Seasonal test: None,Alpha model: 0.99,Beta model: 0.99, Gamma model: 0.01
# | 79        | -719.6    | 0.99      | 0.99      | 0.0       | 0.01      | 2.0       | 0.0       |
# 0.49960606789791007 1.894875091722404 0.23739372483176835
# 0.1 0.13 0.17
#  target es: 118.27058351675628,Eror test: add,Trend test: None,Seasonal test: add,Alpha model: 0.1,Beta model: 0.13, Gamma model: 0.17
# | 80        | -118.3    | 0.1036    | 0.1285    | 0.4996    | 0.1682    | 0.2374    | 1.895     |
# 0.37218486278221374 1.7090541008588351 0.4314570275543672
# 0.65 0.72 0.6
#  target es: 186.7381676875002,Eror test: add,Trend test: None,Seasonal test: add,Alpha model: 0.65,Beta model: 0.72, Gamma model: 0.6
# | 81        | -186.7    | 0.6519    | 0.7196    | 0.3722    | 0.6049    | 0.4315    | 1.709     |
# 0.2860049673250895 1.7208469043244488 0.8711867136487286
# 0.07 0.97 0.97
#  target es: 144.69303612590585,Eror test: add,Trend test: None,Seasonal test: mul,Alpha model: 0.07,Beta model: 0.97, Gamma model: 0.97
# | 82        | -144.7    | 0.07057   | 0.9707    | 0.286     | 0.9735    | 0.8712    | 1.721     |
# 0.5415773959965829 0.48645143898903265 1.036725758069953
# 0.21 0.53 0.03
#  target es: 1309.7583071410922,Eror test: mul,Trend test: add,Seasonal test: mul,Alpha model: 0.21,Beta model: 0.53, Gamma model: 0.03
# | 83        | -1.31e+03 | 0.2082    | 0.5297    | 0.5416    | 0.03018   | 1.037     | 0.4865    |
# 0.5627970679551841 0.9026930153867352 1.8271969965210146
# 0.66 0.6 0.82
#  target es: 1421.1483528825306,Eror test: mul,Trend test: mul,Seasonal test: None,Alpha model: 0.66,Beta model: 0.6, Gamma model: 0.82
# | 84        | -1.421e+0 | 0.6642    | 0.6048    | 0.5628    | 0.8186    | 1.827     | 0.9027    |
# 0.16904478253753907 1.6116739778774645 0.26262933193432647
# 0.18 0.34 0.4
#  target es: 126.51912990290025,Eror test: add,Trend test: None,Seasonal test: add,Alpha model: 0.18,Beta model: 0.34, Gamma model: 0.4
# | 85        | -126.5    | 0.1787    | 0.338     | 0.169     | 0.4043    | 0.2626    | 1.612     |
# 0.0 2.0 2.0
# 0.99 0.99 0.01
#  target es: 184.81962782960665,Eror test: add,Trend test: None,Seasonal test: None,Alpha model: 0.99,Beta model: 0.99, Gamma model: 0.01
# | 86        | -184.8    | 0.99      | 0.99      | 0.0       | 0.01      | 2.0       | 2.0       |
# 0.0 0.0 2.0
# 0.01 0.99 0.01
#  target es: 43977.3093395348,Eror test: add,Trend test: add,Seasonal test: None,Alpha model: 0.01,Beta model: 0.99, Gamma model: 0.01
# | 87        | -4.398e+0 | 0.01      | 0.99      | 0.0       | 0.01      | 2.0       | 0.0       |
# 0.45965455439260905 1.3939245812752734 0.7647326376904973
# 0.52 0.85 0.97
#  target es: 10767.077995654128,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.52,Beta model: 0.85, Gamma model: 0.97
# | 88        | -1.077e+0 | 0.5235    | 0.851     | 0.4597    | 0.9717    | 0.7647    | 1.394     |
# 1.0 2.0 2.0
# 0.99 0.01 0.99
#  target es: 184.81962782960665,Eror test: mul,Trend test: None,Seasonal test: None,Alpha model: 0.99,Beta model: 0.01, Gamma model: 0.99
# | 89        | -184.8    | 0.99      | 0.01      | 1.0       | 0.99      | 2.0       | 2.0       |
# 1.0 0.0 2.0
# 0.99 0.99 0.01
#  target es: 719.6093700850087,Eror test: mul,Trend test: add,Seasonal test: None,Alpha model: 0.99,Beta model: 0.99, Gamma model: 0.01
# | 90        | -719.6    | 0.99      | 0.99      | 1.0       | 0.01      | 2.0       | 0.0       |
# 0.18721467695786953 0.769601542750858 1.8074119827588317
# 0.61 0.2 0.23
#  target es: 270.8752542808976,Eror test: add,Trend test: mul,Seasonal test: None,Alpha model: 0.61,Beta model: 0.2, Gamma model: 0.23
# | 91        | -270.9    | 0.6088    | 0.1975    | 0.1872    | 0.2338    | 1.807     | 0.7696    |
# 0.09915402695413045 1.2198652888866621 0.5454091716820428
# 0.42 0.16 0.17
#  target es: 222.12382585651798,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.42,Beta model: 0.16, Gamma model: 0.17
# | 92        | -222.1    | 0.4178    | 0.164     | 0.09915   | 0.167     | 0.5454    | 1.22      |
# 0.7586390310177874 1.4293148438115493 1.7714799687207852
# 0.52 0.74 0.82
#  target es: 2432.5733240744034,Eror test: mul,Trend test: mul,Seasonal test: None,Alpha model: 0.52,Beta model: 0.74, Gamma model: 0.82
# | 93        | -2.433e+0 | 0.5176    | 0.7392    | 0.7586    | 0.8176    | 1.771     | 1.429     |
# 0.0 2.0 0.0
# 0.99 0.01 0.01
#  target es: 120.31864169042586,Eror test: add,Trend test: None,Seasonal test: add,Alpha model: 0.99,Beta model: 0.01, Gamma model: 0.01
# | 94        | -120.3    | 0.99      | 0.01      | 0.0       | 0.01      | 0.0       | 2.0       |
# 0.5929523255865321 0.3494404547220664 0.43346710238518305
# 0.54 0.64 0.36
#  target es: 939.5071314196432,Eror test: mul,Trend test: add,Seasonal test: add,Alpha model: 0.54,Beta model: 0.64, Gamma model: 0.36
# | 95        | -939.5    | 0.5361    | 0.6403    | 0.593     | 0.3562    | 0.4335    | 0.3494    |
# 1.0 2.0 0.0
# 0.99 0.99 0.99
#  target es: 707.7395866839321,Eror test: mul,Trend test: None,Seasonal test: add,Alpha model: 0.99,Beta model: 0.99, Gamma model: 0.99
# | 96        | -707.7    | 0.99      | 0.99      | 1.0       | 0.99      | 0.0       | 2.0       |
# 0.0 2.0 2.0
# 0.01 0.99 0.99
#  target es: 1181.5028764113183,Eror test: add,Trend test: None,Seasonal test: None,Alpha model: 0.01,Beta model: 0.99, Gamma model: 0.99
# | 97        | -1.182e+0 | 0.01      | 0.99      | 0.0       | 0.99      | 2.0       | 2.0       |
# 0.9988868740735849 0.0215358260953058 0.8846495158737981
# 0.99 0.1 0.32
#  target es: 136.5552852017476,Eror test: mul,Trend test: add,Seasonal test: mul,Alpha model: 0.99,Beta model: 0.1, Gamma model: 0.32
# | 98        | -136.6    | 0.9874    | 0.1004    | 0.9989    | 0.3236    | 0.8846    | 0.02154   |
# 1.0 0.0 2.0
# 0.01 0.01 0.99
#  target es: 173.80384082329388,Eror test: mul,Trend test: add,Seasonal test: None,Alpha model: 0.01,Beta model: 0.01, Gamma model: 0.99
# | 99        | -173.8    | 0.01      | 0.01      | 1.0       | 0.99      | 2.0       | 0.0       |
# 0.7720022968427422 1.3941627914528487 1.4823115503386837
# 0.16 0.31 0.26
#  target es: 780.404279215841,Eror test: mul,Trend test: mul,Seasonal test: mul,Alpha model: 0.16,Beta model: 0.31, Gamma model: 0.26
# | 100       | -780.4    | 0.1578    | 0.3142    | 0.772     | 0.2606    | 1.482     | 1.394     |
# 0.021961594691957353 0.5418574717736468 0.83627094855603
# 0.07 0.69 0.37
#  target es: 2700.7198969013943,Eror test: add,Trend test: mul,Seasonal test: mul,Alpha model: 0.07,Beta model: 0.69, Gamma model: 0.37
# | 101       | -2.701e+0 | 0.07231   | 0.6948    | 0.02196   | 0.3688    | 0.8363    | 0.5419    |
# 1.0 2.0 2.0
# 0.99 0.01 0.01
#  target es: 184.81962782960665,Eror test: mul,Trend test: None,Seasonal test: None,Alpha model: 0.99,Beta model: 0.01, Gamma model: 0.01
# | 102       | -184.8    | 0.99      | 0.01      | 1.0       | 0.01      | 2.0       | 2.0       |
# 0.0 0.0 2.0
# 0.01 0.01 0.01
#  target es: 176.5813449418272,Eror test: add,Trend test: add,Seasonal test: None,Alpha model: 0.01,Beta model: 0.01, Gamma model: 0.01
# | 103       | -176.6    | 0.01      | 0.01      | 0.0       | 0.01      | 2.0       | 0.0       |
# =================================================================================================

# %%
optimizer.max
# Out:
# {'target': -117.66643248793336,
#  'params': {'alpha': 0.13094541835039025,
#   'beta': 0.1703895114195003,
#   'error': 0.5677980381415073,
#   'gamma': 0.1533273729799859,
#   'seasonal': 0.2541486120351484,
#   'trend': 1.9406834156907515}}

# %% [markdown]
# ## **4. Parcial final**
#
# ### Instrucciones
# El examen se compone de dos partes:
# - La primera corresponde a una parte de selección múltiple con 19 preguntas que se responderán en el salón de clase en 45 minutos. Esa primera parte tiene una calificación de 1 a 5.
# -La segunda parte corresponde a la parte práctica del examen y tiene también una calificación de 1 a 5.
#
# - La nota de este examen parcial corresponderá al promedio ponderado de las dos notas, donde la parte práctica tiene un peso de 40 % y la parte de selección múltiple de 60 %.
# - Usted tiene hasta el 30 de agosto a las 12:00 pm para enviar los archivos por correo, estos archivos deben tener su nombre.
# - Sólo se calificaran exámenes en formato pdf. Cualquier otro formato no será tenido en cuenta.
# - El examen debe estar acompañado de un notebook (ipynb)  que incluya todo los códigos de python que se emplean para obtener sus resultados.
# - El nombre del archivo debe tener su nombre. No se recibirán archivos en otro formato.
# - Esta parte del examen es para realizar en casa y debe reflejar el trabajo individual.
#
# ### El Problema
#
# En días recientes trabajamos con una compañía de comestibles que estaba interesada en predecir el comportamiento de las ventas (en unidades) de sus dos productos estrella. Fuimos contratados para generar un modelo que permita pronosticar las ventas del siguiente mes de cada uno de esos dos productos. La base de datos disponible en el archivo Examen.csv tiene la información de cada uno de los productos desde enero de 2008.
#
# Su misión es encontrar el mejor modelo para pronosticar cada una de las series. Usted debe entregar un informe escrito de no más de cuatro páginas que presente los resultados al cliente y cuente el proceso para llegar a los pronósticos. Vea las instrucciones para asegurar que entrega los archivos requeridos
